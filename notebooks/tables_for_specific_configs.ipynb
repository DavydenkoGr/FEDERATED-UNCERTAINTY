# %%
import sys
sys.path.insert(0, "../")

import pandas as pd
import numpy as np
from pathlib import Path
from typing import Dict, List, Tuple, Optional

from mdu.eval.table_analysis_utils import (
    transform_by_tasks,
    select_composite_and_components,
    check_composite_dominance,
    compute_average_ranks,
    analyze_composite_pareto_performance,
)
from configs.interesting_compositions import INTERESTING_COMPOSITIONS

# Set pandas display options to show all columns
pd.set_option("display.max_columns", None)
pd.set_option("display.width", None)
pd.set_option("display.max_colwidth", None)
# Out:
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.3.0 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/Users/nikita/Programming/multidimensional_uncertainty/.venv/lib/python3.12/site-packages/ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "/Users/nikita/Programming/multidimensional_uncertainty/.venv/lib/python3.12/site-packages/traitlets/config/application.py", line 1075, in launch_instance
#     app.start()
#   File "/Users/nikita/Programming/multidimensional_uncertainty/.venv/lib/python3.12/site-packages/ipykernel/kernelapp.py", line 739, in start
#     self.io_loop.start()
#   File "/Users/nikita/Programming/multidimensional_uncertainty/.venv/lib/python3.12/site-packages/tornado/platform/asyncio.py", line 211, in start
#     self.asyncio_loop.run_forever()
#   File "/Users/nikita/.local/share/uv/python/cpython-3.12.9-macos-x86_64-none/lib/python3.12/asyncio/base_events.py", line 645, in run_forever
#     self._run_once()
#   File "/Users/nikita/.local/share/uv/python/cpython-3.12.9-macos-x86_64-none/lib/python3.12/asyncio/base_events.py", line 1999, in _run_once
#     handle._run()
#   File "/Users/nikita/.local/share/uv/python/cpython-3.12.9-macos-x86_64-none/lib/python3.12/asyncio/events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "/Users/nikita/Programming/multidimensional_uncertainty/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 516, in dispatch_queue
#     await self.process_one()
#   File "/Users/nikita/Programming/multidimensional_uncertainty/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 505, in process_one
#     await dispatch(*args)
#   File "/Users/nikita/Programming/multidimensional_uncertainty/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 397, in dispatch_shell
#     await result
#   File "/Users/nikita/Programming/multidimensional_uncertainty/.venv/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 368, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "/Users/nikita/Programming/multidimensional_uncertainty/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 752, in execute_request
#     reply_content = await reply_content
#   File "/Users/nikita/Programming/multidimensional_uncertainty/.venv/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 455, in do_execute
#     res = shell.run_cell(
#   File "/Users/nikita/Programming/multidimensional_uncertainty/.venv/lib/python3.12/site-packages/ipykernel/zmqshell.py", line 577, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/Users/nikita/Programming/multidimensional_uncertainty/.venv/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3100, in run_cell
#     result = self._run_cell(
#   File "/Users/nikita/Programming/multidimensional_uncertainty/.venv/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3155, in _run_cell
#     result = runner(coro)
#   File "/Users/nikita/Programming/multidimensional_uncertainty/.venv/lib/python3.12/site-packages/IPython/core/async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "/Users/nikita/Programming/multidimensional_uncertainty/.venv/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3367, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/Users/nikita/Programming/multidimensional_uncertainty/.venv/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3612, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "/Users/nikita/Programming/multidimensional_uncertainty/.venv/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3672, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/var/folders/4h/nv4crr6d7wjb2hlpkb_c5r4r0000gn/T/ipykernel_35446/2006474962.py", line 9, in <module>
#     from mdu.eval.table_analysis_utils import (
#   File "/Users/nikita/Programming/multidimensional_uncertainty/notebooks/../mdu/eval/__init__.py", line 1, in <module>
#     from . import eval_utils
#   File "/Users/nikita/Programming/multidimensional_uncertainty/notebooks/../mdu/eval/eval_utils.py", line 2, in <module>
#     import torch.nn.functional as F
#   File "/Users/nikita/Programming/multidimensional_uncertainty/.venv/lib/python3.12/site-packages/torch/__init__.py", line 1477, in <module>
#     from .functional import *  # noqa: F403
#   File "/Users/nikita/Programming/multidimensional_uncertainty/.venv/lib/python3.12/site-packages/torch/functional.py", line 9, in <module>
#     import torch.nn.functional as F
#   File "/Users/nikita/Programming/multidimensional_uncertainty/.venv/lib/python3.12/site-packages/torch/nn/__init__.py", line 1, in <module>
#     from .modules import *  # noqa: F403
#   File "/Users/nikita/Programming/multidimensional_uncertainty/.venv/lib/python3.12/site-packages/torch/nn/modules/__init__.py", line 35, in <module>
#     from .transformer import TransformerEncoder, TransformerDecoder, \
#   File "/Users/nikita/Programming/multidimensional_uncertainty/.venv/lib/python3.12/site-packages/torch/nn/modules/transformer.py", line 20, in <module>
#     device: torch.device = torch.device(torch._C._get_default_device()),  # torch.device('cpu'),
# /Users/nikita/Programming/multidimensional_uncertainty/.venv/lib/python3.12/site-packages/torch/nn/modules/transformer.py:20: UserWarning: Failed to initialize NumPy: _ARRAY_API not found (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/torch/csrc/utils/tensor_numpy.cpp:84.)
#   device: torch.device = torch.device(torch._C._get_default_device()),  # torch.device('cpu'),

# %%
def load_config_file(eps: float, grid_size: int, n_targets_multiplier: int, 
                     target: str, scaler_type: str = "global_scaler") -> pd.DataFrame:
    """
    Load a specific config file based on hyperparameters. If multiple files with different
    prefixes exist for the same config, merge them together.
    
    Args:
        eps: Epsilon value
        grid_size: Grid size
        n_targets_multiplier: N targets multiplier  
        target: Target type (exp or beta)
        scaler_type: Scaler type (global_scaler, mahalanobis, or none)
    
    Returns:
        DataFrame with the loaded config data (merged if multiple files exist)
    """
    # Build filename suffix (common part)
    scaler_suffix = f"_{scaler_type}" if scaler_type != "none" else ""
    filename_suffix = (f"_entropic_target_{target}_eps_{eps}_iters_150_"
                      f"tol_1e-06_rs_42_grid_size_{grid_size}_n_targets_multiplier_{n_targets_multiplier}{scaler_suffix}.csv")
    
    # List of possible filename prefixes to try
    possible_prefixes = [
        "extended_benchmark",
        "extra_extended_benchmark",
    ]
    
    # Find all existing files with this config
    found_files = []
    base_dir = Path("../resources/extended_benchmark")
    
    for prefix in possible_prefixes:
        candidate_filename = f"{prefix}{filename_suffix}"
        candidate_filepath = base_dir / candidate_filename
        
        if candidate_filepath.exists():
            found_files.append((candidate_filename, candidate_filepath))
    
    if not found_files:
        # Try to construct a more informative error message
        attempted_files = [f"{prefix}{filename_suffix}" for prefix in possible_prefixes]
        raise FileNotFoundError(
            f"No config files found for the specified parameters.\n"
            f"Attempted files: {attempted_files}\n"
            f"Parameters: eps={eps}, grid_size={grid_size}, n_targets_multiplier={n_targets_multiplier}, "
            f"target={target}, scaler_type={scaler_type}"
        )
    
    # Load and merge all found files
    dataframes = []
    print(f"Found {len(found_files)} files with matching config:")
    
    for filename, filepath in found_files:
        print(f"  Loading: {filename}")
        df = pd.read_csv(filepath)
        print(f"    Rows: {len(df)}, Columns: {len(df.columns)}")
        dataframes.append(df)
    
    # Merge all dataframes
    if len(dataframes) == 1:
        merged_df = dataframes[0]
        print(f"Single file loaded: {len(merged_df)} rows, {len(merged_df.columns)} columns")
    else:
        # Concatenate all dataframes
        merged_df = pd.concat(dataframes, ignore_index=True)
        print(f"Merged {len(dataframes)} files: {len(merged_df)} rows, {len(merged_df.columns)} columns")
        
        # Check for potential issues in merging
        original_total_rows = sum(len(df) for df in dataframes)
        if len(merged_df) != original_total_rows:
            print(f"  Note: Expected {original_total_rows} rows, got {len(merged_df)} after merging")
        
        # Show unique values in key columns to verify merge quality
        if 'measure' in merged_df.columns:
            unique_measures = merged_df['measure'].nunique()
            print(f"  Unique measures in merged data: {unique_measures}")
        
        if 'ind_dataset' in merged_df.columns:
            unique_datasets = merged_df['ind_dataset'].nunique()
            print(f"  Unique ind_datasets in merged data: {unique_datasets}")
    
    return merged_df

# %%
for el in INTERESTING_COMPOSITIONS.keys():
    print(el)
# Out:
# COMPOSITE BAYES ALL OUTER
# COMPOSITE BAYES ALL INNER
# COMPOSITE BAYES ALL CENTRAL
# COMPOSITE BAYES (LBS) OUTER
# COMPOSITE BAYES (LBS) INNER
# COMPOSITE BAYES (LBS) CENTRAL
# COMPOSITE BAYES ALL OUTER + M
# COMPOSITE BAYES ALL INNER + M
# COMPOSITE BAYES ALL CENTRAL + M
# COMPOSITE BAYES (LBS) OUTER + M
# COMPOSITE BAYES (LBS) INNER + M
# COMPOSITE BAYES (LBS) CENTRAL + M
# COMPOSITE BAYES ALL OUTER + GMM
# COMPOSITE BAYES ALL INNER + GMM
# COMPOSITE BAYES ALL CENTRAL + GMM
# COMPOSITE BAYES (LBS) OUTER + GMM
# COMPOSITE BAYES (LBS) INNER + GMM
# COMPOSITE BAYES (LBS) CENTRAL + GMM
# COMPOSITE EXCESS ALL OUTER OUTER
# COMPOSITE EXCESS ALL OUTER INNER
# COMPOSITE EXCESS ALL OUTER CENTRAL
# COMPOSITE EXCESS ALL INNER OUTER
# COMPOSITE EXCESS ALL INNER INNER
# COMPOSITE EXCESS ALL INNER CENTRAL
# COMPOSITE EXCESS ALL CENTRAL OUTER
# COMPOSITE EXCESS ALL CENTRAL INNER
# COMPOSITE EXCESS ALL CENTRAL CENTRAL
# COMPOSITE EXCESS LBS OUTER OUTER
# COMPOSITE EXCESS LBS OUTER INNER
# COMPOSITE EXCESS LBS OUTER CENTRAL
# COMPOSITE EXCESS LBS INNER OUTER
# COMPOSITE EXCESS LBS INNER INNER
# COMPOSITE EXCESS LBS INNER CENTRAL
# COMPOSITE EXCESS LBS CENTRAL OUTER
# COMPOSITE EXCESS LBS CENTRAL INNER
# COMPOSITE EXCESS LBS CENTRAL CENTRAL
# COMPOSITE EXCESS ALL OUTER OUTER + M
# COMPOSITE EXCESS ALL OUTER INNER + M
# COMPOSITE EXCESS ALL OUTER CENTRAL + M
# COMPOSITE EXCESS ALL INNER OUTER + M
# COMPOSITE EXCESS ALL INNER INNER + M
# COMPOSITE EXCESS ALL INNER CENTRAL + M
# COMPOSITE EXCESS ALL CENTRAL OUTER + M
# COMPOSITE EXCESS ALL CENTRAL INNER + M
# COMPOSITE EXCESS ALL CENTRAL CENTRAL + M
# COMPOSITE EAT LOGSCORE OUTER OUTER + M
# COMPOSITE EAT LOGSCORE OUTER INNER + M
# COMPOSITE EAT LOGSCORE OUTER CENTRAL + M
# COMPOSITE EAT LOGSCORE INNER OUTER + M
# COMPOSITE EAT LOGSCORE INNER CENTRAL + M
# COMPOSITE EAT LOGSCORE CENTRAL OUTER + M
# COMPOSITE EAT LOGSCORE CENTRAL INNER + M
# COMPOSITE EAT SPHERICAL OUTER OUTER + M
# COMPOSITE EAT SPHERICAL OUTER INNER + M
# COMPOSITE EAT SPHERICAL OUTER CENTRAL + M
# COMPOSITE EAT SPHERICAL INNER OUTER + M
# COMPOSITE EAT SPHERICAL INNER CENTRAL + M
# COMPOSITE EAT SPHERICAL CENTRAL OUTER + M
# COMPOSITE EAT SPHERICAL CENTRAL INNER + M
# COMPOSITE EAT SPHERICAL OUTER OUTER
# COMPOSITE EAT SPHERICAL OUTER INNER
# COMPOSITE EAT SPHERICAL OUTER CENTRAL
# COMPOSITE EAT SPHERICAL INNER OUTER
# COMPOSITE EAT SPHERICAL INNER CENTRAL
# COMPOSITE EAT SPHERICAL CENTRAL OUTER
# COMPOSITE EAT SPHERICAL CENTRAL INNER

# %%
def shorten_column_names(column_name: str) -> str:
    """
    Shorten column names for better presentation.
    
    Args:
        column_name: Original column name
        
    Returns:
        Shortened column name
    """
    # Handle composite columns
    if column_name.lower().startswith('composite'):
        return 'C'
    
    # Replace score names with shortcuts
    shortened = column_name
    shortened = shortened.replace('Logscore', 'L')
    shortened = shortened.replace('Brier', 'B')
    shortened = shortened.replace('Spherical', 'S')
    shortened = shortened.replace('Zero-one', 'Z')
    shortened = shortened.replace('mahalanobis', 'M')
    
    return shortened


def create_problem_specific_tables(transformed_df: pd.DataFrame, composite_name: str) -> Dict[str, pd.DataFrame]:
    """
    Create separate tables for each problem type: OOD detection, misclassification detection, and selective prediction.
    
    Args:
        transformed_df: Transformed DataFrame from transform_by_tasks
        composite_name: Name of the composite measure to analyze
    
    Returns:
        Dictionary with tables for each problem type
    """
    # Get composite and components data
    composite_df = select_composite_and_components(transformed_df, composite_name)
    
    # Reset index to access ind_dataset and eval columns
    df_reset = composite_df.reset_index()
    
    # Initialize result dictionary
    tables = {}
    
    # Define problem type patterns
    problem_patterns = {
        'ood_detection': '[ood]',
        'misclassification_detection': '[miscls]', 
        'selective_prediction': '[selective]'
    }
    
    for problem_type, pattern in problem_patterns.items():
        # Filter rows for this problem type
        mask = df_reset['eval'].str.contains(pattern, regex=False, na=False)
        problem_df = df_reset[mask].copy()
        
        print(f"Debug - {problem_type}: Found {len(problem_df)} rows with pattern '{pattern}'")
        if len(problem_df) > 0:
            print(f"  Sample eval values: {problem_df['eval'].unique()[:5]}")
        
        if problem_df.empty:
            print(f"Warning: No data found for {problem_type}")
            tables[problem_type] = pd.DataFrame()
            continue
        
        # Set index back to (ind_dataset, eval)
        problem_df = problem_df.set_index(['ind_dataset', 'eval'])
        
        # Identify composite and component columns
        composite_cols = [c for c in problem_df.columns if c.startswith('composite')]
        component_cols = [c for c in problem_df.columns if not c.startswith('composite')]
        
        # Reorder columns: components first, then composite
        ordered_cols = component_cols + composite_cols
        problem_df = problem_df[ordered_cols]
        
        # Apply shortened column names
        shortened_cols = {col: shorten_column_names(col) for col in problem_df.columns}
        problem_df = problem_df.rename(columns=shortened_cols)
        
        # Remove any duplicate rows based on the index
        problem_df = problem_df[~problem_df.index.duplicated(keep='first')]
        
        tables[problem_type] = problem_df
        
        print(f"{problem_type.replace('_', ' ').title()}: {len(problem_df)} rows, {len(problem_df.columns)} measures")
    
    return tables



def create_final_problem_tables(config_results_list: List[Dict]) -> Dict[str, pd.DataFrame]:
    """
    Create final tables for each problem type with rows as (ind_dataset, ood_dataset) 
    and columns stacked from all configurations.
    
    Args:
        config_results_list: List of results from analyze_specific_config
    
    Returns:
        Dictionary with final tables for each problem type
    """
    final_tables = {
        'ood_detection': [],
        'misclassification_detection': [],
        'selective_prediction': []
    }
    
    # Process each configuration result
    for result in config_results_list:
        config = result['config']
        tables = result['tables']
        
        for problem_type in final_tables.keys():
            if problem_type in tables and not tables[problem_type].empty:
                table = tables[problem_type].copy()
                
                # Reset index to get ind_dataset and eval as columns
                table_reset = table.reset_index()
                
                # Keep all metric columns as they are (with shortened names)
                metric_cols = [c for c in table.columns]
                
                if problem_type == 'ood_detection':
                    # For OOD detection: ind_dataset and ood_dataset are different
                    table_reset['ind_dataset'] = table_reset['ind_dataset']
                    table_reset['ood_dataset'] = table_reset['eval'].str.extract(r'^([^[]+)')[0].str.strip()
                    final_cols = ['ind_dataset', 'ood_dataset'] + metric_cols
                else:
                    # For selective prediction and misclassification detection: 
                    # ind_dataset and eval_dataset are the same (just use ind_dataset)
                    table_reset['ind_dataset'] = table_reset['ind_dataset']
                    table_reset['eval_dataset'] = table_reset['ind_dataset']  # Same as ind_dataset
                    final_cols = ['ind_dataset', 'eval_dataset'] + metric_cols
                
                table_final = table_reset[final_cols].copy()
                
                # Remove duplicates - keep only unique rows
                if problem_type == 'ood_detection':
                    table_final = table_final.drop_duplicates(subset=['ind_dataset', 'ood_dataset'])
                else:
                    table_final = table_final.drop_duplicates(subset=['ind_dataset', 'eval_dataset'])
                
                print(f"Debug - Adding table for {problem_type}: shape {table_final.shape} (after deduplication)")
                final_tables[problem_type].append(table_final)
    
    # Combine all configurations for each problem type by concatenating columns
    combined_tables = {}
    for problem_type, table_list in final_tables.items():
        if table_list:
            # Determine the key columns based on problem type
            if problem_type == 'ood_detection':
                key_cols = ['ind_dataset', 'ood_dataset']
            else:
                key_cols = ['ind_dataset', 'eval_dataset']
            
            # Start with the first table
            combined = table_list[0]
            
            # Add columns from subsequent tables
            for i, table in enumerate(table_list[1:], 1):
                # Get metric columns (exclude key columns)
                metric_cols = [c for c in table.columns if c not in key_cols]
                
                # Rename metric columns to avoid conflicts by adding config index
                table_to_merge = table[key_cols + metric_cols].copy()
                rename_dict = {col: f"{col}_v{i+1}" for col in metric_cols}
                table_to_merge = table_to_merge.rename(columns=rename_dict)
                
                # Also rename columns in the first table if this is the first merge
                if i == 1:
                    first_metric_cols = [c for c in combined.columns if c not in key_cols]
                    first_rename_dict = {col: f"{col}_v1" for col in first_metric_cols}
                    combined = combined.rename(columns=first_rename_dict)
                
                # Merge on key columns, adding new metric columns
                combined = pd.merge(combined, table_to_merge, 
                                  on=key_cols, how='outer')
            
            # Set index
            combined = combined.set_index(key_cols)
            combined_tables[problem_type] = combined
            print(f"Debug - Final {problem_type} table shape: {combined.shape}")
        else:
            combined_tables[problem_type] = pd.DataFrame()
            print(f"Debug - No data for {problem_type}")
    
    return combined_tables


def analyze_multiple_configs(config_list: List[Dict], selective_metric: str = "acc_cov_auc") -> Dict:
    """
    Analyze multiple configurations and return results as DataFrames.
    
    Args:
        config_list: List of dictionaries with config parameters and composite_name
        selective_metric: Metric for selective prediction
    
    Returns:
        Dictionary with results and final tables
    """
    results = []
    
    print(f"Analyzing {len(config_list)} configurations...")
    print("=" * 80)
    
    for i, config in enumerate(config_list):
        print(f"\nConfiguration {i+1}/{len(config_list)}:")
        print(f"  eps={config['eps']}, grid_size={config['grid_size']}, n_targets_multiplier={config['n_targets_multiplier']}")
        print(f"  target={config['target']}, scaler_type={config['scaler_type']}")
        print(f"  composite_name={config['composite_name']}")
        
        try:
            # Load and transform data
            df = load_config_file(
                config['eps'], config['grid_size'], config['n_targets_multiplier'], 
                config['target'], config.get('scaler_type', 'global_scaler')
            )
            
            transformed_df = transform_by_tasks(df, selective_metric=selective_metric)
            tables = create_problem_specific_tables(transformed_df, config['composite_name'])
            
            # Store result
            result = {
                'config': config,
                'raw_df': df,
                'transformed_df': transformed_df, 
                'tables': tables
            }
            results.append(result)
            
            print(f"  ✓ Successfully processed")
            
        except Exception as e:
            print(f"  ✗ Error processing configuration: {e}")
            continue
    
    print(f"\nSuccessfully processed {len(results)}/{len(config_list)} configurations")
    
    # Create final combined tables
    print("\nCreating final combined tables...")
    final_tables = create_final_problem_tables(results)
    
    return {
        'individual_results': results,
        'final_tables': final_tables,
        'config_list': config_list
    }

# %%
def display_tables_with_formatting(tables: Dict[str, pd.DataFrame], composite_name: str):
    """
    Display the tables with nice formatting and separators between components and composite.
    
    Args:
        tables: Dictionary of tables from create_problem_specific_tables
        composite_name: Name of the composite measure being analyzed
    """
    print("=" * 100)
    print(f"ANALYSIS FOR COMPOSITE MEASURE: {composite_name}")
    print("=" * 100)
    
    for problem_type, table in tables.items():
        if table.empty:
            continue
            
        print(f"\n{'-' * 60}")
        print(f"{problem_type.replace('_', ' ').upper()} TABLE")
        print(f"{'-' * 60}")
        
        # Identify composite and component columns (using shortened names)
        composite_cols = [c for c in table.columns if c.lower().startswith('comp')]
        component_cols = [c for c in table.columns if not c.lower().startswith('comp')]
        
        print(f"Component measures ({len(component_cols)}): {', '.join(component_cols)}")
        if composite_cols:
            print(f"Composite measure ({len(composite_cols)}): {', '.join(composite_cols)}")
        
        print("\nTable:")
        print(table.round(4))
        
        # Show summary statistics
        print(f"\nSummary Statistics for {problem_type.replace('_', ' ').title()}:")
        print("Mean values:")
        mean_values = table.mean()
        for col in component_cols + composite_cols:
            if col in mean_values:
                print(f"  {col}: {mean_values[col]:.4f}")
        
        print(f"\nStandard deviations:")
        std_values = table.std()
        for col in component_cols + composite_cols:
            if col in std_values:
                print(f"  {col}: {std_values[col]:.4f}")
    
    print("\n" + "=" * 100)

# %% [markdown]
# ## Example Analysis
#
# Now let's analyze a specific configuration. You can modify the parameters below to analyze different configurations:

# %%
config_list = [
    {
        'eps': 0.5,
        'grid_size': 5,
        'n_targets_multiplier': 1,
        'target': 'exp',
        'scaler_type': 'global_scaler',
        'composite_name': 'COMPOSITE BAYES ALL OUTER'
    },
    {
        'eps': 0.5,
        'grid_size': 5,
        'n_targets_multiplier': 1,
        'target': 'beta',
        'scaler_type': 'none',
        'composite_name': 'COMPOSITE BAYES ALL OUTER + M'
    },
    {
        'eps': 0.5,
        'grid_size': 5,
        'n_targets_multiplier': 1,
        'target': 'exp',
        'scaler_type': 'global_scaler',
        'composite_name': 'COMPOSITE EXCESS ALL OUTER INNER'
    },
    {
        'eps': 0.5,
        'grid_size': 5,
        'n_targets_multiplier': 1,
        'target': 'exp',
        'scaler_type': 'none',
        'composite_name': 'COMPOSITE EXCESS ALL OUTER INNER + M'
    },
    {
        'eps': 0.5,
        'grid_size': 5,
        'n_targets_multiplier': 1,
        'target': 'beta',
        'scaler_type': 'none',
        'composite_name': 'COMPOSITE EAT LOGSCORE OUTER OUTER + M'
    },
    {
        'eps': 0.5,
        'grid_size': 5,
        'n_targets_multiplier': 1,
        'target': 'beta',
        'scaler_type': 'none',
        'composite_name': 'COMPOSITE EAT LOGSCORE OUTER INNER + M'
    },
    {
        'eps': 0.5,
        'grid_size': 5,
        'n_targets_multiplier': 1,
        'target': 'beta',
        'scaler_type': 'global_scaler',
        'composite_name': 'COMPOSITE EAT LOGSCORE OUTER CENTRAL + M'
    },
    {
        'eps': 0.5,
        'grid_size': 5,
        'n_targets_multiplier': 1,
        'target': 'exp',
        'scaler_type': 'global_scaler',
        'composite_name': 'COMPOSITE EAT SPHERICAL OUTER OUTER + M'
    },
    {
        'eps': 0.5,
        'grid_size': 5,
        'n_targets_multiplier': 1,
        'target': 'exp',
        'scaler_type': 'global_scaler',
        'composite_name': 'COMPOSITE EAT SPHERICAL OUTER INNER + M'
    },
    {
        'eps': 0.5,
        'grid_size': 5,
        'n_targets_multiplier': 1,
        'target': 'exp',
        'scaler_type': 'global_scaler',
        'composite_name': 'COMPOSITE EAT SPHERICAL OUTER CENTRAL + M'
    },
]

# %%
# Run the analysis for all configurations
results = analyze_multiple_configs(config_list)
# Out:
# Analyzing 10 configurations...
# ================================================================================
#
# Configuration 1/10:
#   eps=0.5, grid_size=5, n_targets_multiplier=1
#   target=exp, scaler_type=global_scaler
#   composite_name=COMPOSITE BAYES ALL OUTER
# Found 2 files with matching config:
#   Loading: extended_benchmark_entropic_target_exp_eps_0.5_iters_150_tol_1e-06_rs_42_grid_size_5_n_targets_multiplier_1_global_scaler.csv
#     Rows: 7680, Columns: 23
#   Loading: extra_extended_benchmark_entropic_target_exp_eps_0.5_iters_150_tol_1e-06_rs_42_grid_size_5_n_targets_multiplier_1_global_scaler.csv
#     Rows: 5940, Columns: 23
# Merged 2 files: 13620 rows, 23 columns
#   Unique measures in merged data: 141
#   Unique ind_datasets in merged data: 3
# Debug - ood_detection: Found 9 rows with pattern '[ood]'
#   Sample eval values: ['cifar100 [ood]' 'svhn [ood]' 'tiny_imagenet [ood]' 'cifar10 [ood]'
#  'imagenet_a [ood]']
# Ood Detection: 9 rows, 5 measures
# Debug - misclassification_detection: Found 3 rows with pattern '[miscls]'
#   Sample eval values: ['cifar10 [miscls]' 'cifar100 [miscls]' 'tiny_imagenet [miscls]']
# Misclassification Detection: 3 rows, 5 measures
# Debug - selective_prediction: Found 3 rows with pattern '[selective]'
#   Sample eval values: ['cifar10 [selective]' 'cifar100 [selective]' 'tiny_imagenet [selective]']
# Selective Prediction: 3 rows, 5 measures
#   ✓ Successfully processed
#
# Configuration 2/10:
#   eps=0.5, grid_size=5, n_targets_multiplier=1
#   target=beta, scaler_type=none
#   composite_name=COMPOSITE BAYES ALL OUTER + M
# Found 2 files with matching config:
#   Loading: extended_benchmark_entropic_target_beta_eps_0.5_iters_150_tol_1e-06_rs_42_grid_size_5_n_targets_multiplier_1.csv
#     Rows: 7920, Columns: 23
#   Loading: extra_extended_benchmark_entropic_target_beta_eps_0.5_iters_150_tol_1e-06_rs_42_grid_size_5_n_targets_multiplier_1.csv
#     Rows: 5940, Columns: 23
# Merged 2 files: 13860 rows, 23 columns
#   Unique measures in merged data: 145
#   Unique ind_datasets in merged data: 3
# Debug - ood_detection: Found 9 rows with pattern '[ood]'
#   Sample eval values: ['cifar100 [ood]' 'svhn [ood]' 'tiny_imagenet [ood]' 'cifar10 [ood]'
#  'imagenet_a [ood]']
# Ood Detection: 9 rows, 6 measures
# Debug - misclassification_detection: Found 3 rows with pattern '[miscls]'
#   Sample eval values: ['cifar10 [miscls]' 'cifar100 [miscls]' 'tiny_imagenet [miscls]']
# Misclassification Detection: 3 rows, 6 measures
# Debug - selective_prediction: Found 3 rows with pattern '[selective]'
#   Sample eval values: ['cifar10 [selective]' 'cifar100 [selective]' 'tiny_imagenet [selective]']
# Selective Prediction: 3 rows, 6 measures
#   ✓ Successfully processed
#
# Configuration 3/10:
#   eps=0.5, grid_size=5, n_targets_multiplier=1
#   target=exp, scaler_type=global_scaler
#   composite_name=COMPOSITE EXCESS ALL OUTER INNER
# Found 2 files with matching config:
#   Loading: extended_benchmark_entropic_target_exp_eps_0.5_iters_150_tol_1e-06_rs_42_grid_size_5_n_targets_multiplier_1_global_scaler.csv
#     Rows: 7680, Columns: 23
#   Loading: extra_extended_benchmark_entropic_target_exp_eps_0.5_iters_150_tol_1e-06_rs_42_grid_size_5_n_targets_multiplier_1_global_scaler.csv
#     Rows: 5940, Columns: 23
# Merged 2 files: 13620 rows, 23 columns
#   Unique measures in merged data: 141
#   Unique ind_datasets in merged data: 3
# Debug - ood_detection: Found 9 rows with pattern '[ood]'
#   Sample eval values: ['cifar100 [ood]' 'svhn [ood]' 'tiny_imagenet [ood]' 'cifar10 [ood]'
#  'imagenet_a [ood]']
# Ood Detection: 9 rows, 5 measures
# Debug - misclassification_detection: Found 3 rows with pattern '[miscls]'
#   Sample eval values: ['cifar10 [miscls]' 'cifar100 [miscls]' 'tiny_imagenet [miscls]']
# Misclassification Detection: 3 rows, 5 measures
# Debug - selective_prediction: Found 3 rows with pattern '[selective]'
#   Sample eval values: ['cifar10 [selective]' 'cifar100 [selective]' 'tiny_imagenet [selective]']
# Selective Prediction: 3 rows, 5 measures
#   ✓ Successfully processed
#
# Configuration 4/10:
#   eps=0.5, grid_size=5, n_targets_multiplier=1
#   target=exp, scaler_type=none
#   composite_name=COMPOSITE EXCESS ALL OUTER INNER + M
# Found 2 files with matching config:
#   Loading: extended_benchmark_entropic_target_exp_eps_0.5_iters_150_tol_1e-06_rs_42_grid_size_5_n_targets_multiplier_1.csv
#     Rows: 7920, Columns: 23
#   Loading: extra_extended_benchmark_entropic_target_exp_eps_0.5_iters_150_tol_1e-06_rs_42_grid_size_5_n_targets_multiplier_1.csv
#     Rows: 5940, Columns: 23
# Merged 2 files: 13860 rows, 23 columns
#   Unique measures in merged data: 145
#   Unique ind_datasets in merged data: 3
# Debug - ood_detection: Found 9 rows with pattern '[ood]'
#   Sample eval values: ['cifar100 [ood]' 'svhn [ood]' 'tiny_imagenet [ood]' 'cifar10 [ood]'
#  'imagenet_a [ood]']
# Ood Detection: 9 rows, 6 measures
# Debug - misclassification_detection: Found 3 rows with pattern '[miscls]'
#   Sample eval values: ['cifar10 [miscls]' 'cifar100 [miscls]' 'tiny_imagenet [miscls]']
# Misclassification Detection: 3 rows, 6 measures
# Debug - selective_prediction: Found 3 rows with pattern '[selective]'
#   Sample eval values: ['cifar10 [selective]' 'cifar100 [selective]' 'tiny_imagenet [selective]']
# Selective Prediction: 3 rows, 6 measures
#   ✓ Successfully processed
#
# Configuration 5/10:
#   eps=0.5, grid_size=5, n_targets_multiplier=1
#   target=beta, scaler_type=none
#   composite_name=COMPOSITE EAT LOGSCORE OUTER OUTER + M
# Found 2 files with matching config:
#   Loading: extended_benchmark_entropic_target_beta_eps_0.5_iters_150_tol_1e-06_rs_42_grid_size_5_n_targets_multiplier_1.csv
#     Rows: 7920, Columns: 23
#   Loading: extra_extended_benchmark_entropic_target_beta_eps_0.5_iters_150_tol_1e-06_rs_42_grid_size_5_n_targets_multiplier_1.csv
#     Rows: 5940, Columns: 23
# Merged 2 files: 13860 rows, 23 columns
#   Unique measures in merged data: 145
#   Unique ind_datasets in merged data: 3
# Debug - ood_detection: Found 9 rows with pattern '[ood]'
#   Sample eval values: ['cifar100 [ood]' 'svhn [ood]' 'tiny_imagenet [ood]' 'cifar10 [ood]'
#  'imagenet_a [ood]']
# Ood Detection: 9 rows, 5 measures
# Debug - misclassification_detection: Found 3 rows with pattern '[miscls]'
#   Sample eval values: ['cifar10 [miscls]' 'cifar100 [miscls]' 'tiny_imagenet [miscls]']
# Misclassification Detection: 3 rows, 5 measures
# Debug - selective_prediction: Found 3 rows with pattern '[selective]'
#   Sample eval values: ['cifar10 [selective]' 'cifar100 [selective]' 'tiny_imagenet [selective]']
# Selective Prediction: 3 rows, 5 measures
#   ✓ Successfully processed
#
# Configuration 6/10:
#   eps=0.5, grid_size=5, n_targets_multiplier=1
#   target=beta, scaler_type=none
#   composite_name=COMPOSITE EAT LOGSCORE OUTER INNER + M
# Found 2 files with matching config:
#   Loading: extended_benchmark_entropic_target_beta_eps_0.5_iters_150_tol_1e-06_rs_42_grid_size_5_n_targets_multiplier_1.csv
#     Rows: 7920, Columns: 23
#   Loading: extra_extended_benchmark_entropic_target_beta_eps_0.5_iters_150_tol_1e-06_rs_42_grid_size_5_n_targets_multiplier_1.csv
#     Rows: 5940, Columns: 23
# Merged 2 files: 13860 rows, 23 columns
#   Unique measures in merged data: 145
#   Unique ind_datasets in merged data: 3
# Debug - ood_detection: Found 9 rows with pattern '[ood]'
#   Sample eval values: ['cifar100 [ood]' 'svhn [ood]' 'tiny_imagenet [ood]' 'cifar10 [ood]'
#  'imagenet_a [ood]']
# Ood Detection: 9 rows, 5 measures
# Debug - misclassification_detection: Found 3 rows with pattern '[miscls]'
#   Sample eval values: ['cifar10 [miscls]' 'cifar100 [miscls]' 'tiny_imagenet [miscls]']
# Misclassification Detection: 3 rows, 5 measures
# Debug - selective_prediction: Found 3 rows with pattern '[selective]'
#   Sample eval values: ['cifar10 [selective]' 'cifar100 [selective]' 'tiny_imagenet [selective]']
# Selective Prediction: 3 rows, 5 measures
#   ✓ Successfully processed
#
# Configuration 7/10:
#   eps=0.5, grid_size=5, n_targets_multiplier=1
#   target=beta, scaler_type=none
#   composite_name=COMPOSITE EAT LOGSCORE OUTER CENTRAL + M
# Found 2 files with matching config:
#   Loading: extended_benchmark_entropic_target_beta_eps_0.5_iters_150_tol_1e-06_rs_42_grid_size_5_n_targets_multiplier_1.csv
#     Rows: 7920, Columns: 23
#   Loading: extra_extended_benchmark_entropic_target_beta_eps_0.5_iters_150_tol_1e-06_rs_42_grid_size_5_n_targets_multiplier_1.csv
#     Rows: 5940, Columns: 23
# Merged 2 files: 13860 rows, 23 columns
#   Unique measures in merged data: 145
#   Unique ind_datasets in merged data: 3
# Debug - ood_detection: Found 9 rows with pattern '[ood]'
#   Sample eval values: ['cifar100 [ood]' 'svhn [ood]' 'tiny_imagenet [ood]' 'cifar10 [ood]'
#  'imagenet_a [ood]']
# Ood Detection: 9 rows, 5 measures
# Debug - misclassification_detection: Found 3 rows with pattern '[miscls]'
#   Sample eval values: ['cifar10 [miscls]' 'cifar100 [miscls]' 'tiny_imagenet [miscls]']
# Misclassification Detection: 3 rows, 5 measures
# Debug - selective_prediction: Found 3 rows with pattern '[selective]'
#   Sample eval values: ['cifar10 [selective]' 'cifar100 [selective]' 'tiny_imagenet [selective]']
# Selective Prediction: 3 rows, 5 measures
#   ✓ Successfully processed
#
# Configuration 8/10:
#   eps=0.5, grid_size=5, n_targets_multiplier=1
#   target=exp, scaler_type=global_scaler
#   composite_name=COMPOSITE EAT SPHERICAL OUTER OUTER + M
# Found 2 files with matching config:
#   Loading: extended_benchmark_entropic_target_exp_eps_0.5_iters_150_tol_1e-06_rs_42_grid_size_5_n_targets_multiplier_1_global_scaler.csv
#     Rows: 7680, Columns: 23
#   Loading: extra_extended_benchmark_entropic_target_exp_eps_0.5_iters_150_tol_1e-06_rs_42_grid_size_5_n_targets_multiplier_1_global_scaler.csv
#     Rows: 5940, Columns: 23
# Merged 2 files: 13620 rows, 23 columns
#   Unique measures in merged data: 141
#   Unique ind_datasets in merged data: 3
# Debug - ood_detection: Found 9 rows with pattern '[ood]'
#   Sample eval values: ['cifar100 [ood]' 'svhn [ood]' 'tiny_imagenet [ood]' 'cifar10 [ood]'
#  'imagenet_a [ood]']
# Ood Detection: 9 rows, 5 measures
# Debug - misclassification_detection: Found 3 rows with pattern '[miscls]'
#   Sample eval values: ['cifar10 [miscls]' 'cifar100 [miscls]' 'tiny_imagenet [miscls]']
# Misclassification Detection: 3 rows, 5 measures
# Debug - selective_prediction: Found 3 rows with pattern '[selective]'
#   Sample eval values: ['cifar10 [selective]' 'cifar100 [selective]' 'tiny_imagenet [selective]']
# Selective Prediction: 3 rows, 5 measures
#   ✓ Successfully processed
#
# Configuration 9/10:
#   eps=0.5, grid_size=5, n_targets_multiplier=1
#   target=beta, scaler_type=none
#   composite_name=COMPOSITE EAT SPHERICAL OUTER INNER + M
# Found 2 files with matching config:
#   Loading: extended_benchmark_entropic_target_beta_eps_0.5_iters_150_tol_1e-06_rs_42_grid_size_5_n_targets_multiplier_1.csv
#     Rows: 7920, Columns: 23
#   Loading: extra_extended_benchmark_entropic_target_beta_eps_0.5_iters_150_tol_1e-06_rs_42_grid_size_5_n_targets_multiplier_1.csv
#     Rows: 5940, Columns: 23
# Merged 2 files: 13860 rows, 23 columns
#   Unique measures in merged data: 145
#   Unique ind_datasets in merged data: 3
# Debug - ood_detection: Found 9 rows with pattern '[ood]'
#   Sample eval values: ['cifar100 [ood]' 'svhn [ood]' 'tiny_imagenet [ood]' 'cifar10 [ood]'
#  'imagenet_a [ood]']
# Ood Detection: 9 rows, 5 measures
# Debug - misclassification_detection: Found 3 rows with pattern '[miscls]'
#   Sample eval values: ['cifar10 [miscls]' 'cifar100 [miscls]' 'tiny_imagenet [miscls]']
# Misclassification Detection: 3 rows, 5 measures
# Debug - selective_prediction: Found 3 rows with pattern '[selective]'
#   Sample eval values: ['cifar10 [selective]' 'cifar100 [selective]' 'tiny_imagenet [selective]']
# Selective Prediction: 3 rows, 5 measures
#   ✓ Successfully processed
#
# Configuration 10/10:
#   eps=0.5, grid_size=5, n_targets_multiplier=1
#   target=beta, scaler_type=none
#   composite_name=COMPOSITE EAT SPHERICAL OUTER CENTRAL + M
# Found 2 files with matching config:
#   Loading: extended_benchmark_entropic_target_beta_eps_0.5_iters_150_tol_1e-06_rs_42_grid_size_5_n_targets_multiplier_1.csv
#     Rows: 7920, Columns: 23
#   Loading: extra_extended_benchmark_entropic_target_beta_eps_0.5_iters_150_tol_1e-06_rs_42_grid_size_5_n_targets_multiplier_1.csv
#     Rows: 5940, Columns: 23
# Merged 2 files: 13860 rows, 23 columns
#   Unique measures in merged data: 145
#   Unique ind_datasets in merged data: 3
# Debug - ood_detection: Found 9 rows with pattern '[ood]'
#   Sample eval values: ['cifar100 [ood]' 'svhn [ood]' 'tiny_imagenet [ood]' 'cifar10 [ood]'
#  'imagenet_a [ood]']
# Ood Detection: 9 rows, 5 measures
# Debug - misclassification_detection: Found 3 rows with pattern '[miscls]'
#   Sample eval values: ['cifar10 [miscls]' 'cifar100 [miscls]' 'tiny_imagenet [miscls]']
# Misclassification Detection: 3 rows, 5 measures
# Debug - selective_prediction: Found 3 rows with pattern '[selective]'
#   Sample eval values: ['cifar10 [selective]' 'cifar100 [selective]' 'tiny_imagenet [selective]']
# Selective Prediction: 3 rows, 5 measures
#   ✓ Successfully processed
#
# Successfully processed 10/10 configurations
#
# Creating final combined tables...
# Debug - Adding table for ood_detection: shape (9, 7) (after deduplication)
# Debug - Adding table for misclassification_detection: shape (3, 7) (after deduplication)
# Debug - Adding table for selective_prediction: shape (3, 7) (after deduplication)
# Debug - Adding table for ood_detection: shape (9, 8) (after deduplication)
# Debug - Adding table for misclassification_detection: shape (3, 8) (after deduplication)
# Debug - Adding table for selective_prediction: shape (3, 8) (after deduplication)
# Debug - Adding table for ood_detection: shape (9, 7) (after deduplication)
# Debug - Adding table for misclassification_detection: shape (3, 7) (after deduplication)
# Debug - Adding table for selective_prediction: shape (3, 7) (after deduplication)
# Debug - Adding table for ood_detection: shape (9, 8) (after deduplication)
# Debug - Adding table for misclassification_detection: shape (3, 8) (after deduplication)
# Debug - Adding table for selective_prediction: shape (3, 8) (after deduplication)
# Debug - Adding table for ood_detection: shape (9, 7) (after deduplication)
# Debug - Adding table for misclassification_detection: shape (3, 7) (after deduplication)
# Debug - Adding table for selective_prediction: shape (3, 7) (after deduplication)
# Debug - Adding table for ood_detection: shape (9, 7) (after deduplication)
# Debug - Adding table for misclassification_detection: shape (3, 7) (after deduplication)
# Debug - Adding table for selective_prediction: shape (3, 7) (after deduplication)
# Debug - Adding table for ood_detection: shape (9, 7) (after deduplication)
# Debug - Adding table for misclassification_detection: shape (3, 7) (after deduplication)
# Debug - Adding table for selective_prediction: shape (3, 7) (after deduplication)
# Debug - Adding table for ood_detection: shape (9, 7) (after deduplication)
# Debug - Adding table for misclassification_detection: shape (3, 7) (after deduplication)
# Debug - Adding table for selective_prediction: shape (3, 7) (after deduplication)
# Debug - Adding table for ood_detection: shape (9, 7) (after deduplication)
# Debug - Adding table for misclassification_detection: shape (3, 7) (after deduplication)
# Debug - Adding table for selective_prediction: shape (3, 7) (after deduplication)
# Debug - Adding table for ood_detection: shape (9, 7) (after deduplication)
# Debug - Adding table for misclassification_detection: shape (3, 7) (after deduplication)
# Debug - Adding table for selective_prediction: shape (3, 7) (after deduplication)
# Debug - Final ood_detection table shape: (9, 52)
# Debug - Final misclassification_detection table shape: (3, 52)
# Debug - Final selective_prediction table shape: (3, 52)

# %% [markdown]
# ## Access Individual Tables
#
# You can access individual tables from the results:

# %%
# Display final combined tables as DataFrames
print("FINAL COMBINED TABLES")
print("=" * 80)

# OOD Detection Table
print("\n1. OOD DETECTION TABLE")
print("-" * 40)
ood_final = results['final_tables']['ood_detection']
if not ood_final.empty:
    print(f"Shape: {ood_final.shape}")
    print("\nDataFrame:")
    display(ood_final.round(4))
else:
    print("No data available for OOD detection")

# Misclassification Detection Table
print("\n2. MISCLASSIFICATION DETECTION TABLE")
print("-" * 50)
miscls_final = results['final_tables']['misclassification_detection']
if not miscls_final.empty:
    print(f"Shape: {miscls_final.shape}")
    print("\nDataFrame:")
    display(miscls_final.round(4))
else:
    print("No data available for misclassification detection")

# Selective Prediction Table
print("\n3. SELECTIVE PREDICTION TABLE")
print("-" * 40)
selective_final = results['final_tables']['selective_prediction']
if not selective_final.empty:
    print(f"Shape: {selective_final.shape}")
    print("\nDataFrame:")
    display(selective_final.round(4))
else:
    print("No data available for selective prediction")
# Out:
# FINAL COMBINED TABLES
# ================================================================================
#
# 1. OOD DETECTION TABLE
# ----------------------------------------
# Shape: (9, 52)
#
# DataFrame:
# measure                      R_b 1 (L)_v1  R_b 1 (B)_v1  R_b 1 (S)_v1  \
# ind_dataset   ood_dataset
# cifar10       cifar100             0.9169        0.9144        0.9145
#               svhn                 0.9630        0.9584        0.9585
#               tiny_imagenet        0.9114        0.9086        0.9087
# cifar100      cifar10              0.7733        0.7730        0.7734
#               svhn                 0.8701        0.8583        0.8610
#               tiny_imagenet        0.8099        0.7895        0.8063
# tiny_imagenet imagenet_a           0.8354        0.8272        0.8301
#               imagenet_o           0.7243        0.7210        0.7226
#               imagenet_r           0.8253        0.8162        0.8192
#
# measure                      R_b 1 (Z)_v1    C_v1  R_b 1 (L)_v2  R_b 1 (B)_v2  \
# ind_dataset   ood_dataset
# cifar10       cifar100             0.9132  0.9158        0.9169        0.9144
#               svhn                 0.9563  0.9610        0.9630        0.9584
#               tiny_imagenet        0.9072  0.9101        0.9114        0.9086
# cifar100      cifar10              0.7722  0.7734        0.7733        0.7730
#               svhn                 0.8559  0.8659        0.8701        0.8583
#               tiny_imagenet        0.8030  0.8054        0.8099        0.7895
# tiny_imagenet imagenet_a           0.8263  0.8331        0.8354        0.8272
#               imagenet_o           0.7212  0.7234        0.7243        0.7210
#               imagenet_r           0.8155  0.8225        0.8253        0.8162
#
# measure                      R_b 1 (S)_v2  R_b 1 (Z)_v2    M_v2    C_v2  \
# ind_dataset   ood_dataset
# cifar10       cifar100             0.9145        0.9132  0.9122  0.9185
#               svhn                 0.9585        0.9563  0.9343  0.9572
#               tiny_imagenet        0.9087        0.9072  0.9103  0.9140
# cifar100      cifar10              0.7734        0.7722  0.5348  0.7681
#               svhn                 0.8610        0.8559  0.6788  0.8677
#               tiny_imagenet        0.8063        0.8030  0.6229  0.8046
# tiny_imagenet imagenet_a           0.8301        0.8263  0.4410  0.8324
#               imagenet_o           0.7226        0.7212  0.5127  0.7277
#               imagenet_r           0.8192        0.8155  0.4048  0.8203
#
# measure                      R_e 1 2 (L)_v3  R_e 1 2 (B)_v3  R_e 1 2 (S)_v3  \
# ind_dataset   ood_dataset
# cifar10       cifar100               0.9072          0.9023          0.9024
#               svhn                   0.9458          0.9402          0.9421
#               tiny_imagenet          0.8987          0.8932          0.8931
# cifar100      cifar10                0.7367          0.6813          0.7216
#               svhn                   0.7763          0.6621          0.7312
#               tiny_imagenet          0.9999          0.9534          0.9944
# tiny_imagenet imagenet_a             0.8014          0.6511          0.7319
#               imagenet_o             0.7552          0.6911          0.7236
#               imagenet_r             0.7933          0.6570          0.7308
#
# measure                      R_e 1 2 (Z)_v3    C_v3  R_e 1 2 (L)_v4  \
# ind_dataset   ood_dataset
# cifar10       cifar100               0.7546  0.9059          0.9072
#               svhn                   0.8246  0.9440          0.9458
#               tiny_imagenet          0.7524  0.8972          0.8987
# cifar100      cifar10                0.6891  0.7206          0.7367
#               svhn                   0.7057  0.7396          0.7763
#               tiny_imagenet          0.9763  0.9999          0.9999
# tiny_imagenet imagenet_a             0.7129  0.7550          0.8014
#               imagenet_o             0.7005  0.7368          0.7552
#               imagenet_r             0.7122  0.7501          0.7933
#
# measure                      R_e 1 2 (B)_v4  R_e 1 2 (S)_v4  R_e 1 2 (Z)_v4  \
# ind_dataset   ood_dataset
# cifar10       cifar100               0.9023          0.9024          0.7546
#               svhn                   0.9402          0.9421          0.8246
#               tiny_imagenet          0.8932          0.8931          0.7524
# cifar100      cifar10                0.6813          0.7216          0.6891
#               svhn                   0.6621          0.7312          0.7057
#               tiny_imagenet          0.9534          0.9944          0.9763
# tiny_imagenet imagenet_a             0.6511          0.7319          0.7129
#               imagenet_o             0.6911          0.7236          0.7005
#               imagenet_r             0.6570          0.7308          0.7122
#
# measure                        M_v4    C_v4  R_e 1 1 (L)_v5  R_t 1 1 (L)_v5  \
# ind_dataset   ood_dataset
# cifar10       cifar100       0.9122  0.9103          0.9047          0.9115
#               svhn           0.9343  0.9423          0.9426          0.9565
#               tiny_imagenet  0.9103  0.9042          0.8957          0.9036
# cifar100      cifar10        0.5348  0.6928          0.7245          0.7740
#               svhn           0.6788  0.7247          0.7558          0.8677
#               tiny_imagenet  0.6229  0.9996          0.9999          1.0000
# tiny_imagenet imagenet_a     0.4410  0.7293          0.7811          0.8463
#               imagenet_o     0.5127  0.7213          0.7528          0.7535
#               imagenet_r     0.4048  0.7238          0.7744          0.8366
#
# measure                      R_b 1 (L)_v5    M_v5    C_v5  R_e 1 2 (L)_v6  \
# ind_dataset   ood_dataset
# cifar10       cifar100             0.9169  0.9122  0.9181          0.9072
#               svhn                 0.9630  0.9343  0.9573          0.9458
#               tiny_imagenet        0.9114  0.9103  0.9123          0.8987
# cifar100      cifar10              0.7733  0.5348  0.7649          0.7367
#               svhn                 0.8701  0.6788  0.8717          0.7763
#               tiny_imagenet        0.8099  0.6229  1.0000          0.9999
# tiny_imagenet imagenet_a           0.8354  0.4410  0.8469          0.8014
#               imagenet_o           0.7243  0.5127  0.7596          0.7552
#               imagenet_r           0.8253  0.4048  0.8347          0.7933
#
# measure                      R_t 1 2 (L)_v6  R_b 1 (L)_v6    M_v6    C_v6  \
# ind_dataset   ood_dataset
# cifar10       cifar100               0.9162        0.9169  0.9122  0.9194
#               svhn                   0.9631        0.9630  0.9343  0.9591
#               tiny_imagenet          0.9095        0.9114  0.9103  0.9141
# cifar100      cifar10                0.7745        0.7733  0.5348  0.7667
#               svhn                   0.8702        0.8701  0.6788  0.8745
#               tiny_imagenet          0.9260        0.8099  0.6229  0.9994
# tiny_imagenet imagenet_a             0.8410        0.8354  0.4410  0.8466
#               imagenet_o             0.7349        0.7243  0.5127  0.7514
#               imagenet_r             0.8310        0.8253  0.4048  0.8344
#
# measure                      R_e 1 3 (L)_v7  R_t 1 3 (L)_v7  R_b 1 (L)_v7  \
# ind_dataset   ood_dataset
# cifar10       cifar100               0.9026          0.9150        0.9169
#               svhn                   0.9397          0.9619        0.9630
#               tiny_imagenet          0.8935          0.9079        0.9114
# cifar100      cifar10                0.7180          0.7742        0.7733
#               svhn                   0.7499          0.8703        0.8701
#               tiny_imagenet          0.9999          0.9797        0.8099
# tiny_imagenet imagenet_a             0.7720          0.8427        0.8354
#               imagenet_o             0.7464          0.7406        0.7243
#               imagenet_r             0.7644          0.8327        0.8253
#
# measure                        M_v7    C_v7  R_e 1 1 (S)_v8  R_t 1 1 (S)_v8  \
# ind_dataset   ood_dataset
# cifar10       cifar100       0.9122  0.9189          0.9044          0.9113
#               svhn           0.9343  0.9584          0.9420          0.9551
#               tiny_imagenet  0.9103  0.9134          0.8956          0.9036
# cifar100      cifar10        0.5348  0.7652          0.7172          0.7735
#               svhn           0.6788  0.8738          0.7234          0.8526
#               tiny_imagenet  0.6229  1.0000          0.9915          0.9930
# tiny_imagenet imagenet_a     0.4410  0.8462          0.7212          0.8352
#               imagenet_o     0.5127  0.7541          0.7211          0.7415
#               imagenet_r     0.4048  0.8339          0.7216          0.8253
#
# measure                      R_b 1 (S)_v8    M_v8    C_v8  R_e 1 2 (S)_v9  \
# ind_dataset   ood_dataset
# cifar10       cifar100             0.9145  0.9122  0.9116          0.9024
#               svhn                 0.9585  0.9343  0.9558          0.9421
#               tiny_imagenet        0.9087  0.9103  0.9040          0.8931
# cifar100      cifar10              0.7734  0.5348  0.7725          0.7216
#               svhn                 0.8610  0.6788  0.8512          0.7312
#               tiny_imagenet        0.8063  0.6229  0.9967          0.9944
# tiny_imagenet imagenet_a           0.8301  0.4410  0.8332          0.7319
#               imagenet_o           0.7226  0.5127  0.7426          0.7236
#               imagenet_r           0.8192  0.4048  0.8236          0.7308
#
# measure                      R_t 1 2 (S)_v9  R_b 1 (S)_v9    M_v9    C_v9  \
# ind_dataset   ood_dataset
# cifar10       cifar100               0.9130        0.9145  0.9122  0.9126
#               svhn                   0.9577        0.9585  0.9343  0.9570
#               tiny_imagenet          0.9058        0.9087  0.9103  0.9052
# cifar100      cifar10                0.7744        0.7734  0.5348  0.7722
#               svhn                   0.8567        0.8610  0.6788  0.8484
#               tiny_imagenet          0.9371        0.8063  0.6229  0.9989
# tiny_imagenet imagenet_a             0.8345        0.8301  0.4410  0.8329
#               imagenet_o             0.7358        0.7226  0.5127  0.7429
#               imagenet_r             0.8241        0.8192  0.4048  0.8231
#
# measure                      R_e 1 3 (S)_v10  R_t 1 3 (S)_v10  R_b 1 (S)_v10  \
# ind_dataset   ood_dataset
# cifar10       cifar100                0.9040           0.9126         0.9145
#               svhn                    0.9418           0.9571         0.9585
#               tiny_imagenet           0.8944           0.9052         0.9087
# cifar100      cifar10                 0.7147           0.7740         0.7734
#               svhn                    0.7186           0.8546         0.8610
#               tiny_imagenet           0.9895           0.9793         0.8063
# tiny_imagenet imagenet_a              0.7154           0.8354         0.8301
#               imagenet_o              0.7189           0.7406         0.7226
#               imagenet_r              0.7163           0.8254         0.8192
#
# measure                       M_v10   C_v10
# ind_dataset   ood_dataset
# cifar10       cifar100       0.9122  0.9124
#               svhn           0.9343  0.9567
#               tiny_imagenet  0.9103  0.9049
# cifar100      cifar10        0.5348  0.7717
#               svhn           0.6788  0.8475
#               tiny_imagenet  0.6229  0.9998
# tiny_imagenet imagenet_a     0.4410  0.8333
#               imagenet_o     0.5127  0.7457
#               imagenet_r     0.4048  0.8238
# 2. MISCLASSIFICATION DETECTION TABLE
# --------------------------------------------------
# Shape: (3, 52)
#
# DataFrame:
# measure                      R_b 1 (L)_v1  R_b 1 (B)_v1  R_b 1 (S)_v1  \
# ind_dataset   eval_dataset
# cifar10       cifar10              0.9423        0.9425        0.9422
# cifar100      cifar100             0.8451        0.8578        0.8562
# tiny_imagenet tiny_imagenet        0.8447        0.8547        0.8532
#
# measure                      R_b 1 (Z)_v1    C_v1  R_b 1 (L)_v2  R_b 1 (B)_v2  \
# ind_dataset   eval_dataset
# cifar10       cifar10              0.9418  0.9423        0.9423        0.9425
# cifar100      cifar100             0.8590  0.8527        0.8451        0.8578
# tiny_imagenet tiny_imagenet        0.8547  0.8506        0.8447        0.8547
#
# measure                      R_b 1 (S)_v2  R_b 1 (Z)_v2    M_v2    C_v2  \
# ind_dataset   eval_dataset
# cifar10       cifar10              0.9422        0.9418  0.9276  0.9420
# cifar100      cifar100             0.8562        0.8590  0.5739  0.8527
# tiny_imagenet tiny_imagenet        0.8532        0.8547  0.4168  0.8511
#
# measure                      R_e 1 2 (L)_v3  R_e 1 2 (B)_v3  R_e 1 2 (S)_v3  \
# ind_dataset   eval_dataset
# cifar10       cifar10                0.9416          0.9424          0.9419
# cifar100      cifar100               0.8315          0.7826          0.8372
# tiny_imagenet tiny_imagenet          0.8315          0.7542          0.8188
#
# measure                      R_e 1 2 (Z)_v3    C_v3  R_e 1 2 (L)_v4  \
# ind_dataset   eval_dataset
# cifar10       cifar10                0.7967  0.9426          0.9416
# cifar100      cifar100               0.8063  0.8289          0.8315
# tiny_imagenet tiny_imagenet          0.8008  0.8192          0.8315
#
# measure                      R_e 1 2 (B)_v4  R_e 1 2 (S)_v4  R_e 1 2 (Z)_v4  \
# ind_dataset   eval_dataset
# cifar10       cifar10                0.9424          0.9419          0.7967
# cifar100      cifar100               0.7826          0.8372          0.8063
# tiny_imagenet tiny_imagenet          0.7542          0.8188          0.8008
#
# measure                        M_v4    C_v4  R_e 1 1 (L)_v5  R_t 1 1 (L)_v5  \
# ind_dataset   eval_dataset
# cifar10       cifar10        0.9276  0.9418          0.9404          0.9432
# cifar100      cifar100       0.5739  0.8034          0.8180          0.8531
# tiny_imagenet tiny_imagenet  0.4168  0.7946          0.8131          0.8508
#
# measure                      R_b 1 (L)_v5    M_v5    C_v5  R_e 1 2 (L)_v6  \
# ind_dataset   eval_dataset
# cifar10       cifar10              0.9423  0.9276  0.9439          0.9416
# cifar100      cifar100             0.8451  0.5739  0.8489          0.8315
# tiny_imagenet tiny_imagenet        0.8447  0.4168  0.8466          0.8315
#
# measure                      R_t 1 2 (L)_v6  R_b 1 (L)_v6    M_v6    C_v6  \
# ind_dataset   eval_dataset
# cifar10       cifar10                0.9449        0.9423  0.9276  0.9441
# cifar100      cifar100               0.8501        0.8451  0.5739  0.8502
# tiny_imagenet tiny_imagenet          0.8497        0.8447  0.4168  0.8493
#
# measure                      R_e 1 3 (L)_v7  R_t 1 3 (L)_v7  R_b 1 (L)_v7  \
# ind_dataset   eval_dataset
# cifar10       cifar10                0.9365          0.9422        0.9423
# cifar100      cifar100               0.8042          0.8488        0.8451
# tiny_imagenet tiny_imagenet          0.7908          0.8465        0.8447
#
# measure                        M_v7    C_v7  R_e 1 1 (S)_v8  R_t 1 1 (S)_v8  \
# ind_dataset   eval_dataset
# cifar10       cifar10        0.9276  0.9420          0.9431          0.9452
# cifar100      cifar100       0.5739  0.8457          0.8298          0.8679
# tiny_imagenet tiny_imagenet  0.4168  0.8419          0.8086          0.8647
#
# measure                      R_b 1 (S)_v8    M_v8    C_v8  R_e 1 2 (S)_v9  \
# ind_dataset   eval_dataset
# cifar10       cifar10              0.9422  0.9276  0.9452          0.9419
# cifar100      cifar100             0.8562  0.5739  0.8677          0.8372
# tiny_imagenet tiny_imagenet        0.8532  0.4168  0.8643          0.8188
#
# measure                      R_t 1 2 (S)_v9  R_b 1 (S)_v9    M_v9    C_v9  \
# ind_dataset   eval_dataset
# cifar10       cifar10                0.9458        0.9422  0.9276  0.9457
# cifar100      cifar100               0.8656        0.8562  0.5739  0.8691
# tiny_imagenet tiny_imagenet          0.8634        0.8532  0.4168  0.8657
#
# measure                      R_e 1 3 (S)_v10  R_t 1 3 (S)_v10  R_b 1 (S)_v10  \
# ind_dataset   eval_dataset
# cifar10       cifar10                 0.9424           0.9456         0.9422
# cifar100      cifar100                0.8274           0.8671         0.8562
# tiny_imagenet tiny_imagenet           0.8052           0.8645         0.8532
#
# measure                       M_v10   C_v10
# ind_dataset   eval_dataset
# cifar10       cifar10        0.9276  0.9456
# cifar100      cifar100       0.5739  0.8685
# tiny_imagenet tiny_imagenet  0.4168  0.8647
# 3. SELECTIVE PREDICTION TABLE
# ----------------------------------------
# Shape: (3, 52)
#
# DataFrame:
# measure                      R_b 1 (L)_v1  R_b 1 (B)_v1  R_b 1 (S)_v1  \
# ind_dataset   eval_dataset
# cifar10       cifar10              0.9968        0.9968        0.9968
# cifar100      cifar100             0.9159        0.9202        0.9197
# tiny_imagenet tiny_imagenet        0.8889        0.8927        0.8921
#
# measure                      R_b 1 (Z)_v1    C_v1  R_b 1 (L)_v2  R_b 1 (B)_v2  \
# ind_dataset   eval_dataset
# cifar10       cifar10              0.9968  0.9968        0.9968        0.9968
# cifar100      cifar100             0.9206  0.9186        0.9159        0.9202
# tiny_imagenet tiny_imagenet        0.8926  0.8912        0.8889        0.8927
#
# measure                      R_b 1 (S)_v2  R_b 1 (Z)_v2    M_v2    C_v2  \
# ind_dataset   eval_dataset
# cifar10       cifar10              0.9968        0.9968  0.9963  0.9969
# cifar100      cifar100             0.9197        0.9206  0.8106  0.9173
# tiny_imagenet tiny_imagenet        0.8921        0.8926  0.6598  0.8890
#
# measure                      R_e 1 2 (L)_v3  R_e 1 2 (B)_v3  R_e 1 2 (S)_v3  \
# ind_dataset   eval_dataset
# cifar10       cifar10                0.9969          0.9969          0.9967
# cifar100      cifar100               0.9133          0.9000          0.9162
# tiny_imagenet tiny_imagenet          0.8853          0.8600          0.8825
#
# measure                      R_e 1 2 (Z)_v3    C_v3  R_e 1 2 (L)_v4  \
# ind_dataset   eval_dataset
# cifar10       cifar10                0.9828  0.9969          0.9969
# cifar100      cifar100               0.8789  0.9130          0.9133
# tiny_imagenet tiny_imagenet          0.8528  0.8820          0.8853
#
# measure                      R_e 1 2 (B)_v4  R_e 1 2 (S)_v4  R_e 1 2 (Z)_v4  \
# ind_dataset   eval_dataset
# cifar10       cifar10                0.9969          0.9967          0.9828
# cifar100      cifar100               0.9000          0.9162          0.8789
# tiny_imagenet tiny_imagenet          0.8600          0.8825          0.8528
#
# measure                        M_v4    C_v4  R_e 1 1 (L)_v5  R_t 1 1 (L)_v5  \
# ind_dataset   eval_dataset
# cifar10       cifar10        0.9963  0.9968          0.9968          0.9969
# cifar100      cifar100       0.8106  0.9013          0.9097          0.9184
# tiny_imagenet tiny_imagenet  0.6598  0.8666          0.8792          0.8909
#
# measure                      R_b 1 (L)_v5    M_v5    C_v5  R_e 1 2 (L)_v6  \
# ind_dataset   eval_dataset
# cifar10       cifar10              0.9968  0.9963  0.9969          0.9969
# cifar100      cifar100             0.9159  0.8106  0.9154          0.9133
# tiny_imagenet tiny_imagenet        0.8889  0.6598  0.8863          0.8853
#
# measure                      R_t 1 2 (L)_v6  R_b 1 (L)_v6    M_v6    C_v6  \
# ind_dataset   eval_dataset
# cifar10       cifar10                0.9969        0.9968  0.9963  0.9969
# cifar100      cifar100               0.9175        0.9159  0.8106  0.9158
# tiny_imagenet tiny_imagenet          0.8907        0.8889  0.6598  0.8874
#
# measure                      R_e 1 3 (L)_v7  R_t 1 3 (L)_v7  R_b 1 (L)_v7  \
# ind_dataset   eval_dataset
# cifar10       cifar10                0.9967          0.9968        0.9968
# cifar100      cifar100               0.9056          0.9171        0.9159
# tiny_imagenet tiny_imagenet          0.8717          0.8893        0.8889
#
# measure                        M_v7    C_v7  R_e 1 1 (S)_v8  R_t 1 1 (S)_v8  \
# ind_dataset   eval_dataset
# cifar10       cifar10        0.9963  0.9969          0.9969          0.9969
# cifar100      cifar100       0.8106  0.9144          0.9141          0.9231
# tiny_imagenet tiny_imagenet  0.6598  0.8846          0.8793          0.8961
#
# measure                      R_b 1 (S)_v8    M_v8    C_v8  R_e 1 2 (S)_v9  \
# ind_dataset   eval_dataset
# cifar10       cifar10              0.9968  0.9963  0.9969          0.9967
# cifar100      cifar100             0.9197  0.8106  0.9231          0.9162
# tiny_imagenet tiny_imagenet        0.8921  0.6598  0.8959          0.8825
#
# measure                      R_t 1 2 (S)_v9  R_b 1 (S)_v9    M_v9    C_v9  \
# ind_dataset   eval_dataset
# cifar10       cifar10                0.9970        0.9968  0.9963  0.9970
# cifar100      cifar100               0.9225        0.9197  0.8106  0.9234
# tiny_imagenet tiny_imagenet          0.8957        0.8921  0.6598  0.8964
#
# measure                      R_e 1 3 (S)_v10  R_t 1 3 (S)_v10  R_b 1 (S)_v10  \
# ind_dataset   eval_dataset
# cifar10       cifar10                 0.9968           0.9970         0.9968
# cifar100      cifar100                0.9135           0.9229         0.9197
# tiny_imagenet tiny_imagenet           0.8779           0.8960         0.8921
#
# measure                       M_v10   C_v10
# ind_dataset   eval_dataset
# cifar10       cifar10        0.9963  0.9970
# cifar100      cifar100       0.8106  0.9233
# tiny_imagenet tiny_imagenet  0.6598  0.8961

# %% [markdown]
# ## Results Structure
#
# The analysis returns:
# 1. **`final_tables`**: Combined tables for each problem type with the requested format
# 2. **`individual_results`**: Detailed results for each configuration
# 3. **`config_list`**: The original configuration list
#
# ### Final Table Format
# Each final table has:
# - **Index**: `(ind_dataset_clean, ood_dataset)` - the in-distribution and out-of-distribution dataset names
# - **Columns**: Individual measures and composite measures, labeled by configuration

# %%
# Debug: Check individual configuration results and their sizes
print("INDIVIDUAL CONFIGURATION RESULTS - DEBUG")
print("=" * 60)

for i, individual_result in enumerate(results['individual_results']):
    config = individual_result['config']
    tables = individual_result['tables']
    transformed_df = individual_result['transformed_df']
    
    print(f"\nConfiguration {i+1}: {config['composite_name']}")
    print(f"Parameters: eps={config['eps']}, grid_size={config['grid_size']}, target={config['target']}")
    print(f"Original transformed_df shape: {transformed_df.shape}")
    print(f"Transformed_df index levels: {transformed_df.index.names}")
    print(f"Sample index values: {transformed_df.index[:5]}")
    
    for problem_type, table in tables.items():
        if not table.empty:
            print(f"\n{problem_type.replace('_', ' ').title()} - Shape: {table.shape}")
            print(f"Index: {table.index[:3]}")
            # Show first few rows
            display(table.head(3).round(4))
        else:
            print(f"\n{problem_type.replace('_', ' ').title()}: No data")
# Out:
# INDIVIDUAL CONFIGURATION RESULTS - DEBUG
# ============================================================
#
# Configuration 1: COMPOSITE BAYES ALL OUTER
# Parameters: eps=0.5, grid_size=5, target=exp
# Original transformed_df shape: (15, 141)
# Transformed_df index levels: ['ind_dataset', 'eval']
# Sample index values: MultiIndex([('cifar10',    'cifar10 [miscls]'),
#             ('cifar10', 'cifar10 [selective]'),
#             ('cifar10',      'cifar100 [ood]'),
#             ('cifar10',          'svhn [ood]'),
#             ('cifar10', 'tiny_imagenet [ood]')],
#            names=['ind_dataset', 'eval'])
#
# Ood Detection - Shape: (9, 5)
# Index: MultiIndex([('cifar10',      'cifar100 [ood]'),
#             ('cifar10',          'svhn [ood]'),
#             ('cifar10', 'tiny_imagenet [ood]')],
#            names=['ind_dataset', 'eval'])
# measure                          R_b 1 (L)  R_b 1 (B)  R_b 1 (S)  R_b 1 (Z)  \
# ind_dataset eval
# cifar10     cifar100 [ood]          0.9169     0.9144     0.9145     0.9132
#             svhn [ood]              0.9630     0.9584     0.9585     0.9563
#             tiny_imagenet [ood]     0.9114     0.9086     0.9087     0.9072
#
# measure                               C
# ind_dataset eval
# cifar10     cifar100 [ood]       0.9158
#             svhn [ood]           0.9610
#             tiny_imagenet [ood]  0.9101
# Misclassification Detection - Shape: (3, 5)
# Index: MultiIndex([(      'cifar10',       'cifar10 [miscls]'),
#             (     'cifar100',      'cifar100 [miscls]'),
#             ('tiny_imagenet', 'tiny_imagenet [miscls]')],
#            names=['ind_dataset', 'eval'])
# measure                               R_b 1 (L)  R_b 1 (B)  R_b 1 (S)  \
# ind_dataset   eval
# cifar10       cifar10 [miscls]           0.9423     0.9425     0.9422
# cifar100      cifar100 [miscls]          0.8451     0.8578     0.8562
# tiny_imagenet tiny_imagenet [miscls]     0.8447     0.8547     0.8532
#
# measure                               R_b 1 (Z)       C
# ind_dataset   eval
# cifar10       cifar10 [miscls]           0.9418  0.9423
# cifar100      cifar100 [miscls]          0.8590  0.8527
# tiny_imagenet tiny_imagenet [miscls]     0.8547  0.8506
# Selective Prediction - Shape: (3, 5)
# Index: MultiIndex([(      'cifar10',       'cifar10 [selective]'),
#             (     'cifar100',      'cifar100 [selective]'),
#             ('tiny_imagenet', 'tiny_imagenet [selective]')],
#            names=['ind_dataset', 'eval'])
# measure                                  R_b 1 (L)  R_b 1 (B)  R_b 1 (S)  \
# ind_dataset   eval
# cifar10       cifar10 [selective]           0.9968     0.9968     0.9968
# cifar100      cifar100 [selective]          0.9159     0.9202     0.9197
# tiny_imagenet tiny_imagenet [selective]     0.8889     0.8927     0.8921
#
# measure                                  R_b 1 (Z)       C
# ind_dataset   eval
# cifar10       cifar10 [selective]           0.9968  0.9968
# cifar100      cifar100 [selective]          0.9206  0.9186
# tiny_imagenet tiny_imagenet [selective]     0.8926  0.8912
# Configuration 2: COMPOSITE BAYES ALL OUTER + M
# Parameters: eps=0.5, grid_size=5, target=beta
# Original transformed_df shape: (15, 145)
# Transformed_df index levels: ['ind_dataset', 'eval']
# Sample index values: MultiIndex([('cifar10',    'cifar10 [miscls]'),
#             ('cifar10', 'cifar10 [selective]'),
#             ('cifar10',      'cifar100 [ood]'),
#             ('cifar10',          'svhn [ood]'),
#             ('cifar10', 'tiny_imagenet [ood]')],
#            names=['ind_dataset', 'eval'])
#
# Ood Detection - Shape: (9, 6)
# Index: MultiIndex([('cifar10',      'cifar100 [ood]'),
#             ('cifar10',          'svhn [ood]'),
#             ('cifar10', 'tiny_imagenet [ood]')],
#            names=['ind_dataset', 'eval'])
# measure                          R_b 1 (L)  R_b 1 (B)  R_b 1 (S)  R_b 1 (Z)  \
# ind_dataset eval
# cifar10     cifar100 [ood]          0.9169     0.9144     0.9145     0.9132
#             svhn [ood]              0.9630     0.9584     0.9585     0.9563
#             tiny_imagenet [ood]     0.9114     0.9086     0.9087     0.9072
#
# measure                               M       C
# ind_dataset eval
# cifar10     cifar100 [ood]       0.9122  0.9185
#             svhn [ood]           0.9343  0.9572
#             tiny_imagenet [ood]  0.9103  0.9140
# Misclassification Detection - Shape: (3, 6)
# Index: MultiIndex([(      'cifar10',       'cifar10 [miscls]'),
#             (     'cifar100',      'cifar100 [miscls]'),
#             ('tiny_imagenet', 'tiny_imagenet [miscls]')],
#            names=['ind_dataset', 'eval'])
# measure                               R_b 1 (L)  R_b 1 (B)  R_b 1 (S)  \
# ind_dataset   eval
# cifar10       cifar10 [miscls]           0.9423     0.9425     0.9422
# cifar100      cifar100 [miscls]          0.8451     0.8578     0.8562
# tiny_imagenet tiny_imagenet [miscls]     0.8447     0.8547     0.8532
#
# measure                               R_b 1 (Z)       M       C
# ind_dataset   eval
# cifar10       cifar10 [miscls]           0.9418  0.9276  0.9420
# cifar100      cifar100 [miscls]          0.8590  0.5739  0.8527
# tiny_imagenet tiny_imagenet [miscls]     0.8547  0.4168  0.8511
# Selective Prediction - Shape: (3, 6)
# Index: MultiIndex([(      'cifar10',       'cifar10 [selective]'),
#             (     'cifar100',      'cifar100 [selective]'),
#             ('tiny_imagenet', 'tiny_imagenet [selective]')],
#            names=['ind_dataset', 'eval'])
# measure                                  R_b 1 (L)  R_b 1 (B)  R_b 1 (S)  \
# ind_dataset   eval
# cifar10       cifar10 [selective]           0.9968     0.9968     0.9968
# cifar100      cifar100 [selective]          0.9159     0.9202     0.9197
# tiny_imagenet tiny_imagenet [selective]     0.8889     0.8927     0.8921
#
# measure                                  R_b 1 (Z)       M       C
# ind_dataset   eval
# cifar10       cifar10 [selective]           0.9968  0.9963  0.9969
# cifar100      cifar100 [selective]          0.9206  0.8106  0.9173
# tiny_imagenet tiny_imagenet [selective]     0.8926  0.6598  0.8890
# Configuration 3: COMPOSITE EXCESS ALL OUTER INNER
# Parameters: eps=0.5, grid_size=5, target=exp
# Original transformed_df shape: (15, 141)
# Transformed_df index levels: ['ind_dataset', 'eval']
# Sample index values: MultiIndex([('cifar10',    'cifar10 [miscls]'),
#             ('cifar10', 'cifar10 [selective]'),
#             ('cifar10',      'cifar100 [ood]'),
#             ('cifar10',          'svhn [ood]'),
#             ('cifar10', 'tiny_imagenet [ood]')],
#            names=['ind_dataset', 'eval'])
#
# Ood Detection - Shape: (9, 5)
# Index: MultiIndex([('cifar10',      'cifar100 [ood]'),
#             ('cifar10',          'svhn [ood]'),
#             ('cifar10', 'tiny_imagenet [ood]')],
#            names=['ind_dataset', 'eval'])
# measure                          R_e 1 2 (L)  R_e 1 2 (B)  R_e 1 2 (S)  \
# ind_dataset eval
# cifar10     cifar100 [ood]            0.9072       0.9023       0.9024
#             svhn [ood]                0.9458       0.9402       0.9421
#             tiny_imagenet [ood]       0.8987       0.8932       0.8931
#
# measure                          R_e 1 2 (Z)       C
# ind_dataset eval
# cifar10     cifar100 [ood]            0.7546  0.9059
#             svhn [ood]                0.8246  0.9440
#             tiny_imagenet [ood]       0.7524  0.8972
# Misclassification Detection - Shape: (3, 5)
# Index: MultiIndex([(      'cifar10',       'cifar10 [miscls]'),
#             (     'cifar100',      'cifar100 [miscls]'),
#             ('tiny_imagenet', 'tiny_imagenet [miscls]')],
#            names=['ind_dataset', 'eval'])
# measure                               R_e 1 2 (L)  R_e 1 2 (B)  R_e 1 2 (S)  \
# ind_dataset   eval
# cifar10       cifar10 [miscls]             0.9416       0.9424       0.9419
# cifar100      cifar100 [miscls]            0.8315       0.7826       0.8372
# tiny_imagenet tiny_imagenet [miscls]       0.8315       0.7542       0.8188
#
# measure                               R_e 1 2 (Z)       C
# ind_dataset   eval
# cifar10       cifar10 [miscls]             0.7967  0.9426
# cifar100      cifar100 [miscls]            0.8063  0.8289
# tiny_imagenet tiny_imagenet [miscls]       0.8008  0.8192
# Selective Prediction - Shape: (3, 5)
# Index: MultiIndex([(      'cifar10',       'cifar10 [selective]'),
#             (     'cifar100',      'cifar100 [selective]'),
#             ('tiny_imagenet', 'tiny_imagenet [selective]')],
#            names=['ind_dataset', 'eval'])
# measure                                  R_e 1 2 (L)  R_e 1 2 (B)  \
# ind_dataset   eval
# cifar10       cifar10 [selective]             0.9969       0.9969
# cifar100      cifar100 [selective]            0.9133       0.9000
# tiny_imagenet tiny_imagenet [selective]       0.8853       0.8600
#
# measure                                  R_e 1 2 (S)  R_e 1 2 (Z)       C
# ind_dataset   eval
# cifar10       cifar10 [selective]             0.9967       0.9828  0.9969
# cifar100      cifar100 [selective]            0.9162       0.8789  0.9130
# tiny_imagenet tiny_imagenet [selective]       0.8825       0.8528  0.8820
# Configuration 4: COMPOSITE EXCESS ALL OUTER INNER + M
# Parameters: eps=0.5, grid_size=5, target=exp
# Original transformed_df shape: (15, 145)
# Transformed_df index levels: ['ind_dataset', 'eval']
# Sample index values: MultiIndex([('cifar10',    'cifar10 [miscls]'),
#             ('cifar10', 'cifar10 [selective]'),
#             ('cifar10',      'cifar100 [ood]'),
#             ('cifar10',          'svhn [ood]'),
#             ('cifar10', 'tiny_imagenet [ood]')],
#            names=['ind_dataset', 'eval'])
#
# Ood Detection - Shape: (9, 6)
# Index: MultiIndex([('cifar10',      'cifar100 [ood]'),
#             ('cifar10',          'svhn [ood]'),
#             ('cifar10', 'tiny_imagenet [ood]')],
#            names=['ind_dataset', 'eval'])
# measure                          R_e 1 2 (L)  R_e 1 2 (B)  R_e 1 2 (S)  \
# ind_dataset eval
# cifar10     cifar100 [ood]            0.9072       0.9023       0.9024
#             svhn [ood]                0.9458       0.9402       0.9421
#             tiny_imagenet [ood]       0.8987       0.8932       0.8931
#
# measure                          R_e 1 2 (Z)       M       C
# ind_dataset eval
# cifar10     cifar100 [ood]            0.7546  0.9122  0.9103
#             svhn [ood]                0.8246  0.9343  0.9423
#             tiny_imagenet [ood]       0.7524  0.9103  0.9042
# Misclassification Detection - Shape: (3, 6)
# Index: MultiIndex([(      'cifar10',       'cifar10 [miscls]'),
#             (     'cifar100',      'cifar100 [miscls]'),
#             ('tiny_imagenet', 'tiny_imagenet [miscls]')],
#            names=['ind_dataset', 'eval'])
# measure                               R_e 1 2 (L)  R_e 1 2 (B)  R_e 1 2 (S)  \
# ind_dataset   eval
# cifar10       cifar10 [miscls]             0.9416       0.9424       0.9419
# cifar100      cifar100 [miscls]            0.8315       0.7826       0.8372
# tiny_imagenet tiny_imagenet [miscls]       0.8315       0.7542       0.8188
#
# measure                               R_e 1 2 (Z)       M       C
# ind_dataset   eval
# cifar10       cifar10 [miscls]             0.7967  0.9276  0.9418
# cifar100      cifar100 [miscls]            0.8063  0.5739  0.8034
# tiny_imagenet tiny_imagenet [miscls]       0.8008  0.4168  0.7946
# Selective Prediction - Shape: (3, 6)
# Index: MultiIndex([(      'cifar10',       'cifar10 [selective]'),
#             (     'cifar100',      'cifar100 [selective]'),
#             ('tiny_imagenet', 'tiny_imagenet [selective]')],
#            names=['ind_dataset', 'eval'])
# measure                                  R_e 1 2 (L)  R_e 1 2 (B)  \
# ind_dataset   eval
# cifar10       cifar10 [selective]             0.9969       0.9969
# cifar100      cifar100 [selective]            0.9133       0.9000
# tiny_imagenet tiny_imagenet [selective]       0.8853       0.8600
#
# measure                                  R_e 1 2 (S)  R_e 1 2 (Z)       M  \
# ind_dataset   eval
# cifar10       cifar10 [selective]             0.9967       0.9828  0.9963
# cifar100      cifar100 [selective]            0.9162       0.8789  0.8106
# tiny_imagenet tiny_imagenet [selective]       0.8825       0.8528  0.6598
#
# measure                                       C
# ind_dataset   eval
# cifar10       cifar10 [selective]        0.9968
# cifar100      cifar100 [selective]       0.9013
# tiny_imagenet tiny_imagenet [selective]  0.8666
# Configuration 5: COMPOSITE EAT LOGSCORE OUTER OUTER + M
# Parameters: eps=0.5, grid_size=5, target=beta
# Original transformed_df shape: (15, 145)
# Transformed_df index levels: ['ind_dataset', 'eval']
# Sample index values: MultiIndex([('cifar10',    'cifar10 [miscls]'),
#             ('cifar10', 'cifar10 [selective]'),
#             ('cifar10',      'cifar100 [ood]'),
#             ('cifar10',          'svhn [ood]'),
#             ('cifar10', 'tiny_imagenet [ood]')],
#            names=['ind_dataset', 'eval'])
#
# Ood Detection - Shape: (9, 5)
# Index: MultiIndex([('cifar10',      'cifar100 [ood]'),
#             ('cifar10',          'svhn [ood]'),
#             ('cifar10', 'tiny_imagenet [ood]')],
#            names=['ind_dataset', 'eval'])
# measure                          R_e 1 1 (L)  R_t 1 1 (L)  R_b 1 (L)       M  \
# ind_dataset eval
# cifar10     cifar100 [ood]            0.9047       0.9115     0.9169  0.9122
#             svhn [ood]                0.9426       0.9565     0.9630  0.9343
#             tiny_imagenet [ood]       0.8957       0.9036     0.9114  0.9103
#
# measure                               C
# ind_dataset eval
# cifar10     cifar100 [ood]       0.9181
#             svhn [ood]           0.9573
#             tiny_imagenet [ood]  0.9123
# Misclassification Detection - Shape: (3, 5)
# Index: MultiIndex([(      'cifar10',       'cifar10 [miscls]'),
#             (     'cifar100',      'cifar100 [miscls]'),
#             ('tiny_imagenet', 'tiny_imagenet [miscls]')],
#            names=['ind_dataset', 'eval'])
# measure                               R_e 1 1 (L)  R_t 1 1 (L)  R_b 1 (L)  \
# ind_dataset   eval
# cifar10       cifar10 [miscls]             0.9404       0.9432     0.9423
# cifar100      cifar100 [miscls]            0.8180       0.8531     0.8451
# tiny_imagenet tiny_imagenet [miscls]       0.8131       0.8508     0.8447
#
# measure                                    M       C
# ind_dataset   eval
# cifar10       cifar10 [miscls]        0.9276  0.9439
# cifar100      cifar100 [miscls]       0.5739  0.8489
# tiny_imagenet tiny_imagenet [miscls]  0.4168  0.8466
# Selective Prediction - Shape: (3, 5)
# Index: MultiIndex([(      'cifar10',       'cifar10 [selective]'),
#             (     'cifar100',      'cifar100 [selective]'),
#             ('tiny_imagenet', 'tiny_imagenet [selective]')],
#            names=['ind_dataset', 'eval'])
# measure                                  R_e 1 1 (L)  R_t 1 1 (L)  R_b 1 (L)  \
# ind_dataset   eval
# cifar10       cifar10 [selective]             0.9968       0.9969     0.9968
# cifar100      cifar100 [selective]            0.9097       0.9184     0.9159
# tiny_imagenet tiny_imagenet [selective]       0.8792       0.8909     0.8889
#
# measure                                       M       C
# ind_dataset   eval
# cifar10       cifar10 [selective]        0.9963  0.9969
# cifar100      cifar100 [selective]       0.8106  0.9154
# tiny_imagenet tiny_imagenet [selective]  0.6598  0.8863
# Configuration 6: COMPOSITE EAT LOGSCORE OUTER INNER + M
# Parameters: eps=0.5, grid_size=5, target=beta
# Original transformed_df shape: (15, 145)
# Transformed_df index levels: ['ind_dataset', 'eval']
# Sample index values: MultiIndex([('cifar10',    'cifar10 [miscls]'),
#             ('cifar10', 'cifar10 [selective]'),
#             ('cifar10',      'cifar100 [ood]'),
#             ('cifar10',          'svhn [ood]'),
#             ('cifar10', 'tiny_imagenet [ood]')],
#            names=['ind_dataset', 'eval'])
#
# Ood Detection - Shape: (9, 5)
# Index: MultiIndex([('cifar10',      'cifar100 [ood]'),
#             ('cifar10',          'svhn [ood]'),
#             ('cifar10', 'tiny_imagenet [ood]')],
#            names=['ind_dataset', 'eval'])
# measure                          R_e 1 2 (L)  R_t 1 2 (L)  R_b 1 (L)       M  \
# ind_dataset eval
# cifar10     cifar100 [ood]            0.9072       0.9162     0.9169  0.9122
#             svhn [ood]                0.9458       0.9631     0.9630  0.9343
#             tiny_imagenet [ood]       0.8987       0.9095     0.9114  0.9103
#
# measure                               C
# ind_dataset eval
# cifar10     cifar100 [ood]       0.9194
#             svhn [ood]           0.9591
#             tiny_imagenet [ood]  0.9141
# Misclassification Detection - Shape: (3, 5)
# Index: MultiIndex([(      'cifar10',       'cifar10 [miscls]'),
#             (     'cifar100',      'cifar100 [miscls]'),
#             ('tiny_imagenet', 'tiny_imagenet [miscls]')],
#            names=['ind_dataset', 'eval'])
# measure                               R_e 1 2 (L)  R_t 1 2 (L)  R_b 1 (L)  \
# ind_dataset   eval
# cifar10       cifar10 [miscls]             0.9416       0.9449     0.9423
# cifar100      cifar100 [miscls]            0.8315       0.8501     0.8451
# tiny_imagenet tiny_imagenet [miscls]       0.8315       0.8497     0.8447
#
# measure                                    M       C
# ind_dataset   eval
# cifar10       cifar10 [miscls]        0.9276  0.9441
# cifar100      cifar100 [miscls]       0.5739  0.8502
# tiny_imagenet tiny_imagenet [miscls]  0.4168  0.8493
# Selective Prediction - Shape: (3, 5)
# Index: MultiIndex([(      'cifar10',       'cifar10 [selective]'),
#             (     'cifar100',      'cifar100 [selective]'),
#             ('tiny_imagenet', 'tiny_imagenet [selective]')],
#            names=['ind_dataset', 'eval'])
# measure                                  R_e 1 2 (L)  R_t 1 2 (L)  R_b 1 (L)  \
# ind_dataset   eval
# cifar10       cifar10 [selective]             0.9969       0.9969     0.9968
# cifar100      cifar100 [selective]            0.9133       0.9175     0.9159
# tiny_imagenet tiny_imagenet [selective]       0.8853       0.8907     0.8889
#
# measure                                       M       C
# ind_dataset   eval
# cifar10       cifar10 [selective]        0.9963  0.9969
# cifar100      cifar100 [selective]       0.8106  0.9158
# tiny_imagenet tiny_imagenet [selective]  0.6598  0.8874
# Configuration 7: COMPOSITE EAT LOGSCORE OUTER CENTRAL + M
# Parameters: eps=0.5, grid_size=5, target=beta
# Original transformed_df shape: (15, 145)
# Transformed_df index levels: ['ind_dataset', 'eval']
# Sample index values: MultiIndex([('cifar10',    'cifar10 [miscls]'),
#             ('cifar10', 'cifar10 [selective]'),
#             ('cifar10',      'cifar100 [ood]'),
#             ('cifar10',          'svhn [ood]'),
#             ('cifar10', 'tiny_imagenet [ood]')],
#            names=['ind_dataset', 'eval'])
#
# Ood Detection - Shape: (9, 5)
# Index: MultiIndex([('cifar10',      'cifar100 [ood]'),
#             ('cifar10',          'svhn [ood]'),
#             ('cifar10', 'tiny_imagenet [ood]')],
#            names=['ind_dataset', 'eval'])
# measure                          R_e 1 3 (L)  R_t 1 3 (L)  R_b 1 (L)       M  \
# ind_dataset eval
# cifar10     cifar100 [ood]            0.9026       0.9150     0.9169  0.9122
#             svhn [ood]                0.9397       0.9619     0.9630  0.9343
#             tiny_imagenet [ood]       0.8935       0.9079     0.9114  0.9103
#
# measure                               C
# ind_dataset eval
# cifar10     cifar100 [ood]       0.9189
#             svhn [ood]           0.9584
#             tiny_imagenet [ood]  0.9134
# Misclassification Detection - Shape: (3, 5)
# Index: MultiIndex([(      'cifar10',       'cifar10 [miscls]'),
#             (     'cifar100',      'cifar100 [miscls]'),
#             ('tiny_imagenet', 'tiny_imagenet [miscls]')],
#            names=['ind_dataset', 'eval'])
# measure                               R_e 1 3 (L)  R_t 1 3 (L)  R_b 1 (L)  \
# ind_dataset   eval
# cifar10       cifar10 [miscls]             0.9365       0.9422     0.9423
# cifar100      cifar100 [miscls]            0.8042       0.8488     0.8451
# tiny_imagenet tiny_imagenet [miscls]       0.7908       0.8465     0.8447
#
# measure                                    M       C
# ind_dataset   eval
# cifar10       cifar10 [miscls]        0.9276  0.9420
# cifar100      cifar100 [miscls]       0.5739  0.8457
# tiny_imagenet tiny_imagenet [miscls]  0.4168  0.8419
# Selective Prediction - Shape: (3, 5)
# Index: MultiIndex([(      'cifar10',       'cifar10 [selective]'),
#             (     'cifar100',      'cifar100 [selective]'),
#             ('tiny_imagenet', 'tiny_imagenet [selective]')],
#            names=['ind_dataset', 'eval'])
# measure                                  R_e 1 3 (L)  R_t 1 3 (L)  R_b 1 (L)  \
# ind_dataset   eval
# cifar10       cifar10 [selective]             0.9967       0.9968     0.9968
# cifar100      cifar100 [selective]            0.9056       0.9171     0.9159
# tiny_imagenet tiny_imagenet [selective]       0.8717       0.8893     0.8889
#
# measure                                       M       C
# ind_dataset   eval
# cifar10       cifar10 [selective]        0.9963  0.9969
# cifar100      cifar100 [selective]       0.8106  0.9144
# tiny_imagenet tiny_imagenet [selective]  0.6598  0.8846
# Configuration 8: COMPOSITE EAT SPHERICAL OUTER OUTER + M
# Parameters: eps=0.5, grid_size=5, target=exp
# Original transformed_df shape: (15, 141)
# Transformed_df index levels: ['ind_dataset', 'eval']
# Sample index values: MultiIndex([('cifar10',    'cifar10 [miscls]'),
#             ('cifar10', 'cifar10 [selective]'),
#             ('cifar10',      'cifar100 [ood]'),
#             ('cifar10',          'svhn [ood]'),
#             ('cifar10', 'tiny_imagenet [ood]')],
#            names=['ind_dataset', 'eval'])
#
# Ood Detection - Shape: (9, 5)
# Index: MultiIndex([('cifar10',      'cifar100 [ood]'),
#             ('cifar10',          'svhn [ood]'),
#             ('cifar10', 'tiny_imagenet [ood]')],
#            names=['ind_dataset', 'eval'])
# measure                          R_e 1 1 (S)  R_t 1 1 (S)  R_b 1 (S)       M  \
# ind_dataset eval
# cifar10     cifar100 [ood]            0.9044       0.9113     0.9145  0.9122
#             svhn [ood]                0.9420       0.9551     0.9585  0.9343
#             tiny_imagenet [ood]       0.8956       0.9036     0.9087  0.9103
#
# measure                               C
# ind_dataset eval
# cifar10     cifar100 [ood]       0.9116
#             svhn [ood]           0.9558
#             tiny_imagenet [ood]  0.9040
# Misclassification Detection - Shape: (3, 5)
# Index: MultiIndex([(      'cifar10',       'cifar10 [miscls]'),
#             (     'cifar100',      'cifar100 [miscls]'),
#             ('tiny_imagenet', 'tiny_imagenet [miscls]')],
#            names=['ind_dataset', 'eval'])
# measure                               R_e 1 1 (S)  R_t 1 1 (S)  R_b 1 (S)  \
# ind_dataset   eval
# cifar10       cifar10 [miscls]             0.9431       0.9452     0.9422
# cifar100      cifar100 [miscls]            0.8298       0.8679     0.8562
# tiny_imagenet tiny_imagenet [miscls]       0.8086       0.8647     0.8532
#
# measure                                    M       C
# ind_dataset   eval
# cifar10       cifar10 [miscls]        0.9276  0.9452
# cifar100      cifar100 [miscls]       0.5739  0.8677
# tiny_imagenet tiny_imagenet [miscls]  0.4168  0.8643
# Selective Prediction - Shape: (3, 5)
# Index: MultiIndex([(      'cifar10',       'cifar10 [selective]'),
#             (     'cifar100',      'cifar100 [selective]'),
#             ('tiny_imagenet', 'tiny_imagenet [selective]')],
#            names=['ind_dataset', 'eval'])
# measure                                  R_e 1 1 (S)  R_t 1 1 (S)  R_b 1 (S)  \
# ind_dataset   eval
# cifar10       cifar10 [selective]             0.9969       0.9969     0.9968
# cifar100      cifar100 [selective]            0.9141       0.9231     0.9197
# tiny_imagenet tiny_imagenet [selective]       0.8793       0.8961     0.8921
#
# measure                                       M       C
# ind_dataset   eval
# cifar10       cifar10 [selective]        0.9963  0.9969
# cifar100      cifar100 [selective]       0.8106  0.9231
# tiny_imagenet tiny_imagenet [selective]  0.6598  0.8959
# Configuration 9: COMPOSITE EAT SPHERICAL OUTER INNER + M
# Parameters: eps=0.5, grid_size=5, target=beta
# Original transformed_df shape: (15, 145)
# Transformed_df index levels: ['ind_dataset', 'eval']
# Sample index values: MultiIndex([('cifar10',    'cifar10 [miscls]'),
#             ('cifar10', 'cifar10 [selective]'),
#             ('cifar10',      'cifar100 [ood]'),
#             ('cifar10',          'svhn [ood]'),
#             ('cifar10', 'tiny_imagenet [ood]')],
#            names=['ind_dataset', 'eval'])
#
# Ood Detection - Shape: (9, 5)
# Index: MultiIndex([('cifar10',      'cifar100 [ood]'),
#             ('cifar10',          'svhn [ood]'),
#             ('cifar10', 'tiny_imagenet [ood]')],
#            names=['ind_dataset', 'eval'])
# measure                          R_e 1 2 (S)  R_t 1 2 (S)  R_b 1 (S)       M  \
# ind_dataset eval
# cifar10     cifar100 [ood]            0.9024       0.9130     0.9145  0.9122
#             svhn [ood]                0.9421       0.9577     0.9585  0.9343
#             tiny_imagenet [ood]       0.8931       0.9058     0.9087  0.9103
#
# measure                               C
# ind_dataset eval
# cifar10     cifar100 [ood]       0.9126
#             svhn [ood]           0.9570
#             tiny_imagenet [ood]  0.9052
# Misclassification Detection - Shape: (3, 5)
# Index: MultiIndex([(      'cifar10',       'cifar10 [miscls]'),
#             (     'cifar100',      'cifar100 [miscls]'),
#             ('tiny_imagenet', 'tiny_imagenet [miscls]')],
#            names=['ind_dataset', 'eval'])
# measure                               R_e 1 2 (S)  R_t 1 2 (S)  R_b 1 (S)  \
# ind_dataset   eval
# cifar10       cifar10 [miscls]             0.9419       0.9458     0.9422
# cifar100      cifar100 [miscls]            0.8372       0.8656     0.8562
# tiny_imagenet tiny_imagenet [miscls]       0.8188       0.8634     0.8532
#
# measure                                    M       C
# ind_dataset   eval
# cifar10       cifar10 [miscls]        0.9276  0.9457
# cifar100      cifar100 [miscls]       0.5739  0.8691
# tiny_imagenet tiny_imagenet [miscls]  0.4168  0.8657
# Selective Prediction - Shape: (3, 5)
# Index: MultiIndex([(      'cifar10',       'cifar10 [selective]'),
#             (     'cifar100',      'cifar100 [selective]'),
#             ('tiny_imagenet', 'tiny_imagenet [selective]')],
#            names=['ind_dataset', 'eval'])
# measure                                  R_e 1 2 (S)  R_t 1 2 (S)  R_b 1 (S)  \
# ind_dataset   eval
# cifar10       cifar10 [selective]             0.9967       0.9970     0.9968
# cifar100      cifar100 [selective]            0.9162       0.9225     0.9197
# tiny_imagenet tiny_imagenet [selective]       0.8825       0.8957     0.8921
#
# measure                                       M       C
# ind_dataset   eval
# cifar10       cifar10 [selective]        0.9963  0.9970
# cifar100      cifar100 [selective]       0.8106  0.9234
# tiny_imagenet tiny_imagenet [selective]  0.6598  0.8964
# Configuration 10: COMPOSITE EAT SPHERICAL OUTER CENTRAL + M
# Parameters: eps=0.5, grid_size=5, target=beta
# Original transformed_df shape: (15, 145)
# Transformed_df index levels: ['ind_dataset', 'eval']
# Sample index values: MultiIndex([('cifar10',    'cifar10 [miscls]'),
#             ('cifar10', 'cifar10 [selective]'),
#             ('cifar10',      'cifar100 [ood]'),
#             ('cifar10',          'svhn [ood]'),
#             ('cifar10', 'tiny_imagenet [ood]')],
#            names=['ind_dataset', 'eval'])
#
# Ood Detection - Shape: (9, 5)
# Index: MultiIndex([('cifar10',      'cifar100 [ood]'),
#             ('cifar10',          'svhn [ood]'),
#             ('cifar10', 'tiny_imagenet [ood]')],
#            names=['ind_dataset', 'eval'])
# measure                          R_e 1 3 (S)  R_t 1 3 (S)  R_b 1 (S)       M  \
# ind_dataset eval
# cifar10     cifar100 [ood]            0.9040       0.9126     0.9145  0.9122
#             svhn [ood]                0.9418       0.9571     0.9585  0.9343
#             tiny_imagenet [ood]       0.8944       0.9052     0.9087  0.9103
#
# measure                               C
# ind_dataset eval
# cifar10     cifar100 [ood]       0.9124
#             svhn [ood]           0.9567
#             tiny_imagenet [ood]  0.9049
# Misclassification Detection - Shape: (3, 5)
# Index: MultiIndex([(      'cifar10',       'cifar10 [miscls]'),
#             (     'cifar100',      'cifar100 [miscls]'),
#             ('tiny_imagenet', 'tiny_imagenet [miscls]')],
#            names=['ind_dataset', 'eval'])
# measure                               R_e 1 3 (S)  R_t 1 3 (S)  R_b 1 (S)  \
# ind_dataset   eval
# cifar10       cifar10 [miscls]             0.9424       0.9456     0.9422
# cifar100      cifar100 [miscls]            0.8274       0.8671     0.8562
# tiny_imagenet tiny_imagenet [miscls]       0.8052       0.8645     0.8532
#
# measure                                    M       C
# ind_dataset   eval
# cifar10       cifar10 [miscls]        0.9276  0.9456
# cifar100      cifar100 [miscls]       0.5739  0.8685
# tiny_imagenet tiny_imagenet [miscls]  0.4168  0.8647
# Selective Prediction - Shape: (3, 5)
# Index: MultiIndex([(      'cifar10',       'cifar10 [selective]'),
#             (     'cifar100',      'cifar100 [selective]'),
#             ('tiny_imagenet', 'tiny_imagenet [selective]')],
#            names=['ind_dataset', 'eval'])
# measure                                  R_e 1 3 (S)  R_t 1 3 (S)  R_b 1 (S)  \
# ind_dataset   eval
# cifar10       cifar10 [selective]             0.9968       0.9970     0.9968
# cifar100      cifar100 [selective]            0.9135       0.9229     0.9197
# tiny_imagenet tiny_imagenet [selective]       0.8779       0.8960     0.8921
#
# measure                                       M       C
# ind_dataset   eval
# cifar10       cifar10 [selective]        0.9963  0.9970
# cifar100      cifar100 [selective]       0.8106  0.9233
# tiny_imagenet tiny_imagenet [selective]  0.6598  0.8961

# %% [markdown]
# ## Compare Composite vs Components
#
# You can also create custom comparisons between the composite measure and its individual components:

# %%
# Column information for final tables
print("COLUMN INFORMATION FOR FINAL TABLES")
print("=" * 60)

for problem_type, final_table in results['final_tables'].items():
    if not final_table.empty:
        print(f"\n{problem_type.replace('_', ' ').title()}:")
        print(f"Shape: {final_table.shape}")
        print(f"Index: {final_table.index.names}")
        print("Columns:")
        for col in final_table.columns:
            print(f"  - {col}")
    else:
        print(f"\n{problem_type.replace('_', ' ').title()}: No data")
# Out:
# COLUMN INFORMATION FOR FINAL TABLES
# ============================================================
#
# Ood Detection:
# Shape: (9, 52)
# Index: ['ind_dataset', 'ood_dataset']
# Columns:
#   - R_b 1 (L)_v1
#   - R_b 1 (B)_v1
#   - R_b 1 (S)_v1
#   - R_b 1 (Z)_v1
#   - C_v1
#   - R_b 1 (L)_v2
#   - R_b 1 (B)_v2
#   - R_b 1 (S)_v2
#   - R_b 1 (Z)_v2
#   - M_v2
#   - C_v2
#   - R_e 1 2 (L)_v3
#   - R_e 1 2 (B)_v3
#   - R_e 1 2 (S)_v3
#   - R_e 1 2 (Z)_v3
#   - C_v3
#   - R_e 1 2 (L)_v4
#   - R_e 1 2 (B)_v4
#   - R_e 1 2 (S)_v4
#   - R_e 1 2 (Z)_v4
#   - M_v4
#   - C_v4
#   - R_e 1 1 (L)_v5
#   - R_t 1 1 (L)_v5
#   - R_b 1 (L)_v5
#   - M_v5
#   - C_v5
#   - R_e 1 2 (L)_v6
#   - R_t 1 2 (L)_v6
#   - R_b 1 (L)_v6
#   - M_v6
#   - C_v6
#   - R_e 1 3 (L)_v7
#   - R_t 1 3 (L)_v7
#   - R_b 1 (L)_v7
#   - M_v7
#   - C_v7
#   - R_e 1 1 (S)_v8
#   - R_t 1 1 (S)_v8
#   - R_b 1 (S)_v8
#   - M_v8
#   - C_v8
#   - R_e 1 2 (S)_v9
#   - R_t 1 2 (S)_v9
#   - R_b 1 (S)_v9
#   - M_v9
#   - C_v9
#   - R_e 1 3 (S)_v10
#   - R_t 1 3 (S)_v10
#   - R_b 1 (S)_v10
#   - M_v10
#   - C_v10
#
# Misclassification Detection:
# Shape: (3, 52)
# Index: ['ind_dataset', 'eval_dataset']
# Columns:
#   - R_b 1 (L)_v1
#   - R_b 1 (B)_v1
#   - R_b 1 (S)_v1
#   - R_b 1 (Z)_v1
#   - C_v1
#   - R_b 1 (L)_v2
#   - R_b 1 (B)_v2
#   - R_b 1 (S)_v2
#   - R_b 1 (Z)_v2
#   - M_v2
#   - C_v2
#   - R_e 1 2 (L)_v3
#   - R_e 1 2 (B)_v3
#   - R_e 1 2 (S)_v3
#   - R_e 1 2 (Z)_v3
#   - C_v3
#   - R_e 1 2 (L)_v4
#   - R_e 1 2 (B)_v4
#   - R_e 1 2 (S)_v4
#   - R_e 1 2 (Z)_v4
#   - M_v4
#   - C_v4
#   - R_e 1 1 (L)_v5
#   - R_t 1 1 (L)_v5
#   - R_b 1 (L)_v5
#   - M_v5
#   - C_v5
#   - R_e 1 2 (L)_v6
#   - R_t 1 2 (L)_v6
#   - R_b 1 (L)_v6
#   - M_v6
#   - C_v6
#   - R_e 1 3 (L)_v7
#   - R_t 1 3 (L)_v7
#   - R_b 1 (L)_v7
#   - M_v7
#   - C_v7
#   - R_e 1 1 (S)_v8
#   - R_t 1 1 (S)_v8
#   - R_b 1 (S)_v8
#   - M_v8
#   - C_v8
#   - R_e 1 2 (S)_v9
#   - R_t 1 2 (S)_v9
#   - R_b 1 (S)_v9
#   - M_v9
#   - C_v9
#   - R_e 1 3 (S)_v10
#   - R_t 1 3 (S)_v10
#   - R_b 1 (S)_v10
#   - M_v10
#   - C_v10
#
# Selective Prediction:
# Shape: (3, 52)
# Index: ['ind_dataset', 'eval_dataset']
# Columns:
#   - R_b 1 (L)_v1
#   - R_b 1 (B)_v1
#   - R_b 1 (S)_v1
#   - R_b 1 (Z)_v1
#   - C_v1
#   - R_b 1 (L)_v2
#   - R_b 1 (B)_v2
#   - R_b 1 (S)_v2
#   - R_b 1 (Z)_v2
#   - M_v2
#   - C_v2
#   - R_e 1 2 (L)_v3
#   - R_e 1 2 (B)_v3
#   - R_e 1 2 (S)_v3
#   - R_e 1 2 (Z)_v3
#   - C_v3
#   - R_e 1 2 (L)_v4
#   - R_e 1 2 (B)_v4
#   - R_e 1 2 (S)_v4
#   - R_e 1 2 (Z)_v4
#   - M_v4
#   - C_v4
#   - R_e 1 1 (L)_v5
#   - R_t 1 1 (L)_v5
#   - R_b 1 (L)_v5
#   - M_v5
#   - C_v5
#   - R_e 1 2 (L)_v6
#   - R_t 1 2 (L)_v6
#   - R_b 1 (L)_v6
#   - M_v6
#   - C_v6
#   - R_e 1 3 (L)_v7
#   - R_t 1 3 (L)_v7
#   - R_b 1 (L)_v7
#   - M_v7
#   - C_v7
#   - R_e 1 1 (S)_v8
#   - R_t 1 1 (S)_v8
#   - R_b 1 (S)_v8
#   - M_v8
#   - C_v8
#   - R_e 1 2 (S)_v9
#   - R_t 1 2 (S)_v9
#   - R_b 1 (S)_v9
#   - M_v9
#   - C_v9
#   - R_e 1 3 (S)_v10
#   - R_t 1 3 (S)_v10
#   - R_b 1 (S)_v10
#   - M_v10
#   - C_v10

# %%
# Export final tables to CSV (optional)
print("EXPORT OPTIONS")
print("=" * 40)

for problem_type, final_table in results['final_tables'].items():
    if not final_table.empty:
        filename = f"final_{problem_type}_table.csv"
        print(f"To export {problem_type.replace('_', ' ').title()} table:")
        print(f"  results['final_tables']['{problem_type}'].to_csv('{filename}')")
        # Uncomment to actually export:
        # final_table.to_csv(filename)
    else:
        print(f"No data to export for {problem_type.replace('_', ' ').title()}")
# Out:
# EXPORT OPTIONS
# ========================================
# To export Ood Detection table:
#   results['final_tables']['ood_detection'].to_csv('final_ood_detection_table.csv')
# To export Misclassification Detection table:
#   results['final_tables']['misclassification_detection'].to_csv('final_misclassification_detection_table.csv')
# To export Selective Prediction table:
#   results['final_tables']['selective_prediction'].to_csv('final_selective_prediction_table.csv')

# %%
def compute_pareto_depth(points: List[Tuple[float, float]], point_idx: int) -> int:
    """
    Compute Pareto depth of a point (how many layers of Pareto fronts it takes to reach this point).
    
    Args:
        points: List of (x, y) coordinate tuples
        point_idx: Index of the point to compute depth for
    
    Returns:
        Pareto depth (0 = on Pareto front, 1 = on second front, etc.)
    """
    from mdu.eval.table_analysis_utils import pareto_front
    
    remaining_points = list(enumerate(points))
    depth = 0
    
    while remaining_points:
        # Find current Pareto front
        current_points = [point for _, point in remaining_points]
        pareto_indices = pareto_front(current_points)
        
        # Check if our point is on this front
        for i, (orig_idx, _) in enumerate(remaining_points):
            if orig_idx == point_idx and i in pareto_indices:
                return depth
        
        # Remove Pareto front points and continue
        remaining_points = [item for i, item in enumerate(remaining_points) if i not in pareto_indices]
        depth += 1
    
    return depth


def analyze_composite_pareto_detailed(results: Dict) -> pd.DataFrame:
    """
    Analyze Pareto front performance for all composite measures across all configurations.
    
    Args:
        results: Results dictionary from analyze_multiple_configs
    
    Returns:
        DataFrame with composite measure, pareto count, average depth, and number of experiments
    """
    import itertools
    
    pareto_analysis = []
    
    # Get all unique composite measures
    composite_names = set()
    for individual_result in results['individual_results']:
        composite_names.add(individual_result['config']['composite_name'])
    
    for composite_name in composite_names:
        pareto_counts = []
        pareto_depths = []
        total_experiments = 0
        
        # Analyze each configuration with this composite measure
        for individual_result in results['individual_results']:
            if individual_result['config']['composite_name'] == composite_name:
                transformed_df = individual_result['transformed_df']
                
                try:
                    # Use the existing pareto analysis function
                    pareto_results = analyze_composite_pareto_performance(
                        transformed_df, {composite_name: INTERESTING_COMPOSITIONS[composite_name]}
                    )
                    
                    if composite_name in pareto_results:
                        pareto_data = pareto_results[composite_name]
                        pareto_counts.append(pareto_data['pareto_count'])
                        total_experiments += pareto_data['total_problems']
                        
                        # Calculate average pareto depth for this configuration
                        composite_df = select_composite_and_components(transformed_df, composite_name)
                        composite_cols = [c for c in composite_df.columns if c.startswith('composite')]
                        component_cols = [c for c in composite_df.columns if not c.startswith('composite')]
                        
                        if composite_cols and len(component_cols) >= 2:
                            composite_col = composite_cols[0]
                            problems = list(composite_df.index)
                            depths = []
                            
                            for problem1, problem2 in itertools.combinations(problems, 2):
                                row1 = composite_df.loc[problem1]
                                row2 = composite_df.loc[problem2]
                                
                                c1, c2 = row1[composite_col], row2[composite_col]
                                if pd.isna(c1) or pd.isna(c2):
                                    continue
                                
                                points = []
                                # Add component points
                                for col in component_cols:
                                    v1, v2 = row1[col], row2[col]
                                    if pd.notna(v1) and pd.notna(v2):
                                        points.append((v1, v2))
                                
                                # Add composite point
                                points.append((c1, c2))
                                
                                if len(points) >= 3:  # Need at least 2 components + 1 composite
                                    composite_idx = len(points) - 1
                                    depth = compute_pareto_depth(points, composite_idx)
                                    depths.append(depth)
                            
                            if depths:
                                avg_depth = sum(depths) / len(depths)
                                pareto_depths.append(avg_depth)
                
                except Exception as e:
                    print(f"Error analyzing {composite_name}: {e}")
                    continue
        
        # Aggregate results for this composite measure
        if pareto_counts:
            total_pareto_count = sum(pareto_counts)
            avg_pareto_depth = sum(pareto_depths) / len(pareto_depths) if pareto_depths else float('nan')
            
            pareto_analysis.append({
                'composite_measure': composite_name,
                'pareto_front_count': total_pareto_count,
                'avg_pareto_depth': avg_pareto_depth,
                'total_experiments': total_experiments
            })
    
    # Create DataFrame and sort by pareto front count
    pareto_df = pd.DataFrame(pareto_analysis)
    if not pareto_df.empty:
        pareto_df = pareto_df.sort_values('pareto_front_count', ascending=False)
    
    return pareto_df

# %% [markdown]
# ## Pareto Front Analysis
#
# Analyze how often each composite measure appears on the Pareto front compared to its individual components:

# %%
# Perform Pareto front analysis
print("PARETO FRONT ANALYSIS")
print("=" * 60)

pareto_results_df = analyze_composite_pareto_detailed(results)

if not pareto_results_df.empty:
    print("Composite Measure Pareto Performance:")
    print("-" * 40)
    
    # Display the results DataFrame
    display(pareto_results_df.round(3))
    
    print(f"\nSummary:")
    print(f"- Total composite measures analyzed: {len(pareto_results_df)}")
    print(f"- Best performing composite (most Pareto front appearances): {pareto_results_df.iloc[0]['composite_measure']}")
    print(f"  - Pareto front count: {pareto_results_df.iloc[0]['pareto_front_count']}")
    print(f"  - Average Pareto depth: {pareto_results_df.iloc[0]['avg_pareto_depth']:.3f}")
    print(f"  - Total experiments: {pareto_results_df.iloc[0]['total_experiments']}")
    
    # Calculate percentage for best performer
    best_pct = (pareto_results_df.iloc[0]['pareto_front_count'] / pareto_results_df.iloc[0]['total_experiments']) * 100
    print(f"  - Pareto front percentage: {best_pct:.1f}%")
    
else:
    print("No Pareto analysis results available.")
# Out:
# PARETO FRONT ANALYSIS
# ============================================================
# Composite Measure Pareto Performance:
# ----------------------------------------
#                            composite_measure  pareto_front_count  \
# 6     COMPOSITE EAT LOGSCORE OUTER INNER + M                  89
# 4     COMPOSITE EAT LOGSCORE OUTER OUTER + M                  87
# 7   COMPOSITE EAT LOGSCORE OUTER CENTRAL + M                  84
# 1  COMPOSITE EAT SPHERICAL OUTER CENTRAL + M                  69
# 8    COMPOSITE EAT SPHERICAL OUTER INNER + M                  69
# 0    COMPOSITE EAT SPHERICAL OUTER OUTER + M                  68
# 5              COMPOSITE BAYES ALL OUTER + M                  62
# 2                  COMPOSITE BAYES ALL OUTER                  57
# 9       COMPOSITE EXCESS ALL OUTER INNER + M                  28
# 3           COMPOSITE EXCESS ALL OUTER INNER                  27
#
#    avg_pareto_depth  total_experiments
# 6             0.210                105
# 4             0.200                105
# 7             0.267                105
# 1             0.400                105
# 8             0.400                105
# 0             0.352                105
# 5             0.581                105
# 2             0.571                105
# 9             0.952                105
# 3             0.762                105
# Summary:
# - Total composite measures analyzed: 10
# - Best performing composite (most Pareto front appearances): COMPOSITE EAT LOGSCORE OUTER INNER + M
#   - Pareto front count: 89
#   - Average Pareto depth: 0.210
#   - Total experiments: 105
#   - Pareto front percentage: 84.8%

# %%
pareto_results_df
# Out:
#                            composite_measure  pareto_front_count  \
# 6     COMPOSITE EAT LOGSCORE OUTER INNER + M                  89
# 4     COMPOSITE EAT LOGSCORE OUTER OUTER + M                  87
# 7   COMPOSITE EAT LOGSCORE OUTER CENTRAL + M                  84
# 1  COMPOSITE EAT SPHERICAL OUTER CENTRAL + M                  69
# 8    COMPOSITE EAT SPHERICAL OUTER INNER + M                  69
# 0    COMPOSITE EAT SPHERICAL OUTER OUTER + M                  68
# 5              COMPOSITE BAYES ALL OUTER + M                  62
# 2                  COMPOSITE BAYES ALL OUTER                  57
# 9       COMPOSITE EXCESS ALL OUTER INNER + M                  28
# 3           COMPOSITE EXCESS ALL OUTER INNER                  27
#
#    avg_pareto_depth  total_experiments
# 6          0.209524                105
# 4          0.200000                105
# 7          0.266667                105
# 1          0.400000                105
# 8          0.400000                105
# 0          0.352381                105
# 5          0.580952                105
# 2          0.571429                105
# 9          0.952381                105
# 3          0.761905                105

# %%
# Additional analysis of Pareto results
if not pareto_results_df.empty:
    print("\nDETAILED PARETO ANALYSIS")
    print("=" * 50)
    
    # Add percentage column
    pareto_results_df['pareto_percentage'] = (pareto_results_df['pareto_front_count'] / 
                                            pareto_results_df['total_experiments'] * 100)
    
    # Sort by percentage
    pareto_results_df_sorted = pareto_results_df.sort_values('pareto_percentage', ascending=False)
    
    print("Ranking by Pareto Front Percentage:")
    for i, (_, row) in enumerate(pareto_results_df_sorted.iterrows(), 1):
        print(f"{i:2d}. {row['composite_measure']}")
        print(f"    Pareto front: {row['pareto_front_count']:3d}/{row['total_experiments']:3d} ({row['pareto_percentage']:5.1f}%)")
        print(f"    Avg depth: {row['avg_pareto_depth']:6.3f}")
        print()
    
    # Show statistics
    print("STATISTICS:")
    print(f"- Mean Pareto percentage: {pareto_results_df['pareto_percentage'].mean():.1f}%")
    print(f"- Median Pareto percentage: {pareto_results_df['pareto_percentage'].median():.1f}%")
    print(f"- Best Pareto percentage: {pareto_results_df['pareto_percentage'].max():.1f}%")
    print(f"- Worst Pareto percentage: {pareto_results_df['pareto_percentage'].min():.1f}%")
    print()
    print(f"- Mean Pareto depth: {pareto_results_df['avg_pareto_depth'].mean():.3f}")
    print(f"- Best (lowest) Pareto depth: {pareto_results_df['avg_pareto_depth'].min():.3f}")
    print(f"- Worst (highest) Pareto depth: {pareto_results_df['avg_pareto_depth'].max():.3f}")
    
    # Final DataFrame with all columns
    print("\nFINAL RESULTS DATAFRAME:")
    display(pareto_results_df_sorted[['composite_measure', 'pareto_front_count', 
                                    'avg_pareto_depth', 'total_experiments', 'pareto_percentage']].round(3))
# Out:
# DETAILED PARETO ANALYSIS
# ==================================================
# Ranking by Pareto Front Percentage:
#  1. COMPOSITE EAT LOGSCORE OUTER INNER + M
#     Pareto front:  89/105 ( 84.8%)
#     Avg depth:  0.210
#
#  2. COMPOSITE EAT LOGSCORE OUTER OUTER + M
#     Pareto front:  87/105 ( 82.9%)
#     Avg depth:  0.200
#
#  3. COMPOSITE EAT LOGSCORE OUTER CENTRAL + M
#     Pareto front:  84/105 ( 80.0%)
#     Avg depth:  0.267
#
#  4. COMPOSITE EAT SPHERICAL OUTER CENTRAL + M
#     Pareto front:  69/105 ( 65.7%)
#     Avg depth:  0.400
#
#  5. COMPOSITE EAT SPHERICAL OUTER INNER + M
#     Pareto front:  69/105 ( 65.7%)
#     Avg depth:  0.400
#
#  6. COMPOSITE EAT SPHERICAL OUTER OUTER + M
#     Pareto front:  68/105 ( 64.8%)
#     Avg depth:  0.352
#
#  7. COMPOSITE BAYES ALL OUTER + M
#     Pareto front:  62/105 ( 59.0%)
#     Avg depth:  0.581
#
#  8. COMPOSITE BAYES ALL OUTER
#     Pareto front:  57/105 ( 54.3%)
#     Avg depth:  0.571
#
#  9. COMPOSITE EXCESS ALL OUTER INNER + M
#     Pareto front:  28/105 ( 26.7%)
#     Avg depth:  0.952
#
# 10. COMPOSITE EXCESS ALL OUTER INNER
#     Pareto front:  27/105 ( 25.7%)
#     Avg depth:  0.762
#
# STATISTICS:
# - Mean Pareto percentage: 61.0%
# - Median Pareto percentage: 65.2%
# - Best Pareto percentage: 84.8%
# - Worst Pareto percentage: 25.7%
#
# - Mean Pareto depth: 0.470
# - Best (lowest) Pareto depth: 0.200
# - Worst (highest) Pareto depth: 0.952
#
# FINAL RESULTS DATAFRAME:
#                            composite_measure  pareto_front_count  \
# 6     COMPOSITE EAT LOGSCORE OUTER INNER + M                  89
# 4     COMPOSITE EAT LOGSCORE OUTER OUTER + M                  87
# 7   COMPOSITE EAT LOGSCORE OUTER CENTRAL + M                  84
# 1  COMPOSITE EAT SPHERICAL OUTER CENTRAL + M                  69
# 8    COMPOSITE EAT SPHERICAL OUTER INNER + M                  69
# 0    COMPOSITE EAT SPHERICAL OUTER OUTER + M                  68
# 5              COMPOSITE BAYES ALL OUTER + M                  62
# 2                  COMPOSITE BAYES ALL OUTER                  57
# 9       COMPOSITE EXCESS ALL OUTER INNER + M                  28
# 3           COMPOSITE EXCESS ALL OUTER INNER                  27
#
#    avg_pareto_depth  total_experiments  pareto_percentage
# 6             0.210                105             84.762
# 4             0.200                105             82.857
# 7             0.267                105             80.000
# 1             0.400                105             65.714
# 8             0.400                105             65.714
# 0             0.352                105             64.762
# 5             0.581                105             59.048
# 2             0.571                105             54.286
# 9             0.952                105             26.667
# 3             0.762                105             25.714

# %%
# Additional analysis of Pareto results
if not pareto_results_df.empty:
    print("\nDETAILED PARETO ANALYSIS")
    print("=" * 50)
    
    # Add percentage column
    pareto_results_df['pareto_percentage'] = (pareto_results_df['pareto_front_count'] / 
                                            pareto_results_df['total_experiments'] * 100)
    
    # Sort by percentage
    pareto_results_df_sorted = pareto_results_df.sort_values('pareto_percentage', ascending=False)
    
    print("Ranking by Pareto Front Percentage:")
    for i, (_, row) in enumerate(pareto_results_df_sorted.iterrows(), 1):
        print(f"{i:2d}. {row['composite_measure']}")
        print(f"    Pareto front: {row['pareto_front_count']:3d}/{row['total_experiments']:3d} ({row['pareto_percentage']:5.1f}%)")
        print(f"    Avg depth: {row['avg_pareto_depth']:6.3f}")
        print()
    
    # Show statistics
    print("STATISTICS:")
    print(f"- Mean Pareto percentage: {pareto_results_df['pareto_percentage'].mean():.1f}%")
    print(f"- Median Pareto percentage: {pareto_results_df['pareto_percentage'].median():.1f}%")
    print(f"- Best Pareto percentage: {pareto_results_df['pareto_percentage'].max():.1f}%")
    print(f"- Worst Pareto percentage: {pareto_results_df['pareto_percentage'].min():.1f}%")
    print()
    print(f"- Mean Pareto depth: {pareto_results_df['avg_pareto_depth'].mean():.3f}")
    print(f"- Best (lowest) Pareto depth: {pareto_results_df['avg_pareto_depth'].min():.3f}")
    print(f"- Worst (highest) Pareto depth: {pareto_results_df['avg_pareto_depth'].max():.3f}")
    
    # Final DataFrame with all columns
    print("\nFINAL RESULTS DATAFRAME:")
    display(pareto_results_df_sorted[['composite_measure', 'pareto_front_count', 
                                    'avg_pareto_depth', 'total_experiments', 'pareto_percentage']].round(3))
# Out:
# DETAILED PARETO ANALYSIS
# ==================================================
# Ranking by Pareto Front Percentage:
#  1. COMPOSITE EAT LOGSCORE OUTER INNER + M
#     Pareto front:  89/105 ( 84.8%)
#     Avg depth:  0.210
#
#  2. COMPOSITE EAT LOGSCORE OUTER OUTER + M
#     Pareto front:  87/105 ( 82.9%)
#     Avg depth:  0.200
#
#  3. COMPOSITE EAT LOGSCORE OUTER CENTRAL + M
#     Pareto front:  84/105 ( 80.0%)
#     Avg depth:  0.267
#
#  4. COMPOSITE EAT SPHERICAL OUTER CENTRAL + M
#     Pareto front:  69/105 ( 65.7%)
#     Avg depth:  0.400
#
#  5. COMPOSITE EAT SPHERICAL OUTER INNER + M
#     Pareto front:  69/105 ( 65.7%)
#     Avg depth:  0.400
#
#  6. COMPOSITE EAT SPHERICAL OUTER OUTER + M
#     Pareto front:  68/105 ( 64.8%)
#     Avg depth:  0.352
#
#  7. COMPOSITE BAYES ALL OUTER + M
#     Pareto front:  62/105 ( 59.0%)
#     Avg depth:  0.581
#
#  8. COMPOSITE BAYES ALL OUTER
#     Pareto front:  57/105 ( 54.3%)
#     Avg depth:  0.571
#
#  9. COMPOSITE EXCESS ALL OUTER INNER + M
#     Pareto front:  28/105 ( 26.7%)
#     Avg depth:  0.952
#
# 10. COMPOSITE EXCESS ALL OUTER INNER
#     Pareto front:  27/105 ( 25.7%)
#     Avg depth:  0.762
#
# STATISTICS:
# - Mean Pareto percentage: 61.0%
# - Median Pareto percentage: 65.2%
# - Best Pareto percentage: 84.8%
# - Worst Pareto percentage: 25.7%
#
# - Mean Pareto depth: 0.470
# - Best (lowest) Pareto depth: 0.200
# - Worst (highest) Pareto depth: 0.952
#
# FINAL RESULTS DATAFRAME:
#                            composite_measure  pareto_front_count  \
# 6     COMPOSITE EAT LOGSCORE OUTER INNER + M                  89
# 4     COMPOSITE EAT LOGSCORE OUTER OUTER + M                  87
# 7   COMPOSITE EAT LOGSCORE OUTER CENTRAL + M                  84
# 1  COMPOSITE EAT SPHERICAL OUTER CENTRAL + M                  69
# 8    COMPOSITE EAT SPHERICAL OUTER INNER + M                  69
# 0    COMPOSITE EAT SPHERICAL OUTER OUTER + M                  68
# 5              COMPOSITE BAYES ALL OUTER + M                  62
# 2                  COMPOSITE BAYES ALL OUTER                  57
# 9       COMPOSITE EXCESS ALL OUTER INNER + M                  28
# 3           COMPOSITE EXCESS ALL OUTER INNER                  27
#
#    avg_pareto_depth  total_experiments  pareto_percentage
# 6             0.210                105             84.762
# 4             0.200                105             82.857
# 7             0.267                105             80.000
# 1             0.400                105             65.714
# 8             0.400                105             65.714
# 0             0.352                105             64.762
# 5             0.581                105             59.048
# 2             0.571                105             54.286
# 9             0.952                105             26.667
# 3             0.762                105             25.714

# %% [markdown]
# ## Export Tables
#
# You can export the tables to CSV files for further analysis:

# %%
# Example: Add more configurations to the analysis
additional_configs = [
    {
        'eps': 2.0,
        'grid_size': 2,
        'n_targets_multiplier': 1,
        'target': 'exp',
        'scaler_type': 'global_scaler',
        'composite_name': 'COMPOSITE BAYES ALL INNER'
    }
]

print("To analyze additional configurations, add them to the config_list:")
print("config_list.extend(additional_configs)")
print("results_extended = analyze_multiple_configs(config_list)")

# Uncomment to run with additional configs:
# config_list.extend(additional_configs)
# results_extended = analyze_multiple_configs(config_list)
# Out:
# To analyze additional configurations, add them to the config_list:
# config_list.extend(additional_configs)
# results_extended = analyze_multiple_configs(config_list)

# %%
# Test the shortened column names function
test_columns = [
    'R_b 1 (Logscore)',
    'R_e 2 3 (Brier)', 
    'R_t 1 2 (Spherical)',
    'composite bayes all outer',
    'mahalanobis',
    'R_b 3 (Zero-one)'
]

print("Column name shortening examples:")
print("Original -> Shortened")
print("-" * 40)
for col in test_columns:
    shortened = shorten_column_names(col)
    print(f"{col} -> {shortened}")
# Out:
# Column name shortening examples:
# Original -> Shortened
# ----------------------------------------
# R_b 1 (Logscore) -> R_b 1 (L)
# R_e 2 3 (Brier) -> R_e 2 3 (B)
# R_t 1 2 (Spherical) -> R_t 1 2 (S)
# composite bayes all outer -> C
# mahalanobis -> M
# R_b 3 (Zero-one) -> R_b 3 (Z)

# %%
# Create concatenated tables per problem type (side-by-side by composite measure)
def create_concatenated_problem_tables(individual_results: List[Dict]) -> Dict[str, pd.DataFrame]:
    """
    Create concatenated tables for each problem type with all composite measures side-by-side.
    
    Args:
        individual_results: List of individual configuration results
        
    Returns:
        Dictionary with concatenated tables for each problem type
    """
    problem_types = ['ood_detection', 'misclassification_detection', 'selective_prediction']
    concatenated_tables = {}
    
    for problem_type in problem_types:
        tables_to_concat = []
        
        for i, result in enumerate(individual_results):
            config = result['config']
            tables = result['tables']
            
            if problem_type in tables and not tables[problem_type].empty:
                table = tables[problem_type].copy()
                
                # Add suffix to column names to identify the composite measure
                composite_suffix = config['composite_name'].replace(' ', '_').replace('+', 'PLUS')
                
                # Rename columns with composite suffix
                new_columns = {}
                for col in table.columns:
                    new_columns[col] = f"{col}_{composite_suffix}"
                
                table = table.rename(columns=new_columns)
                tables_to_concat.append(table)
        
        # Concatenate all tables side-by-side
        if tables_to_concat:
            # Use outer join to include all indices
            concatenated = pd.concat(tables_to_concat, axis=1, join='outer', sort=True)
            concatenated_tables[problem_type] = concatenated
        else:
            concatenated_tables[problem_type] = pd.DataFrame()
    
    return concatenated_tables

# Create the concatenated tables
concatenated_results = create_concatenated_problem_tables(results['individual_results'])

print("CONCATENATED TABLES BY PROBLEM TYPE")
print("=" * 80)
print("Each table combines all composite measures side-by-side")
print()
# Out:
# CONCATENATED TABLES BY PROBLEM TYPE
# ================================================================================
# Each table combines all composite measures side-by-side

# %%
# Display the concatenated tables
for problem_type, table in concatenated_results.items():
    print(f"\n{problem_type.replace('_', ' ').upper()} - CONCATENATED TABLE")
    print("-" * 60)
    
    if not table.empty:
        print(f"Shape: {table.shape}")
        print(f"Index: {table.index.names}")
        print(f"Columns ({len(table.columns)}):")
        
        # Group columns by composite measure for better display
        column_groups = {}
        for col in table.columns:
            # Extract the composite measure suffix
            parts = col.split('_')
            if len(parts) >= 2:
                # Find the composite measure part (usually the last few parts)
                measure_parts = []
                for part in reversed(parts):
                    measure_parts.insert(0, part)
                    if any(comp_key in '_'.join(measure_parts) for comp_key in ['COMPOSITE', 'BAYES', 'EXCESS']):
                        break
                measure_key = '_'.join(measure_parts)
            else:
                measure_key = 'OTHER'
                
            if measure_key not in column_groups:
                column_groups[measure_key] = []
            column_groups[measure_key].append(col)
        
        # Display columns grouped by composite measure
        for measure, cols in column_groups.items():
            print(f"\n  {measure} ({len(cols)} columns):")
            for col in cols:
                print(f"    - {col}")
        
        print(f"\nDataFrame:")
        display(table.round(4))
        
    else:
        print("No data available")
    
    print("\n" + "="*80)
# Out:
# OOD DETECTION - CONCATENATED TABLE
# ------------------------------------------------------------
# Shape: (9, 52)
# Index: ['ind_dataset', 'eval']
# Columns (52):
#
#   BAYES_ALL_OUTER (5 columns):
#     - R_b 1 (L)_COMPOSITE_BAYES_ALL_OUTER
#     - R_b 1 (B)_COMPOSITE_BAYES_ALL_OUTER
#     - R_b 1 (S)_COMPOSITE_BAYES_ALL_OUTER
#     - R_b 1 (Z)_COMPOSITE_BAYES_ALL_OUTER
#     - C_COMPOSITE_BAYES_ALL_OUTER
#
#   BAYES_ALL_OUTER_PLUS_M (6 columns):
#     - R_b 1 (L)_COMPOSITE_BAYES_ALL_OUTER_PLUS_M
#     - R_b 1 (B)_COMPOSITE_BAYES_ALL_OUTER_PLUS_M
#     - R_b 1 (S)_COMPOSITE_BAYES_ALL_OUTER_PLUS_M
#     - R_b 1 (Z)_COMPOSITE_BAYES_ALL_OUTER_PLUS_M
#     - M_COMPOSITE_BAYES_ALL_OUTER_PLUS_M
#     - C_COMPOSITE_BAYES_ALL_OUTER_PLUS_M
#
#   EXCESS_ALL_OUTER_INNER (5 columns):
#     - R_e 1 2 (L)_COMPOSITE_EXCESS_ALL_OUTER_INNER
#     - R_e 1 2 (B)_COMPOSITE_EXCESS_ALL_OUTER_INNER
#     - R_e 1 2 (S)_COMPOSITE_EXCESS_ALL_OUTER_INNER
#     - R_e 1 2 (Z)_COMPOSITE_EXCESS_ALL_OUTER_INNER
#     - C_COMPOSITE_EXCESS_ALL_OUTER_INNER
#
#   EXCESS_ALL_OUTER_INNER_PLUS_M (6 columns):
#     - R_e 1 2 (L)_COMPOSITE_EXCESS_ALL_OUTER_INNER_PLUS_M
#     - R_e 1 2 (B)_COMPOSITE_EXCESS_ALL_OUTER_INNER_PLUS_M
#     - R_e 1 2 (S)_COMPOSITE_EXCESS_ALL_OUTER_INNER_PLUS_M
#     - R_e 1 2 (Z)_COMPOSITE_EXCESS_ALL_OUTER_INNER_PLUS_M
#     - M_COMPOSITE_EXCESS_ALL_OUTER_INNER_PLUS_M
#     - C_COMPOSITE_EXCESS_ALL_OUTER_INNER_PLUS_M
#
#   COMPOSITE_EAT_LOGSCORE_OUTER_OUTER_PLUS_M (5 columns):
#     - R_e 1 1 (L)_COMPOSITE_EAT_LOGSCORE_OUTER_OUTER_PLUS_M
#     - R_t 1 1 (L)_COMPOSITE_EAT_LOGSCORE_OUTER_OUTER_PLUS_M
#     - R_b 1 (L)_COMPOSITE_EAT_LOGSCORE_OUTER_OUTER_PLUS_M
#     - M_COMPOSITE_EAT_LOGSCORE_OUTER_OUTER_PLUS_M
#     - C_COMPOSITE_EAT_LOGSCORE_OUTER_OUTER_PLUS_M
#
#   COMPOSITE_EAT_LOGSCORE_OUTER_INNER_PLUS_M (5 columns):
#     - R_e 1 2 (L)_COMPOSITE_EAT_LOGSCORE_OUTER_INNER_PLUS_M
#     - R_t 1 2 (L)_COMPOSITE_EAT_LOGSCORE_OUTER_INNER_PLUS_M
#     - R_b 1 (L)_COMPOSITE_EAT_LOGSCORE_OUTER_INNER_PLUS_M
#     - M_COMPOSITE_EAT_LOGSCORE_OUTER_INNER_PLUS_M
#     - C_COMPOSITE_EAT_LOGSCORE_OUTER_INNER_PLUS_M
#
#   COMPOSITE_EAT_LOGSCORE_OUTER_CENTRAL_PLUS_M (5 columns):
#     - R_e 1 3 (L)_COMPOSITE_EAT_LOGSCORE_OUTER_CENTRAL_PLUS_M
#     - R_t 1 3 (L)_COMPOSITE_EAT_LOGSCORE_OUTER_CENTRAL_PLUS_M
#     - R_b 1 (L)_COMPOSITE_EAT_LOGSCORE_OUTER_CENTRAL_PLUS_M
#     - M_COMPOSITE_EAT_LOGSCORE_OUTER_CENTRAL_PLUS_M
#     - C_COMPOSITE_EAT_LOGSCORE_OUTER_CENTRAL_PLUS_M
#
#   COMPOSITE_EAT_SPHERICAL_OUTER_OUTER_PLUS_M (5 columns):
#     - R_e 1 1 (S)_COMPOSITE_EAT_SPHERICAL_OUTER_OUTER_PLUS_M
#     - R_t 1 1 (S)_COMPOSITE_EAT_SPHERICAL_OUTER_OUTER_PLUS_M
#     - R_b 1 (S)_COMPOSITE_EAT_SPHERICAL_OUTER_OUTER_PLUS_M
#     - M_COMPOSITE_EAT_SPHERICAL_OUTER_OUTER_PLUS_M
#     - C_COMPOSITE_EAT_SPHERICAL_OUTER_OUTER_PLUS_M
#
#   COMPOSITE_EAT_SPHERICAL_OUTER_INNER_PLUS_M (5 columns):
#     - R_e 1 2 (S)_COMPOSITE_EAT_SPHERICAL_OUTER_INNER_PLUS_M
#     - R_t 1 2 (S)_COMPOSITE_EAT_SPHERICAL_OUTER_INNER_PLUS_M
#     - R_b 1 (S)_COMPOSITE_EAT_SPHERICAL_OUTER_INNER_PLUS_M
#     - M_COMPOSITE_EAT_SPHERICAL_OUTER_INNER_PLUS_M
#     - C_COMPOSITE_EAT_SPHERICAL_OUTER_INNER_PLUS_M
#
#   COMPOSITE_EAT_SPHERICAL_OUTER_CENTRAL_PLUS_M (5 columns):
#     - R_e 1 3 (S)_COMPOSITE_EAT_SPHERICAL_OUTER_CENTRAL_PLUS_M
#     - R_t 1 3 (S)_COMPOSITE_EAT_SPHERICAL_OUTER_CENTRAL_PLUS_M
#     - R_b 1 (S)_COMPOSITE_EAT_SPHERICAL_OUTER_CENTRAL_PLUS_M
#     - M_COMPOSITE_EAT_SPHERICAL_OUTER_CENTRAL_PLUS_M
#     - C_COMPOSITE_EAT_SPHERICAL_OUTER_CENTRAL_PLUS_M
#
# DataFrame:
# measure                            R_b 1 (L)_COMPOSITE_BAYES_ALL_OUTER  \
# ind_dataset   eval
# cifar10       cifar100 [ood]                                    0.9169
#               svhn [ood]                                        0.9630
#               tiny_imagenet [ood]                               0.9114
# cifar100      cifar10 [ood]                                     0.7733
#               svhn [ood]                                        0.8701
#               tiny_imagenet [ood]                               0.8099
# tiny_imagenet imagenet_a [ood]                                  0.8354
#               imagenet_o [ood]                                  0.7243
#               imagenet_r [ood]                                  0.8253
#
# measure                            R_b 1 (B)_COMPOSITE_BAYES_ALL_OUTER  \
# ind_dataset   eval
# cifar10       cifar100 [ood]                                    0.9144
#               svhn [ood]                                        0.9584
#               tiny_imagenet [ood]                               0.9086
# cifar100      cifar10 [ood]                                     0.7730
#               svhn [ood]                                        0.8583
#               tiny_imagenet [ood]                               0.7895
# tiny_imagenet imagenet_a [ood]                                  0.8272
#               imagenet_o [ood]                                  0.7210
#               imagenet_r [ood]                                  0.8162
#
# measure                            R_b 1 (S)_COMPOSITE_BAYES_ALL_OUTER  \
# ind_dataset   eval
# cifar10       cifar100 [ood]                                    0.9145
#               svhn [ood]                                        0.9585
#               tiny_imagenet [ood]                               0.9087
# cifar100      cifar10 [ood]                                     0.7734
#               svhn [ood]                                        0.8610
#               tiny_imagenet [ood]                               0.8063
# tiny_imagenet imagenet_a [ood]                                  0.8301
#               imagenet_o [ood]                                  0.7226
#               imagenet_r [ood]                                  0.8192
#
# measure                            R_b 1 (Z)_COMPOSITE_BAYES_ALL_OUTER  \
# ind_dataset   eval
# cifar10       cifar100 [ood]                                    0.9132
#               svhn [ood]                                        0.9563
#               tiny_imagenet [ood]                               0.9072
# cifar100      cifar10 [ood]                                     0.7722
#               svhn [ood]                                        0.8559
#               tiny_imagenet [ood]                               0.8030
# tiny_imagenet imagenet_a [ood]                                  0.8263
#               imagenet_o [ood]                                  0.7212
#               imagenet_r [ood]                                  0.8155
#
# measure                            C_COMPOSITE_BAYES_ALL_OUTER  \
# ind_dataset   eval
# cifar10       cifar100 [ood]                            0.9158
#               svhn [ood]                                0.9610
#               tiny_imagenet [ood]                       0.9101
# cifar100      cifar10 [ood]                             0.7734
#               svhn [ood]                                0.8659
#               tiny_imagenet [ood]                       0.8054
# tiny_imagenet imagenet_a [ood]                          0.8331
#               imagenet_o [ood]                          0.7234
#               imagenet_r [ood]                          0.8225
#
# measure                            R_b 1 (L)_COMPOSITE_BAYES_ALL_OUTER_PLUS_M  \
# ind_dataset   eval
# cifar10       cifar100 [ood]                                           0.9169
#               svhn [ood]                                               0.9630
#               tiny_imagenet [ood]                                      0.9114
# cifar100      cifar10 [ood]                                            0.7733
#               svhn [ood]                                               0.8701
#               tiny_imagenet [ood]                                      0.8099
# tiny_imagenet imagenet_a [ood]                                         0.8354
#               imagenet_o [ood]                                         0.7243
#               imagenet_r [ood]                                         0.8253
#
# measure                            R_b 1 (B)_COMPOSITE_BAYES_ALL_OUTER_PLUS_M  \
# ind_dataset   eval
# cifar10       cifar100 [ood]                                           0.9144
#               svhn [ood]                                               0.9584
#               tiny_imagenet [ood]                                      0.9086
# cifar100      cifar10 [ood]                                            0.7730
#               svhn [ood]                                               0.8583
#               tiny_imagenet [ood]                                      0.7895
# tiny_imagenet imagenet_a [ood]                                         0.8272
#               imagenet_o [ood]                                         0.7210
#               imagenet_r [ood]                                         0.8162
#
# measure                            R_b 1 (S)_COMPOSITE_BAYES_ALL_OUTER_PLUS_M  \
# ind_dataset   eval
# cifar10       cifar100 [ood]                                           0.9145
#               svhn [ood]                                               0.9585
#               tiny_imagenet [ood]                                      0.9087
# cifar100      cifar10 [ood]                                            0.7734
#               svhn [ood]                                               0.8610
#               tiny_imagenet [ood]                                      0.8063
# tiny_imagenet imagenet_a [ood]                                         0.8301
#               imagenet_o [ood]                                         0.7226
#               imagenet_r [ood]                                         0.8192
#
# measure                            R_b 1 (Z)_COMPOSITE_BAYES_ALL_OUTER_PLUS_M  \
# ind_dataset   eval
# cifar10       cifar100 [ood]                                           0.9132
#               svhn [ood]                                               0.9563
#               tiny_imagenet [ood]                                      0.9072
# cifar100      cifar10 [ood]                                            0.7722
#               svhn [ood]                                               0.8559
#               tiny_imagenet [ood]                                      0.8030
# tiny_imagenet imagenet_a [ood]                                         0.8263
#               imagenet_o [ood]                                         0.7212
#               imagenet_r [ood]                                         0.8155
#
# measure                            M_COMPOSITE_BAYES_ALL_OUTER_PLUS_M  \
# ind_dataset   eval
# cifar10       cifar100 [ood]                                   0.9122
#               svhn [ood]                                       0.9343
#               tiny_imagenet [ood]                              0.9103
# cifar100      cifar10 [ood]                                    0.5348
#               svhn [ood]                                       0.6788
#               tiny_imagenet [ood]                              0.6229
# tiny_imagenet imagenet_a [ood]                                 0.4410
#               imagenet_o [ood]                                 0.5127
#               imagenet_r [ood]                                 0.4048
#
# measure                            C_COMPOSITE_BAYES_ALL_OUTER_PLUS_M  \
# ind_dataset   eval
# cifar10       cifar100 [ood]                                   0.9185
#               svhn [ood]                                       0.9572
#               tiny_imagenet [ood]                              0.9140
# cifar100      cifar10 [ood]                                    0.7681
#               svhn [ood]                                       0.8677
#               tiny_imagenet [ood]                              0.8046
# tiny_imagenet imagenet_a [ood]                                 0.8324
#               imagenet_o [ood]                                 0.7277
#               imagenet_r [ood]                                 0.8203
#
# measure                            R_e 1 2 (L)_COMPOSITE_EXCESS_ALL_OUTER_INNER  \
# ind_dataset   eval
# cifar10       cifar100 [ood]                                             0.9072
#               svhn [ood]                                                 0.9458
#               tiny_imagenet [ood]                                        0.8987
# cifar100      cifar10 [ood]                                              0.7367
#               svhn [ood]                                                 0.7763
#               tiny_imagenet [ood]                                        0.9999
# tiny_imagenet imagenet_a [ood]                                           0.8014
#               imagenet_o [ood]                                           0.7552
#               imagenet_r [ood]                                           0.7933
#
# measure                            R_e 1 2 (B)_COMPOSITE_EXCESS_ALL_OUTER_INNER  \
# ind_dataset   eval
# cifar10       cifar100 [ood]                                             0.9023
#               svhn [ood]                                                 0.9402
#               tiny_imagenet [ood]                                        0.8932
# cifar100      cifar10 [ood]                                              0.6813
#               svhn [ood]                                                 0.6621
#               tiny_imagenet [ood]                                        0.9534
# tiny_imagenet imagenet_a [ood]                                           0.6511
#               imagenet_o [ood]                                           0.6911
#               imagenet_r [ood]                                           0.6570
#
# measure                            R_e 1 2 (S)_COMPOSITE_EXCESS_ALL_OUTER_INNER  \
# ind_dataset   eval
# cifar10       cifar100 [ood]                                             0.9024
#               svhn [ood]                                                 0.9421
#               tiny_imagenet [ood]                                        0.8931
# cifar100      cifar10 [ood]                                              0.7216
#               svhn [ood]                                                 0.7312
#               tiny_imagenet [ood]                                        0.9944
# tiny_imagenet imagenet_a [ood]                                           0.7319
#               imagenet_o [ood]                                           0.7236
#               imagenet_r [ood]                                           0.7308
#
# measure                            R_e 1 2 (Z)_COMPOSITE_EXCESS_ALL_OUTER_INNER  \
# ind_dataset   eval
# cifar10       cifar100 [ood]                                             0.7546
#               svhn [ood]                                                 0.8246
#               tiny_imagenet [ood]                                        0.7524
# cifar100      cifar10 [ood]                                              0.6891
#               svhn [ood]                                                 0.7057
#               tiny_imagenet [ood]                                        0.9763
# tiny_imagenet imagenet_a [ood]                                           0.7129
#               imagenet_o [ood]                                           0.7005
#               imagenet_r [ood]                                           0.7122
#
# measure                            C_COMPOSITE_EXCESS_ALL_OUTER_INNER  \
# ind_dataset   eval
# cifar10       cifar100 [ood]                                   0.9059
#               svhn [ood]                                       0.9440
#               tiny_imagenet [ood]                              0.8972
# cifar100      cifar10 [ood]                                    0.7206
#               svhn [ood]                                       0.7396
#               tiny_imagenet [ood]                              0.9999
# tiny_imagenet imagenet_a [ood]                                 0.7550
#               imagenet_o [ood]                                 0.7368
#               imagenet_r [ood]                                 0.7501
#
# measure                            R_e 1 2 (L)_COMPOSITE_EXCESS_ALL_OUTER_INNER_PLUS_M  \
# ind_dataset   eval
# cifar10       cifar100 [ood]                                                    0.9072
#               svhn [ood]                                                        0.9458
#               tiny_imagenet [ood]                                               0.8987
# cifar100      cifar10 [ood]                                                     0.7367
#               svhn [ood]                                                        0.7763
#               tiny_imagenet [ood]                                               0.9999
# tiny_imagenet imagenet_a [ood]                                                  0.8014
#               imagenet_o [ood]                                                  0.7552
#               imagenet_r [ood]                                                  0.7933
#
# measure                            R_e 1 2 (B)_COMPOSITE_EXCESS_ALL_OUTER_INNER_PLUS_M  \
# ind_dataset   eval
# cifar10       cifar100 [ood]                                                    0.9023
#               svhn [ood]                                                        0.9402
#               tiny_imagenet [ood]                                               0.8932
# cifar100      cifar10 [ood]                                                     0.6813
#               svhn [ood]                                                        0.6621
#               tiny_imagenet [ood]                                               0.9534
# tiny_imagenet imagenet_a [ood]                                                  0.6511
#               imagenet_o [ood]                                                  0.6911
#               imagenet_r [ood]                                                  0.6570
#
# measure                            R_e 1 2 (S)_COMPOSITE_EXCESS_ALL_OUTER_INNER_PLUS_M  \
# ind_dataset   eval
# cifar10       cifar100 [ood]                                                    0.9024
#               svhn [ood]                                                        0.9421
#               tiny_imagenet [ood]                                               0.8931
# cifar100      cifar10 [ood]                                                     0.7216
#               svhn [ood]                                                        0.7312
#               tiny_imagenet [ood]                                               0.9944
# tiny_imagenet imagenet_a [ood]                                                  0.7319
#               imagenet_o [ood]                                                  0.7236
#               imagenet_r [ood]                                                  0.7308
#
# measure                            R_e 1 2 (Z)_COMPOSITE_EXCESS_ALL_OUTER_INNER_PLUS_M  \
# ind_dataset   eval
# cifar10       cifar100 [ood]                                                    0.7546
#               svhn [ood]                                                        0.8246
#               tiny_imagenet [ood]                                               0.7524
# cifar100      cifar10 [ood]                                                     0.6891
#               svhn [ood]                                                        0.7057
#               tiny_imagenet [ood]                                               0.9763
# tiny_imagenet imagenet_a [ood]                                                  0.7129
#               imagenet_o [ood]                                                  0.7005
#               imagenet_r [ood]                                                  0.7122
#
# measure                            M_COMPOSITE_EXCESS_ALL_OUTER_INNER_PLUS_M  \
# ind_dataset   eval
# cifar10       cifar100 [ood]                                          0.9122
#               svhn [ood]                                              0.9343
#               tiny_imagenet [ood]                                     0.9103
# cifar100      cifar10 [ood]                                           0.5348
#               svhn [ood]                                              0.6788
#               tiny_imagenet [ood]                                     0.6229
# tiny_imagenet imagenet_a [ood]                                        0.4410
#               imagenet_o [ood]                                        0.5127
#               imagenet_r [ood]                                        0.4048
#
# measure                            C_COMPOSITE_EXCESS_ALL_OUTER_INNER_PLUS_M  \
# ind_dataset   eval
# cifar10       cifar100 [ood]                                          0.9103
#               svhn [ood]                                              0.9423
#               tiny_imagenet [ood]                                     0.9042
# cifar100      cifar10 [ood]                                           0.6928
#               svhn [ood]                                              0.7247
#               tiny_imagenet [ood]                                     0.9996
# tiny_imagenet imagenet_a [ood]                                        0.7293
#               imagenet_o [ood]                                        0.7213
#               imagenet_r [ood]                                        0.7238
#
# measure                            R_e 1 1 (L)_COMPOSITE_EAT_LOGSCORE_OUTER_OUTER_PLUS_M  \
# ind_dataset   eval
# cifar10       cifar100 [ood]                                                      0.9047
#               svhn [ood]                                                          0.9426
#               tiny_imagenet [ood]                                                 0.8957
# cifar100      cifar10 [ood]                                                       0.7245
#               svhn [ood]                                                          0.7558
#               tiny_imagenet [ood]                                                 0.9999
# tiny_imagenet imagenet_a [ood]                                                    0.7811
#               imagenet_o [ood]                                                    0.7528
#               imagenet_r [ood]                                                    0.7744
#
# measure                            R_t 1 1 (L)_COMPOSITE_EAT_LOGSCORE_OUTER_OUTER_PLUS_M  \
# ind_dataset   eval
# cifar10       cifar100 [ood]                                                      0.9115
#               svhn [ood]                                                          0.9565
#               tiny_imagenet [ood]                                                 0.9036
# cifar100      cifar10 [ood]                                                       0.7740
#               svhn [ood]                                                          0.8677
#               tiny_imagenet [ood]                                                 1.0000
# tiny_imagenet imagenet_a [ood]                                                    0.8463
#               imagenet_o [ood]                                                    0.7535
#               imagenet_r [ood]                                                    0.8366
#
# measure                            R_b 1 (L)_COMPOSITE_EAT_LOGSCORE_OUTER_OUTER_PLUS_M  \
# ind_dataset   eval
# cifar10       cifar100 [ood]                                                    0.9169
#               svhn [ood]                                                        0.9630
#               tiny_imagenet [ood]                                               0.9114
# cifar100      cifar10 [ood]                                                     0.7733
#               svhn [ood]                                                        0.8701
#               tiny_imagenet [ood]                                               0.8099
# tiny_imagenet imagenet_a [ood]                                                  0.8354
#               imagenet_o [ood]                                                  0.7243
#               imagenet_r [ood]                                                  0.8253
#
# measure                            M_COMPOSITE_EAT_LOGSCORE_OUTER_OUTER_PLUS_M  \
# ind_dataset   eval
# cifar10       cifar100 [ood]                                            0.9122
#               svhn [ood]                                                0.9343
#               tiny_imagenet [ood]                                       0.9103
# cifar100      cifar10 [ood]                                             0.5348
#               svhn [ood]                                                0.6788
#               tiny_imagenet [ood]                                       0.6229
# tiny_imagenet imagenet_a [ood]                                          0.4410
#               imagenet_o [ood]                                          0.5127
#               imagenet_r [ood]                                          0.4048
#
# measure                            C_COMPOSITE_EAT_LOGSCORE_OUTER_OUTER_PLUS_M  \
# ind_dataset   eval
# cifar10       cifar100 [ood]                                            0.9181
#               svhn [ood]                                                0.9573
#               tiny_imagenet [ood]                                       0.9123
# cifar100      cifar10 [ood]                                             0.7649
#               svhn [ood]                                                0.8717
#               tiny_imagenet [ood]                                       1.0000
# tiny_imagenet imagenet_a [ood]                                          0.8469
#               imagenet_o [ood]                                          0.7596
#               imagenet_r [ood]                                          0.8347
#
# measure                            R_e 1 2 (L)_COMPOSITE_EAT_LOGSCORE_OUTER_INNER_PLUS_M  \
# ind_dataset   eval
# cifar10       cifar100 [ood]                                                      0.9072
#               svhn [ood]                                                          0.9458
#               tiny_imagenet [ood]                                                 0.8987
# cifar100      cifar10 [ood]                                                       0.7367
#               svhn [ood]                                                          0.7763
#               tiny_imagenet [ood]                                                 0.9999
# tiny_imagenet imagenet_a [ood]                                                    0.8014
#               imagenet_o [ood]                                                    0.7552
#               imagenet_r [ood]                                                    0.7933
#
# measure                            R_t 1 2 (L)_COMPOSITE_EAT_LOGSCORE_OUTER_INNER_PLUS_M  \
# ind_dataset   eval
# cifar10       cifar100 [ood]                                                      0.9162
#               svhn [ood]                                                          0.9631
#               tiny_imagenet [ood]                                                 0.9095
# cifar100      cifar10 [ood]                                                       0.7745
#               svhn [ood]                                                          0.8702
#               tiny_imagenet [ood]                                                 0.9260
# tiny_imagenet imagenet_a [ood]                                                    0.8410
#               imagenet_o [ood]                                                    0.7349
#               imagenet_r [ood]                                                    0.8310
#
# measure                            R_b 1 (L)_COMPOSITE_EAT_LOGSCORE_OUTER_INNER_PLUS_M  \
# ind_dataset   eval
# cifar10       cifar100 [ood]                                                    0.9169
#               svhn [ood]                                                        0.9630
#               tiny_imagenet [ood]                                               0.9114
# cifar100      cifar10 [ood]                                                     0.7733
#               svhn [ood]                                                        0.8701
#               tiny_imagenet [ood]                                               0.8099
# tiny_imagenet imagenet_a [ood]                                                  0.8354
#               imagenet_o [ood]                                                  0.7243
#               imagenet_r [ood]                                                  0.8253
#
# measure                            M_COMPOSITE_EAT_LOGSCORE_OUTER_INNER_PLUS_M  \
# ind_dataset   eval
# cifar10       cifar100 [ood]                                            0.9122
#               svhn [ood]                                                0.9343
#               tiny_imagenet [ood]                                       0.9103
# cifar100      cifar10 [ood]                                             0.5348
#               svhn [ood]                                                0.6788
#               tiny_imagenet [ood]                                       0.6229
# tiny_imagenet imagenet_a [ood]                                          0.4410
#               imagenet_o [ood]                                          0.5127
#               imagenet_r [ood]                                          0.4048
#
# measure                            C_COMPOSITE_EAT_LOGSCORE_OUTER_INNER_PLUS_M  \
# ind_dataset   eval
# cifar10       cifar100 [ood]                                            0.9194
#               svhn [ood]                                                0.9591
#               tiny_imagenet [ood]                                       0.9141
# cifar100      cifar10 [ood]                                             0.7667
#               svhn [ood]                                                0.8745
#               tiny_imagenet [ood]                                       0.9994
# tiny_imagenet imagenet_a [ood]                                          0.8466
#               imagenet_o [ood]                                          0.7514
#               imagenet_r [ood]                                          0.8344
#
# measure                            R_e 1 3 (L)_COMPOSITE_EAT_LOGSCORE_OUTER_CENTRAL_PLUS_M  \
# ind_dataset   eval
# cifar10       cifar100 [ood]                                                        0.9026
#               svhn [ood]                                                            0.9397
#               tiny_imagenet [ood]                                                   0.8935
# cifar100      cifar10 [ood]                                                         0.7180
#               svhn [ood]                                                            0.7499
#               tiny_imagenet [ood]                                                   0.9999
# tiny_imagenet imagenet_a [ood]                                                      0.7720
#               imagenet_o [ood]                                                      0.7464
#               imagenet_r [ood]                                                      0.7644
#
# measure                            R_t 1 3 (L)_COMPOSITE_EAT_LOGSCORE_OUTER_CENTRAL_PLUS_M  \
# ind_dataset   eval
# cifar10       cifar100 [ood]                                                        0.9150
#               svhn [ood]                                                            0.9619
#               tiny_imagenet [ood]                                                   0.9079
# cifar100      cifar10 [ood]                                                         0.7742
#               svhn [ood]                                                            0.8703
#               tiny_imagenet [ood]                                                   0.9797
# tiny_imagenet imagenet_a [ood]                                                      0.8427
#               imagenet_o [ood]                                                      0.7406
#               imagenet_r [ood]                                                      0.8327
#
# measure                            R_b 1 (L)_COMPOSITE_EAT_LOGSCORE_OUTER_CENTRAL_PLUS_M  \
# ind_dataset   eval
# cifar10       cifar100 [ood]                                                      0.9169
#               svhn [ood]                                                          0.9630
#               tiny_imagenet [ood]                                                 0.9114
# cifar100      cifar10 [ood]                                                       0.7733
#               svhn [ood]                                                          0.8701
#               tiny_imagenet [ood]                                                 0.8099
# tiny_imagenet imagenet_a [ood]                                                    0.8354
#               imagenet_o [ood]                                                    0.7243
#               imagenet_r [ood]                                                    0.8253
#
# measure                            M_COMPOSITE_EAT_LOGSCORE_OUTER_CENTRAL_PLUS_M  \
# ind_dataset   eval
# cifar10       cifar100 [ood]                                              0.9122
#               svhn [ood]                                                  0.9343
#               tiny_imagenet [ood]                                         0.9103
# cifar100      cifar10 [ood]                                               0.5348
#               svhn [ood]                                                  0.6788
#               tiny_imagenet [ood]                                         0.6229
# tiny_imagenet imagenet_a [ood]                                            0.4410
#               imagenet_o [ood]                                            0.5127
#               imagenet_r [ood]                                            0.4048
#
# measure                            C_COMPOSITE_EAT_LOGSCORE_OUTER_CENTRAL_PLUS_M  \
# ind_dataset   eval
# cifar10       cifar100 [ood]                                              0.9189
#               svhn [ood]                                                  0.9584
#               tiny_imagenet [ood]                                         0.9134
# cifar100      cifar10 [ood]                                               0.7652
#               svhn [ood]                                                  0.8738
#               tiny_imagenet [ood]                                         1.0000
# tiny_imagenet imagenet_a [ood]                                            0.8462
#               imagenet_o [ood]                                            0.7541
#               imagenet_r [ood]                                            0.8339
#
# measure                            R_e 1 1 (S)_COMPOSITE_EAT_SPHERICAL_OUTER_OUTER_PLUS_M  \
# ind_dataset   eval
# cifar10       cifar100 [ood]                                                       0.9044
#               svhn [ood]                                                           0.9420
#               tiny_imagenet [ood]                                                  0.8956
# cifar100      cifar10 [ood]                                                        0.7172
#               svhn [ood]                                                           0.7234
#               tiny_imagenet [ood]                                                  0.9915
# tiny_imagenet imagenet_a [ood]                                                     0.7212
#               imagenet_o [ood]                                                     0.7211
#               imagenet_r [ood]                                                     0.7216
#
# measure                            R_t 1 1 (S)_COMPOSITE_EAT_SPHERICAL_OUTER_OUTER_PLUS_M  \
# ind_dataset   eval
# cifar10       cifar100 [ood]                                                       0.9113
#               svhn [ood]                                                           0.9551
#               tiny_imagenet [ood]                                                  0.9036
# cifar100      cifar10 [ood]                                                        0.7735
#               svhn [ood]                                                           0.8526
#               tiny_imagenet [ood]                                                  0.9930
# tiny_imagenet imagenet_a [ood]                                                     0.8352
#               imagenet_o [ood]                                                     0.7415
#               imagenet_r [ood]                                                     0.8253
#
# measure                            R_b 1 (S)_COMPOSITE_EAT_SPHERICAL_OUTER_OUTER_PLUS_M  \
# ind_dataset   eval
# cifar10       cifar100 [ood]                                                     0.9145
#               svhn [ood]                                                         0.9585
#               tiny_imagenet [ood]                                                0.9087
# cifar100      cifar10 [ood]                                                      0.7734
#               svhn [ood]                                                         0.8610
#               tiny_imagenet [ood]                                                0.8063
# tiny_imagenet imagenet_a [ood]                                                   0.8301
#               imagenet_o [ood]                                                   0.7226
#               imagenet_r [ood]                                                   0.8192
#
# measure                            M_COMPOSITE_EAT_SPHERICAL_OUTER_OUTER_PLUS_M  \
# ind_dataset   eval
# cifar10       cifar100 [ood]                                             0.9122
#               svhn [ood]                                                 0.9343
#               tiny_imagenet [ood]                                        0.9103
# cifar100      cifar10 [ood]                                              0.5348
#               svhn [ood]                                                 0.6788
#               tiny_imagenet [ood]                                        0.6229
# tiny_imagenet imagenet_a [ood]                                           0.4410
#               imagenet_o [ood]                                           0.5127
#               imagenet_r [ood]                                           0.4048
#
# measure                            C_COMPOSITE_EAT_SPHERICAL_OUTER_OUTER_PLUS_M  \
# ind_dataset   eval
# cifar10       cifar100 [ood]                                             0.9116
#               svhn [ood]                                                 0.9558
#               tiny_imagenet [ood]                                        0.9040
# cifar100      cifar10 [ood]                                              0.7725
#               svhn [ood]                                                 0.8512
#               tiny_imagenet [ood]                                        0.9967
# tiny_imagenet imagenet_a [ood]                                           0.8332
#               imagenet_o [ood]                                           0.7426
#               imagenet_r [ood]                                           0.8236
#
# measure                            R_e 1 2 (S)_COMPOSITE_EAT_SPHERICAL_OUTER_INNER_PLUS_M  \
# ind_dataset   eval
# cifar10       cifar100 [ood]                                                       0.9024
#               svhn [ood]                                                           0.9421
#               tiny_imagenet [ood]                                                  0.8931
# cifar100      cifar10 [ood]                                                        0.7216
#               svhn [ood]                                                           0.7312
#               tiny_imagenet [ood]                                                  0.9944
# tiny_imagenet imagenet_a [ood]                                                     0.7319
#               imagenet_o [ood]                                                     0.7236
#               imagenet_r [ood]                                                     0.7308
#
# measure                            R_t 1 2 (S)_COMPOSITE_EAT_SPHERICAL_OUTER_INNER_PLUS_M  \
# ind_dataset   eval
# cifar10       cifar100 [ood]                                                       0.9130
#               svhn [ood]                                                           0.9577
#               tiny_imagenet [ood]                                                  0.9058
# cifar100      cifar10 [ood]                                                        0.7744
#               svhn [ood]                                                           0.8567
#               tiny_imagenet [ood]                                                  0.9371
# tiny_imagenet imagenet_a [ood]                                                     0.8345
#               imagenet_o [ood]                                                     0.7358
#               imagenet_r [ood]                                                     0.8241
#
# measure                            R_b 1 (S)_COMPOSITE_EAT_SPHERICAL_OUTER_INNER_PLUS_M  \
# ind_dataset   eval
# cifar10       cifar100 [ood]                                                     0.9145
#               svhn [ood]                                                         0.9585
#               tiny_imagenet [ood]                                                0.9087
# cifar100      cifar10 [ood]                                                      0.7734
#               svhn [ood]                                                         0.8610
#               tiny_imagenet [ood]                                                0.8063
# tiny_imagenet imagenet_a [ood]                                                   0.8301
#               imagenet_o [ood]                                                   0.7226
#               imagenet_r [ood]                                                   0.8192
#
# measure                            M_COMPOSITE_EAT_SPHERICAL_OUTER_INNER_PLUS_M  \
# ind_dataset   eval
# cifar10       cifar100 [ood]                                             0.9122
#               svhn [ood]                                                 0.9343
#               tiny_imagenet [ood]                                        0.9103
# cifar100      cifar10 [ood]                                              0.5348
#               svhn [ood]                                                 0.6788
#               tiny_imagenet [ood]                                        0.6229
# tiny_imagenet imagenet_a [ood]                                           0.4410
#               imagenet_o [ood]                                           0.5127
#               imagenet_r [ood]                                           0.4048
#
# measure                            C_COMPOSITE_EAT_SPHERICAL_OUTER_INNER_PLUS_M  \
# ind_dataset   eval
# cifar10       cifar100 [ood]                                             0.9126
#               svhn [ood]                                                 0.9570
#               tiny_imagenet [ood]                                        0.9052
# cifar100      cifar10 [ood]                                              0.7722
#               svhn [ood]                                                 0.8484
#               tiny_imagenet [ood]                                        0.9989
# tiny_imagenet imagenet_a [ood]                                           0.8329
#               imagenet_o [ood]                                           0.7429
#               imagenet_r [ood]                                           0.8231
#
# measure                            R_e 1 3 (S)_COMPOSITE_EAT_SPHERICAL_OUTER_CENTRAL_PLUS_M  \
# ind_dataset   eval
# cifar10       cifar100 [ood]                                                         0.9040
#               svhn [ood]                                                             0.9418
#               tiny_imagenet [ood]                                                    0.8944
# cifar100      cifar10 [ood]                                                          0.7147
#               svhn [ood]                                                             0.7186
#               tiny_imagenet [ood]                                                    0.9895
# tiny_imagenet imagenet_a [ood]                                                       0.7154
# ...
# cifar10       cifar10 [selective]                                                     0.9967
# cifar100      cifar100 [selective]                                                    0.9162
# tiny_imagenet tiny_imagenet [selective]                                               0.8825
#
# measure                                  R_e 1 2 (Z)_COMPOSITE_EXCESS_ALL_OUTER_INNER_PLUS_M  \
# ind_dataset   eval
# cifar10       cifar10 [selective]                                                     0.9828
# cifar100      cifar100 [selective]                                                    0.8789
# tiny_imagenet tiny_imagenet [selective]                                               0.8528
#
# measure                                  M_COMPOSITE_EXCESS_ALL_OUTER_INNER_PLUS_M  \
# ind_dataset   eval
# cifar10       cifar10 [selective]                                           0.9963
# cifar100      cifar100 [selective]                                          0.8106
# tiny_imagenet tiny_imagenet [selective]                                     0.6598
#
# measure                                  C_COMPOSITE_EXCESS_ALL_OUTER_INNER_PLUS_M  \
# ind_dataset   eval
# cifar10       cifar10 [selective]                                           0.9968
# cifar100      cifar100 [selective]                                          0.9013
# tiny_imagenet tiny_imagenet [selective]                                     0.8666
#
# measure                                  R_e 1 1 (L)_COMPOSITE_EAT_LOGSCORE_OUTER_OUTER_PLUS_M  \
# ind_dataset   eval
# cifar10       cifar10 [selective]                                                       0.9968
# cifar100      cifar100 [selective]                                                      0.9097
# tiny_imagenet tiny_imagenet [selective]                                                 0.8792
#
# measure                                  R_t 1 1 (L)_COMPOSITE_EAT_LOGSCORE_OUTER_OUTER_PLUS_M  \
# ind_dataset   eval
# cifar10       cifar10 [selective]                                                       0.9969
# cifar100      cifar100 [selective]                                                      0.9184
# tiny_imagenet tiny_imagenet [selective]                                                 0.8909
#
# measure                                  R_b 1 (L)_COMPOSITE_EAT_LOGSCORE_OUTER_OUTER_PLUS_M  \
# ind_dataset   eval
# cifar10       cifar10 [selective]                                                     0.9968
# cifar100      cifar100 [selective]                                                    0.9159
# tiny_imagenet tiny_imagenet [selective]                                               0.8889
#
# measure                                  M_COMPOSITE_EAT_LOGSCORE_OUTER_OUTER_PLUS_M  \
# ind_dataset   eval
# cifar10       cifar10 [selective]                                             0.9963
# cifar100      cifar100 [selective]                                            0.8106
# tiny_imagenet tiny_imagenet [selective]                                       0.6598
#
# measure                                  C_COMPOSITE_EAT_LOGSCORE_OUTER_OUTER_PLUS_M  \
# ind_dataset   eval
# cifar10       cifar10 [selective]                                             0.9969
# cifar100      cifar100 [selective]                                            0.9154
# tiny_imagenet tiny_imagenet [selective]                                       0.8863
#
# measure                                  R_e 1 2 (L)_COMPOSITE_EAT_LOGSCORE_OUTER_INNER_PLUS_M  \
# ind_dataset   eval
# cifar10       cifar10 [selective]                                                       0.9969
# cifar100      cifar100 [selective]                                                      0.9133
# tiny_imagenet tiny_imagenet [selective]                                                 0.8853
#
# measure                                  R_t 1 2 (L)_COMPOSITE_EAT_LOGSCORE_OUTER_INNER_PLUS_M  \
# ind_dataset   eval
# cifar10       cifar10 [selective]                                                       0.9969
# cifar100      cifar100 [selective]                                                      0.9175
# tiny_imagenet tiny_imagenet [selective]                                                 0.8907
#
# measure                                  R_b 1 (L)_COMPOSITE_EAT_LOGSCORE_OUTER_INNER_PLUS_M  \
# ind_dataset   eval
# cifar10       cifar10 [selective]                                                     0.9968
# cifar100      cifar100 [selective]                                                    0.9159
# tiny_imagenet tiny_imagenet [selective]                                               0.8889
#
# measure                                  M_COMPOSITE_EAT_LOGSCORE_OUTER_INNER_PLUS_M  \
# ind_dataset   eval
# cifar10       cifar10 [selective]                                             0.9963
# cifar100      cifar100 [selective]                                            0.8106
# tiny_imagenet tiny_imagenet [selective]                                       0.6598
#
# measure                                  C_COMPOSITE_EAT_LOGSCORE_OUTER_INNER_PLUS_M  \
# ind_dataset   eval
# cifar10       cifar10 [selective]                                             0.9969
# cifar100      cifar100 [selective]                                            0.9158
# tiny_imagenet tiny_imagenet [selective]                                       0.8874
#
# measure                                  R_e 1 3 (L)_COMPOSITE_EAT_LOGSCORE_OUTER_CENTRAL_PLUS_M  \
# ind_dataset   eval
# cifar10       cifar10 [selective]                                                         0.9967
# cifar100      cifar100 [selective]                                                        0.9056
# tiny_imagenet tiny_imagenet [selective]                                                   0.8717
#
# measure                                  R_t 1 3 (L)_COMPOSITE_EAT_LOGSCORE_OUTER_CENTRAL_PLUS_M  \
# ind_dataset   eval
# cifar10       cifar10 [selective]                                                         0.9968
# cifar100      cifar100 [selective]                                                        0.9171
# tiny_imagenet tiny_imagenet [selective]                                                   0.8893
#
# measure                                  R_b 1 (L)_COMPOSITE_EAT_LOGSCORE_OUTER_CENTRAL_PLUS_M  \
# ind_dataset   eval
# cifar10       cifar10 [selective]                                                       0.9968
# cifar100      cifar100 [selective]                                                      0.9159
# tiny_imagenet tiny_imagenet [selective]                                                 0.8889
#
# measure                                  M_COMPOSITE_EAT_LOGSCORE_OUTER_CENTRAL_PLUS_M  \
# ind_dataset   eval
# cifar10       cifar10 [selective]                                               0.9963
# cifar100      cifar100 [selective]                                              0.8106
# tiny_imagenet tiny_imagenet [selective]                                         0.6598
#
# measure                                  C_COMPOSITE_EAT_LOGSCORE_OUTER_CENTRAL_PLUS_M  \
# ind_dataset   eval
# cifar10       cifar10 [selective]                                               0.9969
# cifar100      cifar100 [selective]                                              0.9144
# tiny_imagenet tiny_imagenet [selective]                                         0.8846
#
# measure                                  R_e 1 1 (S)_COMPOSITE_EAT_SPHERICAL_OUTER_OUTER_PLUS_M  \
# ind_dataset   eval
# cifar10       cifar10 [selective]                                                        0.9969
# cifar100      cifar100 [selective]                                                       0.9141
# tiny_imagenet tiny_imagenet [selective]                                                  0.8793
#
# measure                                  R_t 1 1 (S)_COMPOSITE_EAT_SPHERICAL_OUTER_OUTER_PLUS_M  \
# ind_dataset   eval
# cifar10       cifar10 [selective]                                                        0.9969
# cifar100      cifar100 [selective]                                                       0.9231
# tiny_imagenet tiny_imagenet [selective]                                                  0.8961
#
# measure                                  R_b 1 (S)_COMPOSITE_EAT_SPHERICAL_OUTER_OUTER_PLUS_M  \
# ind_dataset   eval
# cifar10       cifar10 [selective]                                                      0.9968
# cifar100      cifar100 [selective]                                                     0.9197
# tiny_imagenet tiny_imagenet [selective]                                                0.8921
#
# measure                                  M_COMPOSITE_EAT_SPHERICAL_OUTER_OUTER_PLUS_M  \
# ind_dataset   eval
# cifar10       cifar10 [selective]                                              0.9963
# cifar100      cifar100 [selective]                                             0.8106
# tiny_imagenet tiny_imagenet [selective]                                        0.6598
#
# measure                                  C_COMPOSITE_EAT_SPHERICAL_OUTER_OUTER_PLUS_M  \
# ind_dataset   eval
# cifar10       cifar10 [selective]                                              0.9969
# cifar100      cifar100 [selective]                                             0.9231
# tiny_imagenet tiny_imagenet [selective]                                        0.8959
#
# measure                                  R_e 1 2 (S)_COMPOSITE_EAT_SPHERICAL_OUTER_INNER_PLUS_M  \
# ind_dataset   eval
# cifar10       cifar10 [selective]                                                        0.9967
# cifar100      cifar100 [selective]                                                       0.9162
# tiny_imagenet tiny_imagenet [selective]                                                  0.8825
#
# measure                                  R_t 1 2 (S)_COMPOSITE_EAT_SPHERICAL_OUTER_INNER_PLUS_M  \
# ind_dataset   eval
# cifar10       cifar10 [selective]                                                        0.9970
# cifar100      cifar100 [selective]                                                       0.9225
# tiny_imagenet tiny_imagenet [selective]                                                  0.8957
#
# measure                                  R_b 1 (S)_COMPOSITE_EAT_SPHERICAL_OUTER_INNER_PLUS_M  \
# ind_dataset   eval
# cifar10       cifar10 [selective]                                                      0.9968
# cifar100      cifar100 [selective]                                                     0.9197
# tiny_imagenet tiny_imagenet [selective]                                                0.8921
#
# measure                                  M_COMPOSITE_EAT_SPHERICAL_OUTER_INNER_PLUS_M  \
# ind_dataset   eval
# cifar10       cifar10 [selective]                                              0.9963
# cifar100      cifar100 [selective]                                             0.8106
# tiny_imagenet tiny_imagenet [selective]                                        0.6598
#
# measure                                  C_COMPOSITE_EAT_SPHERICAL_OUTER_INNER_PLUS_M  \
# ind_dataset   eval
# cifar10       cifar10 [selective]                                              0.9970
# cifar100      cifar100 [selective]                                             0.9234
# tiny_imagenet tiny_imagenet [selective]                                        0.8964
#
# measure                                  R_e 1 3 (S)_COMPOSITE_EAT_SPHERICAL_OUTER_CENTRAL_PLUS_M  \
# ind_dataset   eval
# cifar10       cifar10 [selective]                                                          0.9968
# cifar100      cifar100 [selective]                                                         0.9135
# tiny_imagenet tiny_imagenet [selective]                                                    0.8779
#
# measure                                  R_t 1 3 (S)_COMPOSITE_EAT_SPHERICAL_OUTER_CENTRAL_PLUS_M  \
# ind_dataset   eval
# cifar10       cifar10 [selective]                                                          0.9970
# cifar100      cifar100 [selective]                                                         0.9229
# tiny_imagenet tiny_imagenet [selective]                                                    0.8960
#
# measure                                  R_b 1 (S)_COMPOSITE_EAT_SPHERICAL_OUTER_CENTRAL_PLUS_M  \
# ind_dataset   eval
# cifar10       cifar10 [selective]                                                        0.9968
# cifar100      cifar100 [selective]                                                       0.9197
# tiny_imagenet tiny_imagenet [selective]                                                  0.8921
#
# measure                                  M_COMPOSITE_EAT_SPHERICAL_OUTER_CENTRAL_PLUS_M  \
# ind_dataset   eval
# cifar10       cifar10 [selective]                                                0.9963
# cifar100      cifar100 [selective]                                               0.8106
# tiny_imagenet tiny_imagenet [selective]                                          0.6598
#
# measure                                  C_COMPOSITE_EAT_SPHERICAL_OUTER_CENTRAL_PLUS_M
# ind_dataset   eval
# cifar10       cifar10 [selective]                                                0.9970
# cifar100      cifar100 [selective]                                               0.9233
# tiny_imagenet tiny_imagenet [selective]                                          0.8961
# ================================================================================

# %%
# Access individual concatenated tables
ood_concatenated = concatenated_results['ood_detection']
miscls_concatenated = concatenated_results['misclassification_detection']
selective_concatenated = concatenated_results['selective_prediction']

print("INDIVIDUAL ACCESS TO CONCATENATED TABLES")
print("=" * 50)
print("You can now access each concatenated table individually:")
print()
print("# OOD Detection (all composite measures side-by-side)")
print("ood_concatenated = concatenated_results['ood_detection']")
print(f"Shape: {ood_concatenated.shape if not ood_concatenated.empty else 'Empty'}")
print()
print("# Misclassification Detection (all composite measures side-by-side)")  
print("miscls_concatenated = concatenated_results['misclassification_detection']")
print(f"Shape: {miscls_concatenated.shape if not miscls_concatenated.empty else 'Empty'}")
print()
print("# Selective Prediction (all composite measures side-by-side)")
print("selective_concatenated = concatenated_results['selective_prediction']")
print(f"Shape: {selective_concatenated.shape if not selective_concatenated.empty else 'Empty'}")
print()
print("Each table has:")
print("- Rows: (ind_dataset, eval) pairs")
print("- Columns: Individual measures + Comp, grouped by composite measure")
print("- All composite measures are side-by-side in the same table")
# Out:
# INDIVIDUAL ACCESS TO CONCATENATED TABLES
# ==================================================
# You can now access each concatenated table individually:
#
# # OOD Detection (all composite measures side-by-side)
# ood_concatenated = concatenated_results['ood_detection']
# Shape: (9, 52)
#
# # Misclassification Detection (all composite measures side-by-side)
# miscls_concatenated = concatenated_results['misclassification_detection']
# Shape: (3, 52)
#
# # Selective Prediction (all composite measures side-by-side)
# selective_concatenated = concatenated_results['selective_prediction']
# Shape: (3, 52)
#
# Each table has:
# - Rows: (ind_dataset, eval) pairs
# - Columns: Individual measures + Comp, grouped by composite measure
# - All composite measures are side-by-side in the same table

# %%
# Create separate pandas DataFrames for each problem type

# Convert each problem type table to a pandas DataFrame
problem_dataframes = {}
for problem_type in results['final_tables'].keys():
    problem_dataframes[problem_type] = pd.DataFrame(results['final_tables'][problem_type])
    print(f"\n{problem_type.upper()} Problem DataFrame:")
    print(f"Shape: {problem_dataframes[problem_type].shape}")
    print(problem_dataframes[problem_type])
# Out:
# OOD_DETECTION Problem DataFrame:
# Shape: (9, 52)
# measure                      R_b 1 (L)_v1  R_b 1 (B)_v1  R_b 1 (S)_v1  \
# ind_dataset   ood_dataset
# cifar10       cifar100           0.916906      0.914436      0.914506
#               svhn               0.962992      0.958357      0.958530
#               tiny_imagenet      0.911364      0.908611      0.908679
# cifar100      cifar10            0.773270      0.773000      0.773388
#               svhn               0.870120      0.858293      0.860970
#               tiny_imagenet      0.809888      0.789521      0.806267
# tiny_imagenet imagenet_a         0.835350      0.827188      0.830074
#               imagenet_o         0.724312      0.720970      0.722622
#               imagenet_r         0.825339      0.816241      0.819225
#
# measure                      R_b 1 (Z)_v1      C_v1  R_b 1 (L)_v2  \
# ind_dataset   ood_dataset
# cifar10       cifar100           0.913191  0.915758      0.916906
#               svhn               0.956294  0.960983      0.962992
#               tiny_imagenet      0.907210  0.910094      0.911364
# cifar100      cifar10            0.772177  0.773419      0.773270
#               svhn               0.855937  0.865872      0.870120
#               tiny_imagenet      0.803022  0.805415      0.809888
# tiny_imagenet imagenet_a         0.826338  0.833061      0.835350
#               imagenet_o         0.721199  0.723431      0.724312
#               imagenet_r         0.815484  0.822548      0.825339
#
# measure                      R_b 1 (B)_v2  R_b 1 (S)_v2  R_b 1 (Z)_v2  \
# ind_dataset   ood_dataset
# cifar10       cifar100           0.914436      0.914506      0.913191
#               svhn               0.958357      0.958530      0.956294
#               tiny_imagenet      0.908611      0.908679      0.907210
# cifar100      cifar10            0.773000      0.773388      0.772177
#               svhn               0.858293      0.860970      0.855937
#               tiny_imagenet      0.789521      0.806267      0.803022
# tiny_imagenet imagenet_a         0.827188      0.830074      0.826338
#               imagenet_o         0.720970      0.722622      0.721199
#               imagenet_r         0.816241      0.819225      0.815484
#
# measure                          M_v2      C_v2  R_e 1 2 (L)_v3  \
# ind_dataset   ood_dataset
# cifar10       cifar100       0.912238  0.918528        0.907203
#               svhn           0.934311  0.957215        0.945786
#               tiny_imagenet  0.910273  0.914034        0.898685
# cifar100      cifar10        0.534822  0.768139        0.736746
#               svhn           0.678832  0.867749        0.776340
#               tiny_imagenet  0.622941  0.804597        0.999942
# tiny_imagenet imagenet_a     0.440974  0.832422        0.801424
#               imagenet_o     0.512686  0.727679        0.755245
#               imagenet_r     0.404755  0.820272        0.793349
#
# measure                      R_e 1 2 (B)_v3  R_e 1 2 (S)_v3  R_e 1 2 (Z)_v3  \
# ind_dataset   ood_dataset
# cifar10       cifar100             0.902342        0.902404        0.754648
#               svhn                 0.940173        0.942129        0.824603
#               tiny_imagenet        0.893229        0.893123        0.752376
# cifar100      cifar10              0.681292        0.721580        0.689059
#               svhn                 0.662081        0.731242        0.705718
#               tiny_imagenet        0.953406        0.994416        0.976322
# tiny_imagenet imagenet_a           0.651126        0.731905        0.712905
#               imagenet_o           0.691078        0.723552        0.700500
#               imagenet_r           0.656990        0.730844        0.712239
#
# measure                          C_v3  R_e 1 2 (L)_v4  R_e 1 2 (B)_v4  \
# ind_dataset   ood_dataset
# cifar10       cifar100       0.905882        0.907203        0.902342
#               svhn           0.943957        0.945786        0.940173
#               tiny_imagenet  0.897247        0.898685        0.893229
# cifar100      cifar10        0.720619        0.736746        0.681292
#               svhn           0.739645        0.776340        0.662081
#               tiny_imagenet  0.999854        0.999942        0.953406
# tiny_imagenet imagenet_a     0.754996        0.801424        0.651126
#               imagenet_o     0.736824        0.755245        0.691078
#               imagenet_r     0.750137        0.793349        0.656990
#
# measure                      R_e 1 2 (S)_v4  R_e 1 2 (Z)_v4      M_v4  \
# ind_dataset   ood_dataset
# cifar10       cifar100             0.902404        0.754648  0.912238
#               svhn                 0.942129        0.824603  0.934311
#               tiny_imagenet        0.893123        0.752376  0.910273
# cifar100      cifar10              0.721580        0.689059  0.534822
#               svhn                 0.731242        0.705718  0.678832
#               tiny_imagenet        0.994416        0.976322  0.622941
# tiny_imagenet imagenet_a           0.731905        0.712905  0.440974
#               imagenet_o           0.723552        0.700500  0.512686
#               imagenet_r           0.730844        0.712239  0.404755
#
# measure                          C_v4  R_e 1 1 (L)_v5  R_t 1 1 (L)_v5  \
# ind_dataset   ood_dataset
# cifar10       cifar100       0.910281        0.904730        0.911507
#               svhn           0.942297        0.942616        0.956506
#               tiny_imagenet  0.904191        0.895731        0.903615
# cifar100      cifar10        0.692810        0.724548        0.774023
#               svhn           0.724697        0.755848        0.867727
#               tiny_imagenet  0.999611        0.999852        0.999997
# tiny_imagenet imagenet_a     0.729263        0.781130        0.846305
#               imagenet_o     0.721285        0.752832        0.753524
#               imagenet_r     0.723755        0.774366        0.836572
#
# measure                      R_b 1 (L)_v5      M_v5      C_v5  R_e 1 2 (L)_v6  \
# ind_dataset   ood_dataset
# cifar10       cifar100           0.916906  0.912238  0.918087        0.907203
#               svhn               0.962992  0.934311  0.957326        0.945786
#               tiny_imagenet      0.911364  0.910273  0.912274        0.898685
# cifar100      cifar10            0.773270  0.534822  0.764887        0.736746
#               svhn               0.870120  0.678832  0.871659        0.776340
#               tiny_imagenet      0.809888  0.622941  0.999998        0.999942
# tiny_imagenet imagenet_a         0.835350  0.440974  0.846915        0.801424
#               imagenet_o         0.724312  0.512686  0.759562        0.755245
#               imagenet_r         0.825339  0.404755  0.834687        0.793349
#
# measure                      R_t 1 2 (L)_v6  R_b 1 (L)_v6      M_v6      C_v6  \
# ind_dataset   ood_dataset
# cifar10       cifar100             0.916237      0.916906  0.912238  0.919435
#               svhn                 0.963150      0.962992  0.934311  0.959062
#               tiny_imagenet        0.909549      0.911364  0.910273  0.914107
# cifar100      cifar10              0.774538      0.773270  0.534822  0.766726
#               svhn                 0.870178      0.870120  0.678832  0.874491
#               tiny_imagenet        0.926019      0.809888  0.622941  0.999382
# tiny_imagenet imagenet_a           0.840955      0.835350  0.440974  0.846650
#               imagenet_o           0.734891      0.724312  0.512686  0.751435
#               imagenet_r           0.830950      0.825339  0.404755  0.834365
#
# measure                      R_e 1 3 (L)_v7  R_t 1 3 (L)_v7  R_b 1 (L)_v7  \
# ind_dataset   ood_dataset
# cifar10       cifar100             0.902604        0.915012      0.916906
#               svhn                 0.939684        0.961888      0.962992
#               tiny_imagenet        0.893504        0.907927      0.911364
# cifar100      cifar10              0.718033        0.774192      0.773270
#               svhn                 0.749942        0.870307      0.870120
#               tiny_imagenet        0.999900        0.979732      0.809888
# tiny_imagenet imagenet_a           0.771967        0.842723      0.835350
#               imagenet_o           0.746410        0.740633      0.724312
#               imagenet_r           0.764380        0.832725      0.825339
#
# measure                          M_v7      C_v7  R_e 1 1 (S)_v8  \
# ind_dataset   ood_dataset
# cifar10       cifar100       0.912238  0.918911        0.904375
#               svhn           0.934311  0.958395        0.941999
#               tiny_imagenet  0.910273  0.913435        0.895592
# cifar100      cifar10        0.534822  0.765247        0.717172
#               svhn           0.678832  0.873782        0.723351
#               tiny_imagenet  0.622941  0.999974        0.991516
# tiny_imagenet imagenet_a     0.440974  0.846220        0.721152
#               imagenet_o     0.512686  0.754100        0.721061
#               imagenet_r     0.404755  0.833866        0.721591
#
# measure                      R_t 1 1 (S)_v8  R_b 1 (S)_v8      M_v8      C_v8  \
# ind_dataset   ood_dataset
# cifar10       cifar100             0.911267      0.914506  0.912238  0.911576
#               svhn                 0.955074      0.958530  0.934311  0.955774
#               tiny_imagenet        0.903609      0.908679  0.910273  0.903958
# cifar100      cifar10              0.773545      0.773388  0.534822  0.772483
#               svhn                 0.852639      0.860970  0.678832  0.851173
#               tiny_imagenet        0.992987      0.806267  0.622941  0.996683
# tiny_imagenet imagenet_a           0.835164      0.830074  0.440974  0.833246
#               imagenet_o           0.741544      0.722622  0.512686  0.742560
#               imagenet_r           0.825256      0.819225  0.404755  0.823563
#
# measure                      R_e 1 2 (S)_v9  R_t 1 2 (S)_v9  R_b 1 (S)_v9  \
# ind_dataset   ood_dataset
# cifar10       cifar100             0.902404        0.913049      0.914506
#               svhn                 0.942129        0.957686      0.958530
#               tiny_imagenet        0.893123        0.905816      0.908679
# cifar100      cifar10              0.721580        0.774385      0.773388
#               svhn                 0.731242        0.856738      0.860970
#               tiny_imagenet        0.994416        0.937085      0.806267
# tiny_imagenet imagenet_a           0.731905        0.834463      0.830074
#               imagenet_o           0.723552        0.735803      0.722622
#               imagenet_r           0.730844        0.824133      0.819225
#
# measure                          M_v9      C_v9  R_e 1 3 (S)_v10  \
# ind_dataset   ood_dataset
# cifar10       cifar100       0.912238  0.912573         0.903989
#               svhn           0.934311  0.957044         0.941816
#               tiny_imagenet  0.910273  0.905217         0.894407
# cifar100      cifar10        0.534822  0.772186         0.714663
#               svhn           0.678832  0.848436         0.718591
#               tiny_imagenet  0.622941  0.998886         0.989533
# tiny_imagenet imagenet_a     0.440974  0.832908         0.715396
#               imagenet_o     0.512686  0.742889         0.718873
#               imagenet_r     0.404755  0.823110         0.716317
#
# measure                      R_t 1 3 (S)_v10  R_b 1 (S)_v10     M_v10  \
# ind_dataset   ood_dataset
# cifar10       cifar100              0.912580       0.914506  0.912238
#               svhn                  0.957069       0.958530  0.934311
#               tiny_imagenet         0.905196       0.908679  0.910273
# cifar100      cifar10               0.773969       0.773388  0.534822
#               svhn                  0.854648       0.860970  0.678832
#               tiny_imagenet         0.979339       0.806267  0.622941
# tiny_imagenet imagenet_a            0.835404       0.830074  0.440974
#               imagenet_o            0.740566       0.722622  0.512686
#               imagenet_r            0.825429       0.819225  0.404755
#
# measure                         C_v10
# ind_dataset   ood_dataset
# cifar10       cifar100       0.912362
#               svhn           0.956739
#               tiny_imagenet  0.904926
# cifar100      cifar10        0.771673
#               svhn           0.847529
#               tiny_imagenet  0.999849
# tiny_imagenet imagenet_a     0.833250
#               imagenet_o     0.745659
#               imagenet_r     0.823839
#
# MISCLASSIFICATION_DETECTION Problem DataFrame:
# Shape: (3, 52)
# measure                      R_b 1 (L)_v1  R_b 1 (B)_v1  R_b 1 (S)_v1  \
# ind_dataset   eval_dataset
# cifar10       cifar10            0.942267      0.942466      0.942228
# cifar100      cifar100           0.845094      0.857773      0.856181
# tiny_imagenet tiny_imagenet      0.844739      0.854657      0.853150
#
# measure                      R_b 1 (Z)_v1      C_v1  R_b 1 (L)_v2  \
# ind_dataset   eval_dataset
# cifar10       cifar10            0.941776  0.942284      0.942267
# cifar100      cifar100           0.858986  0.852723      0.845094
# tiny_imagenet tiny_imagenet      0.854657  0.850581      0.844739
#
# measure                      R_b 1 (B)_v2  R_b 1 (S)_v2  R_b 1 (Z)_v2  \
# ind_dataset   eval_dataset
# cifar10       cifar10            0.942466      0.942228      0.941776
# cifar100      cifar100           0.857773      0.856181      0.858986
# tiny_imagenet tiny_imagenet      0.854657      0.853150      0.854657
#
# measure                          M_v2      C_v2  R_e 1 2 (L)_v3  \
# ind_dataset   eval_dataset
# cifar10       cifar10        0.927621  0.941973        0.941645
# cifar100      cifar100       0.573908  0.852722        0.831543
# tiny_imagenet tiny_imagenet  0.416754  0.851068        0.831461
#
# measure                      R_e 1 2 (B)_v3  R_e 1 2 (S)_v3  R_e 1 2 (Z)_v3  \
# ind_dataset   eval_dataset
# cifar10       cifar10              0.942365        0.941898        0.796675
# cifar100      cifar100             0.782572        0.837240        0.806319
# tiny_imagenet tiny_imagenet        0.754206        0.818794        0.800772
#
# measure                          C_v3  R_e 1 2 (L)_v4  R_e 1 2 (B)_v4  \
# ind_dataset   eval_dataset
# cifar10       cifar10        0.942578        0.941645        0.942365
# cifar100      cifar100       0.828869        0.831543        0.782572
# tiny_imagenet tiny_imagenet  0.819192        0.831461        0.754206
#
# measure                      R_e 1 2 (S)_v4  R_e 1 2 (Z)_v4      M_v4  \
# ind_dataset   eval_dataset
# cifar10       cifar10              0.941898        0.796675  0.927621
# cifar100      cifar100             0.837240        0.806319  0.573908
# tiny_imagenet tiny_imagenet        0.818794        0.800772  0.416754
#
# measure                          C_v4  R_e 1 1 (L)_v5  R_t 1 1 (L)_v5  \
# ind_dataset   eval_dataset
# cifar10       cifar10        0.941765        0.940430        0.943244
# cifar100      cifar100       0.803405        0.818006        0.853064
# tiny_imagenet tiny_imagenet  0.794594        0.813053        0.850815
#
# measure                      R_b 1 (L)_v5      M_v5      C_v5  R_e 1 2 (L)_v6  \
# ind_dataset   eval_dataset
# cifar10       cifar10            0.942267  0.927621  0.943901        0.941645
# cifar100      cifar100           0.845094  0.573908  0.848899        0.831543
# tiny_imagenet tiny_imagenet      0.844739  0.416754  0.846564        0.831461
#
# measure                      R_t 1 2 (L)_v6  R_b 1 (L)_v6      M_v6      C_v6  \
# ind_dataset   eval_dataset
# cifar10       cifar10              0.944886      0.942267  0.927621  0.944127
# cifar100      cifar100             0.850089      0.845094  0.573908  0.850217
# tiny_imagenet tiny_imagenet        0.849698      0.844739  0.416754  0.849263
#
# measure                      R_e 1 3 (L)_v7  R_t 1 3 (L)_v7  R_b 1 (L)_v7  \
# ind_dataset   eval_dataset
# cifar10       cifar10              0.936452        0.942223      0.942267
# cifar100      cifar100             0.804200        0.848810      0.845094
# tiny_imagenet tiny_imagenet        0.790788        0.846491      0.844739
#
# measure                          M_v7      C_v7  R_e 1 1 (S)_v8  \
# ind_dataset   eval_dataset
# cifar10       cifar10        0.927621  0.942019        0.943107
# cifar100      cifar100       0.573908  0.845683        0.829750
# tiny_imagenet tiny_imagenet  0.416754  0.841879        0.808581
#
# measure                      R_t 1 1 (S)_v8  R_b 1 (S)_v8      M_v8      C_v8  \
# ind_dataset   eval_dataset
# cifar10       cifar10              0.945171      0.942228  0.927621  0.945244
# cifar100      cifar100             0.867947      0.856181  0.573908  0.867715
# tiny_imagenet tiny_imagenet        0.864741      0.853150  0.416754  0.864256
#
# measure                      R_e 1 2 (S)_v9  R_t 1 2 (S)_v9  R_b 1 (S)_v9  \
# ind_dataset   eval_dataset
# cifar10       cifar10              0.941898        0.945782      0.942228
# cifar100      cifar100             0.837240        0.865555      0.856181
# tiny_imagenet tiny_imagenet        0.818794        0.863376      0.853150
#
# measure                          M_v9      C_v9  R_e 1 3 (S)_v10  \
# ind_dataset   eval_dataset
# cifar10       cifar10        0.927621  0.945720         0.942409
# cifar100      cifar100       0.573908  0.869103         0.827383
# tiny_imagenet tiny_imagenet  0.416754  0.865718         0.805184
#
# measure                      R_t 1 3 (S)_v10  R_b 1 (S)_v10     M_v10  \
# ind_dataset   eval_dataset
# cifar10       cifar10               0.945640       0.942228  0.927621
# cifar100      cifar100              0.867136       0.856181  0.573908
# tiny_imagenet tiny_imagenet         0.864523       0.853150  0.416754
#
# measure                         C_v10
# ind_dataset   eval_dataset
# cifar10       cifar10        0.945577
# cifar100      cifar100       0.868501
# tiny_imagenet tiny_imagenet  0.864705
#
# SELECTIVE_PREDICTION Problem DataFrame:
# Shape: (3, 52)
# measure                      R_b 1 (L)_v1  R_b 1 (B)_v1  R_b 1 (S)_v1  \
# ind_dataset   eval_dataset
# cifar10       cifar10            0.996818      0.996836      0.996827
# cifar100      cifar100           0.915943      0.920203      0.919719
# tiny_imagenet tiny_imagenet      0.888853      0.892676      0.892115
#
# measure                      R_b 1 (Z)_v1      C_v1  R_b 1 (L)_v2  \
# ind_dataset   eval_dataset
# cifar10       cifar10            0.996810  0.996822      0.996818
# cifar100      cifar100           0.920576  0.918640      0.915943
# tiny_imagenet tiny_imagenet      0.892648  0.891225      0.888853
#
# measure                      R_b 1 (B)_v2  R_b 1 (S)_v2  R_b 1 (Z)_v2  \
# ind_dataset   eval_dataset
# cifar10       cifar10            0.996836      0.996827      0.996810
# cifar100      cifar100           0.920203      0.919719      0.920576
# tiny_imagenet tiny_imagenet      0.892676      0.892115      0.892648
#
# measure                          M_v2      C_v2  R_e 1 2 (L)_v3  \
# ind_dataset   eval_dataset
# cifar10       cifar10        0.996266  0.996852        0.996886
# cifar100      cifar100       0.810550  0.917283        0.913284
# tiny_imagenet tiny_imagenet  0.659777  0.889025        0.885251
#
# measure                      R_e 1 2 (B)_v3  R_e 1 2 (S)_v3  R_e 1 2 (Z)_v3  \
# ind_dataset   eval_dataset
# cifar10       cifar10              0.996913        0.996698        0.982762
# cifar100      cifar100             0.899957        0.916155        0.878853
# tiny_imagenet tiny_imagenet        0.860041        0.882483        0.852802
#
# measure                          C_v3  R_e 1 2 (L)_v4  R_e 1 2 (B)_v4  \
# ind_dataset   eval_dataset
# cifar10       cifar10        0.996921        0.996886        0.996913
# cifar100      cifar100       0.913014        0.913284        0.899957
# tiny_imagenet tiny_imagenet  0.881994        0.885251        0.860041
#
# measure                      R_e 1 2 (S)_v4  R_e 1 2 (Z)_v4      M_v4  \
# ind_dataset   eval_dataset
# cifar10       cifar10              0.996698        0.982762  0.996266
# cifar100      cifar100             0.916155        0.878853  0.810550
# tiny_imagenet tiny_imagenet        0.882483        0.852802  0.659777
#
# measure                          C_v4  R_e 1 1 (L)_v5  R_t 1 1 (L)_v5  \
# ind_dataset   eval_dataset
# cifar10       cifar10        0.996818        0.996843        0.996864
# cifar100      cifar100       0.901336        0.909667        0.918425
# tiny_imagenet tiny_imagenet  0.866560        0.879249        0.890910
#
# measure                      R_b 1 (L)_v5      M_v5      C_v5  R_e 1 2 (L)_v6  \
# ind_dataset   eval_dataset
# cifar10       cifar10            0.996818  0.996266  0.996920        0.996886
# cifar100      cifar100           0.915943  0.810550  0.915408        0.913284
# tiny_imagenet tiny_imagenet      0.888853  0.659777  0.886301        0.885251
#
# measure                      R_t 1 2 (L)_v6  R_b 1 (L)_v6      M_v6      C_v6  \
# ind_dataset   eval_dataset
# cifar10       cifar10              0.996920      0.996818  0.996266  0.996931
# cifar100      cifar100             0.917541      0.915943  0.810550  0.915775
# tiny_imagenet tiny_imagenet        0.890666      0.888853  0.659777  0.887371
#
# measure                      R_e 1 3 (L)_v7  R_t 1 3 (L)_v7  R_b 1 (L)_v7  \
# ind_dataset   eval_dataset
# cifar10       cifar10              0.996693        0.996823      0.996818
# cifar100      cifar100             0.905640        0.917088      0.915943
# tiny_imagenet tiny_imagenet        0.871655        0.889288      0.888853
#
# measure                          M_v7      C_v7  R_e 1 1 (S)_v8  \
# ind_dataset   eval_dataset
# cifar10       cifar10        0.996266  0.996853        0.996936
# cifar100      cifar100       0.810550  0.914440        0.914149
# tiny_imagenet tiny_imagenet  0.659777  0.884567        0.879327
#
# measure                      R_t 1 1 (S)_v8  R_b 1 (S)_v8      M_v8      C_v8  \
# ind_dataset   eval_dataset
# cifar10       cifar10              0.996936      0.996827  0.996266  0.996939
# cifar100      cifar100             0.923118      0.919719  0.810550  0.923075
# tiny_imagenet tiny_imagenet        0.896064      0.892115  0.659777  0.895900
#
# measure                      R_e 1 2 (S)_v9  R_t 1 2 (S)_v9  R_b 1 (S)_v9  \
# ind_dataset   eval_dataset
# cifar10       cifar10              0.996698        0.996959      0.996827
# cifar100      cifar100             0.916155        0.922462      0.919719
# tiny_imagenet tiny_imagenet        0.882483        0.895661      0.892115
#
# measure                          M_v9      C_v9  R_e 1 3 (S)_v10  \
# ind_dataset   eval_dataset
# cifar10       cifar10        0.996266  0.996957         0.996769
# cifar100      cifar100       0.810550  0.923432         0.913539
# tiny_imagenet tiny_imagenet  0.659777  0.896391         0.877934
#
# measure                      R_t 1 3 (S)_v10  R_b 1 (S)_v10     M_v10  \
# ind_dataset   eval_dataset
# cifar10       cifar10               0.996954       0.996827  0.996266
# cifar100      cifar100              0.922896       0.919719  0.810550
# tiny_imagenet tiny_imagenet         0.896005       0.892115  0.659777
#
# measure                         C_v10
# ind_dataset   eval_dataset
# cifar10       cifar10        0.996951
# cifar100      cifar100       0.923270
# tiny_imagenet tiny_imagenet  0.896058

# %%
problem_dataframes['ood_detection']
# Out:
# measure                      R_b 1 (L)_v1  R_b 1 (B)_v1  R_b 1 (S)_v1  \
# ind_dataset   ood_dataset
# cifar10       cifar100           0.916906      0.914436      0.914506
#               svhn               0.962992      0.958357      0.958530
#               tiny_imagenet      0.911364      0.908611      0.908679
# cifar100      cifar10            0.773270      0.773000      0.773388
#               svhn               0.870120      0.858293      0.860970
#               tiny_imagenet      0.809888      0.789521      0.806267
# tiny_imagenet imagenet_a         0.835350      0.827188      0.830074
#               imagenet_o         0.724312      0.720970      0.722622
#               imagenet_r         0.825339      0.816241      0.819225
#
# measure                      R_b 1 (Z)_v1      C_v1  R_b 1 (L)_v2  \
# ind_dataset   ood_dataset
# cifar10       cifar100           0.913191  0.915758      0.916906
#               svhn               0.956294  0.960983      0.962992
#               tiny_imagenet      0.907210  0.910094      0.911364
# cifar100      cifar10            0.772177  0.773419      0.773270
#               svhn               0.855937  0.865872      0.870120
#               tiny_imagenet      0.803022  0.805415      0.809888
# tiny_imagenet imagenet_a         0.826338  0.833061      0.835350
#               imagenet_o         0.721199  0.723431      0.724312
#               imagenet_r         0.815484  0.822548      0.825339
#
# measure                      R_b 1 (B)_v2  R_b 1 (S)_v2  R_b 1 (Z)_v2  \
# ind_dataset   ood_dataset
# cifar10       cifar100           0.914436      0.914506      0.913191
#               svhn               0.958357      0.958530      0.956294
#               tiny_imagenet      0.908611      0.908679      0.907210
# cifar100      cifar10            0.773000      0.773388      0.772177
#               svhn               0.858293      0.860970      0.855937
#               tiny_imagenet      0.789521      0.806267      0.803022
# tiny_imagenet imagenet_a         0.827188      0.830074      0.826338
#               imagenet_o         0.720970      0.722622      0.721199
#               imagenet_r         0.816241      0.819225      0.815484
#
# measure                          M_v2      C_v2  R_e 1 2 (L)_v3  \
# ind_dataset   ood_dataset
# cifar10       cifar100       0.912238  0.918528        0.907203
#               svhn           0.934311  0.957215        0.945786
#               tiny_imagenet  0.910273  0.914034        0.898685
# cifar100      cifar10        0.534822  0.768139        0.736746
#               svhn           0.678832  0.867749        0.776340
#               tiny_imagenet  0.622941  0.804597        0.999942
# tiny_imagenet imagenet_a     0.440974  0.832422        0.801424
#               imagenet_o     0.512686  0.727679        0.755245
#               imagenet_r     0.404755  0.820272        0.793349
#
# measure                      R_e 1 2 (B)_v3  R_e 1 2 (S)_v3  R_e 1 2 (Z)_v3  \
# ind_dataset   ood_dataset
# cifar10       cifar100             0.902342        0.902404        0.754648
#               svhn                 0.940173        0.942129        0.824603
#               tiny_imagenet        0.893229        0.893123        0.752376
# cifar100      cifar10              0.681292        0.721580        0.689059
#               svhn                 0.662081        0.731242        0.705718
#               tiny_imagenet        0.953406        0.994416        0.976322
# tiny_imagenet imagenet_a           0.651126        0.731905        0.712905
#               imagenet_o           0.691078        0.723552        0.700500
#               imagenet_r           0.656990        0.730844        0.712239
#
# measure                          C_v3  R_e 1 2 (L)_v4  R_e 1 2 (B)_v4  \
# ind_dataset   ood_dataset
# cifar10       cifar100       0.905882        0.907203        0.902342
#               svhn           0.943957        0.945786        0.940173
#               tiny_imagenet  0.897247        0.898685        0.893229
# cifar100      cifar10        0.720619        0.736746        0.681292
#               svhn           0.739645        0.776340        0.662081
#               tiny_imagenet  0.999854        0.999942        0.953406
# tiny_imagenet imagenet_a     0.754996        0.801424        0.651126
#               imagenet_o     0.736824        0.755245        0.691078
#               imagenet_r     0.750137        0.793349        0.656990
#
# measure                      R_e 1 2 (S)_v4  R_e 1 2 (Z)_v4      M_v4  \
# ind_dataset   ood_dataset
# cifar10       cifar100             0.902404        0.754648  0.912238
#               svhn                 0.942129        0.824603  0.934311
#               tiny_imagenet        0.893123        0.752376  0.910273
# cifar100      cifar10              0.721580        0.689059  0.534822
#               svhn                 0.731242        0.705718  0.678832
#               tiny_imagenet        0.994416        0.976322  0.622941
# tiny_imagenet imagenet_a           0.731905        0.712905  0.440974
#               imagenet_o           0.723552        0.700500  0.512686
#               imagenet_r           0.730844        0.712239  0.404755
#
# measure                          C_v4  R_e 1 1 (L)_v5  R_t 1 1 (L)_v5  \
# ind_dataset   ood_dataset
# cifar10       cifar100       0.910281        0.904730        0.911507
#               svhn           0.942297        0.942616        0.956506
#               tiny_imagenet  0.904191        0.895731        0.903615
# cifar100      cifar10        0.692810        0.724548        0.774023
#               svhn           0.724697        0.755848        0.867727
#               tiny_imagenet  0.999611        0.999852        0.999997
# tiny_imagenet imagenet_a     0.729263        0.781130        0.846305
#               imagenet_o     0.721285        0.752832        0.753524
#               imagenet_r     0.723755        0.774366        0.836572
#
# measure                      R_b 1 (L)_v5      M_v5      C_v5  R_e 1 2 (L)_v6  \
# ind_dataset   ood_dataset
# cifar10       cifar100           0.916906  0.912238  0.918087        0.907203
#               svhn               0.962992  0.934311  0.957326        0.945786
#               tiny_imagenet      0.911364  0.910273  0.912274        0.898685
# cifar100      cifar10            0.773270  0.534822  0.764887        0.736746
#               svhn               0.870120  0.678832  0.871659        0.776340
#               tiny_imagenet      0.809888  0.622941  0.999998        0.999942
# tiny_imagenet imagenet_a         0.835350  0.440974  0.846915        0.801424
#               imagenet_o         0.724312  0.512686  0.759562        0.755245
#               imagenet_r         0.825339  0.404755  0.834687        0.793349
#
# measure                      R_t 1 2 (L)_v6  R_b 1 (L)_v6      M_v6      C_v6  \
# ind_dataset   ood_dataset
# cifar10       cifar100             0.916237      0.916906  0.912238  0.919435
#               svhn                 0.963150      0.962992  0.934311  0.959062
#               tiny_imagenet        0.909549      0.911364  0.910273  0.914107
# cifar100      cifar10              0.774538      0.773270  0.534822  0.766726
#               svhn                 0.870178      0.870120  0.678832  0.874491
#               tiny_imagenet        0.926019      0.809888  0.622941  0.999382
# tiny_imagenet imagenet_a           0.840955      0.835350  0.440974  0.846650
#               imagenet_o           0.734891      0.724312  0.512686  0.751435
#               imagenet_r           0.830950      0.825339  0.404755  0.834365
#
# measure                      R_e 1 3 (L)_v7  R_t 1 3 (L)_v7  R_b 1 (L)_v7  \
# ind_dataset   ood_dataset
# cifar10       cifar100             0.902604        0.915012      0.916906
#               svhn                 0.939684        0.961888      0.962992
#               tiny_imagenet        0.893504        0.907927      0.911364
# cifar100      cifar10              0.718033        0.774192      0.773270
#               svhn                 0.749942        0.870307      0.870120
#               tiny_imagenet        0.999900        0.979732      0.809888
# tiny_imagenet imagenet_a           0.771967        0.842723      0.835350
#               imagenet_o           0.746410        0.740633      0.724312
#               imagenet_r           0.764380        0.832725      0.825339
#
# measure                          M_v7      C_v7  R_e 1 1 (S)_v8  \
# ind_dataset   ood_dataset
# cifar10       cifar100       0.912238  0.918911        0.904375
#               svhn           0.934311  0.958395        0.941999
#               tiny_imagenet  0.910273  0.913435        0.895592
# cifar100      cifar10        0.534822  0.765247        0.717172
#               svhn           0.678832  0.873782        0.723351
#               tiny_imagenet  0.622941  0.999974        0.991516
# tiny_imagenet imagenet_a     0.440974  0.846220        0.721152
#               imagenet_o     0.512686  0.754100        0.721061
#               imagenet_r     0.404755  0.833866        0.721591
#
# measure                      R_t 1 1 (S)_v8  R_b 1 (S)_v8      M_v8      C_v8  \
# ind_dataset   ood_dataset
# cifar10       cifar100             0.911267      0.914506  0.912238  0.911576
#               svhn                 0.955074      0.958530  0.934311  0.955774
#               tiny_imagenet        0.903609      0.908679  0.910273  0.903958
# cifar100      cifar10              0.773545      0.773388  0.534822  0.772483
#               svhn                 0.852639      0.860970  0.678832  0.851173
#               tiny_imagenet        0.992987      0.806267  0.622941  0.996683
# tiny_imagenet imagenet_a           0.835164      0.830074  0.440974  0.833246
#               imagenet_o           0.741544      0.722622  0.512686  0.742560
#               imagenet_r           0.825256      0.819225  0.404755  0.823563
#
# measure                      R_e 1 2 (S)_v9  R_t 1 2 (S)_v9  R_b 1 (S)_v9  \
# ind_dataset   ood_dataset
# cifar10       cifar100             0.902404        0.913049      0.914506
#               svhn                 0.942129        0.957686      0.958530
#               tiny_imagenet        0.893123        0.905816      0.908679
# cifar100      cifar10              0.721580        0.774385      0.773388
#               svhn                 0.731242        0.856738      0.860970
#               tiny_imagenet        0.994416        0.937085      0.806267
# tiny_imagenet imagenet_a           0.731905        0.834463      0.830074
#               imagenet_o           0.723552        0.735803      0.722622
#               imagenet_r           0.730844        0.824133      0.819225
#
# measure                          M_v9      C_v9  R_e 1 3 (S)_v10  \
# ind_dataset   ood_dataset
# cifar10       cifar100       0.912238  0.912573         0.903989
#               svhn           0.934311  0.957044         0.941816
#               tiny_imagenet  0.910273  0.905217         0.894407
# cifar100      cifar10        0.534822  0.772186         0.714663
#               svhn           0.678832  0.848436         0.718591
#               tiny_imagenet  0.622941  0.998886         0.989533
# tiny_imagenet imagenet_a     0.440974  0.832908         0.715396
#               imagenet_o     0.512686  0.742889         0.718873
#               imagenet_r     0.404755  0.823110         0.716317
#
# measure                      R_t 1 3 (S)_v10  R_b 1 (S)_v10     M_v10  \
# ind_dataset   ood_dataset
# cifar10       cifar100              0.912580       0.914506  0.912238
#               svhn                  0.957069       0.958530  0.934311
#               tiny_imagenet         0.905196       0.908679  0.910273
# cifar100      cifar10               0.773969       0.773388  0.534822
#               svhn                  0.854648       0.860970  0.678832
#               tiny_imagenet         0.979339       0.806267  0.622941
# tiny_imagenet imagenet_a            0.835404       0.830074  0.440974
#               imagenet_o            0.740566       0.722622  0.512686
#               imagenet_r            0.825429       0.819225  0.404755
#
# measure                         C_v10
# ind_dataset   ood_dataset
# cifar10       cifar100       0.912362
#               svhn           0.956739
#               tiny_imagenet  0.904926
# cifar100      cifar10        0.771673
#               svhn           0.847529
#               tiny_imagenet  0.999849
# tiny_imagenet imagenet_a     0.833250
#               imagenet_o     0.745659
#               imagenet_r     0.823839
