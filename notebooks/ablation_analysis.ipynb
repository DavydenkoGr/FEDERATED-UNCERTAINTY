# %%
import pandas as pd

pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", None)
pd.set_option("display.width", None)
pd.set_option("display.max_colwidth", None)

# df = pd.read_csv("../ablation_ood_results_cifar10_cifar100_1.csv")
df = pd.read_csv("../ablation_ood_results_tiny_imagenet_imagenet_r_1.csv")

# %%
df
# Out:
#    In-distribution Out-of-distribution             Metric  \
# 0    tiny_imagenet          imagenet_r      TOT 1 1 (log)
# 1    tiny_imagenet          imagenet_r      EXC 1 1 (log)
# 2    tiny_imagenet          imagenet_r      BAYES 1 (log)
# 3    tiny_imagenet          imagenet_r  Mahalanobis score
# 4    tiny_imagenet          imagenet_r    multidim_scores
# 5    tiny_imagenet          imagenet_r      TOT 1 1 (log)
# 6    tiny_imagenet          imagenet_r      EXC 1 1 (log)
# 7    tiny_imagenet          imagenet_r      BAYES 1 (log)
# 8    tiny_imagenet          imagenet_r  Mahalanobis score
# 9    tiny_imagenet          imagenet_r    multidim_scores
# 10   tiny_imagenet          imagenet_r      TOT 1 1 (log)
# 11   tiny_imagenet          imagenet_r      EXC 1 1 (log)
# 12   tiny_imagenet          imagenet_r      BAYES 1 (log)
# 13   tiny_imagenet          imagenet_r  Mahalanobis score
# 14   tiny_imagenet          imagenet_r    multidim_scores
# 15   tiny_imagenet          imagenet_r      TOT 1 1 (log)
# 16   tiny_imagenet          imagenet_r      EXC 1 1 (log)
# 17   tiny_imagenet          imagenet_r      BAYES 1 (log)
# 18   tiny_imagenet          imagenet_r  Mahalanobis score
# 19   tiny_imagenet          imagenet_r    multidim_scores
# 20   tiny_imagenet          imagenet_r      TOT 1 1 (log)
# 21   tiny_imagenet          imagenet_r      EXC 1 1 (log)
# 22   tiny_imagenet          imagenet_r      BAYES 1 (log)
# 23   tiny_imagenet          imagenet_r  Mahalanobis score
# 24   tiny_imagenet          imagenet_r    multidim_scores
# 25   tiny_imagenet          imagenet_r      TOT 1 1 (log)
# 26   tiny_imagenet          imagenet_r      EXC 1 1 (log)
# 27   tiny_imagenet          imagenet_r      BAYES 1 (log)
# 28   tiny_imagenet          imagenet_r  Mahalanobis score
# 29   tiny_imagenet          imagenet_r    multidim_scores
# 30   tiny_imagenet          imagenet_r      TOT 1 1 (log)
# 31   tiny_imagenet          imagenet_r      EXC 1 1 (log)
# 32   tiny_imagenet          imagenet_r      BAYES 1 (log)
# 33   tiny_imagenet          imagenet_r  Mahalanobis score
# 34   tiny_imagenet          imagenet_r    multidim_scores
# 35   tiny_imagenet          imagenet_r      TOT 1 1 (log)
# 36   tiny_imagenet          imagenet_r      EXC 1 1 (log)
# 37   tiny_imagenet          imagenet_r      BAYES 1 (log)
# 38   tiny_imagenet          imagenet_r  Mahalanobis score
# 39   tiny_imagenet          imagenet_r    multidim_scores
# 40   tiny_imagenet          imagenet_r      TOT 1 1 (log)
# 41   tiny_imagenet          imagenet_r      EXC 1 1 (log)
# 42   tiny_imagenet          imagenet_r      BAYES 1 (log)
# 43   tiny_imagenet          imagenet_r  Mahalanobis score
# 44   tiny_imagenet          imagenet_r    multidim_scores
# 45   tiny_imagenet          imagenet_r      TOT 1 1 (log)
#     Mean ROC AUC  Std ROC AUC target scaling_type  grid_size
# 0       0.836572     0.001496    Exp  FeatureWise          5
# 1       0.774366     0.002809    Exp  FeatureWise          5
# 2       0.825339     0.002994    Exp  FeatureWise          5
# 3       0.404755     0.006890    Exp  FeatureWise          5
# 4       0.831289     0.000829    Exp  FeatureWise          5
# 5       0.836572     0.001496    Exp  FeatureWise          2
# 6       0.774366     0.002809    Exp  FeatureWise          2
# 7       0.825339     0.002994    Exp  FeatureWise          2
# 8       0.404755     0.006890    Exp  FeatureWise          2
# 9       0.831306     0.000835    Exp  FeatureWise          2
# 10      0.836572     0.001496    Exp  FeatureWise          0
# 11      0.774366     0.002809    Exp  FeatureWise          0
# 12      0.825339     0.002994    Exp  FeatureWise          0
# 13      0.404755     0.006890    Exp  FeatureWise          0
# 14      0.831367     0.000777    Exp  FeatureWise          0
# 15      0.836572     0.001496    Exp       Global          5
# 16      0.774366     0.002809    Exp       Global          5
# 17      0.825339     0.002994    Exp       Global          5
# 18      0.404755     0.006890    Exp       Global          5
# 19      0.421999     0.006611    Exp       Global          5
# 20      0.836572     0.001496    Exp       Global          2
# 21      0.774366     0.002809    Exp       Global          2
# 22      0.825339     0.002994    Exp       Global          2
# 23      0.404755     0.006890    Exp       Global          2
# 24      0.421810     0.006610    Exp       Global          2
# 25      0.836572     0.001496    Exp       Global          0
# 26      0.774366     0.002809    Exp       Global          0
# 27      0.825339     0.002994    Exp       Global          0
# 28      0.404755     0.006890    Exp       Global          0
# 29      0.420473     0.006612    Exp       Global          0
# 30      0.836572     0.001496   Beta  FeatureWise          5
# 31      0.774366     0.002809   Beta  FeatureWise          5
# 32      0.825339     0.002994   Beta  FeatureWise          5
# 33      0.404755     0.006890   Beta  FeatureWise          5
# 34      0.834519     0.000639   Beta  FeatureWise          5
# 35      0.836572     0.001496   Beta  FeatureWise          2
# 36      0.774366     0.002809   Beta  FeatureWise          2
# 37      0.825339     0.002994   Beta  FeatureWise          2
# 38      0.404755     0.006890   Beta  FeatureWise          2
# 39      0.834514     0.000639   Beta  FeatureWise          2
# 40      0.836572     0.001496   Beta  FeatureWise          0
# 41      0.774366     0.002809   Beta  FeatureWise          0
# 42      0.825339     0.002994   Beta  FeatureWise          0
# 43      0.404755     0.006890   Beta  FeatureWise          0
# 44      0.834509     0.000652   Beta  FeatureWise          0
# 45      0.836572     0.001496   Beta       Global          5
# 46      0.774366     0.002809   Beta       Global          5
# 47      0.825339     0.002994   Beta       Global          5
# 48      0.404755     0.006890   Beta       Global          5
# 49      0.419511     0.006852   Beta       Global          5
# 50      0.836572     0.001496   Beta       Global          2
# 51      0.774366     0.002809   Beta       Global          2
# 52      0.825339     0.002994   Beta       Global          2
# 53      0.404755     0.006890   Beta       Global          2
# 54      0.419462     0.006853   Beta       Global          2
# 55      0.836572     0.001496   Beta       Global          0
# 56      0.774366     0.002809   Beta       Global          0
# 57      0.825339     0.002994   Beta       Global          0
# 58      0.404755     0.006890   Beta       Global          0
# 59      0.419213     0.006850   Beta       Global          0

# %%
# df.sort_values(by=['Mean ROC AUC'])
df = df.drop(columns=["ROC AUC Scores"])
df = df[df["Metric"] == "multidim_scores"].sort_values(by="Mean ROC AUC", ascending=False)
df = df.drop(columns=["Metric"])
df
# Out:
#    In-distribution Out-of-distribution  Mean ROC AUC  Std ROC AUC target  \
# 34   tiny_imagenet          imagenet_r      0.834519     0.000639   Beta
# 39   tiny_imagenet          imagenet_r      0.834514     0.000639   Beta
# 44   tiny_imagenet          imagenet_r      0.834509     0.000652   Beta
# 14   tiny_imagenet          imagenet_r      0.831367     0.000777    Exp
# 9    tiny_imagenet          imagenet_r      0.831306     0.000835    Exp
# 4    tiny_imagenet          imagenet_r      0.831289     0.000829    Exp
# 19   tiny_imagenet          imagenet_r      0.421999     0.006611    Exp
# 24   tiny_imagenet          imagenet_r      0.421810     0.006610    Exp
# 29   tiny_imagenet          imagenet_r      0.420473     0.006612    Exp
# 49   tiny_imagenet          imagenet_r      0.419511     0.006852   Beta
# 54   tiny_imagenet          imagenet_r      0.419462     0.006853   Beta
# 59   tiny_imagenet          imagenet_r      0.419213     0.006850   Beta
#
#    scaling_type  grid_size
# 34  FeatureWise          5
# 39  FeatureWise          2
# 44  FeatureWise          0
# 14  FeatureWise          0
# 9   FeatureWise          2
# 4   FeatureWise          5
# 19       Global          5
# 24       Global          2
# 29       Global          0
# 49       Global          5
# 54       Global          2
# 59       Global          0

# %%
df["In-distribution"] = "TinyImageNet"
df["Out-of-distribution"] = "ImageNet-R"
print(df.round(6).to_latex(float_format="%.6f", index=False))
# Out:
# \begin{tabular}{llrrllr}
# \toprule
# In-distribution & Out-of-distribution & Mean ROC AUC & Std ROC AUC & target & scaling_type & grid_size \\
# \midrule
# TinyImageNet & ImageNet-R & 0.834519 & 0.000639 & Beta & FeatureWise & 5 \\
# TinyImageNet & ImageNet-R & 0.834514 & 0.000639 & Beta & FeatureWise & 2 \\
# TinyImageNet & ImageNet-R & 0.834509 & 0.000652 & Beta & FeatureWise & 0 \\
# TinyImageNet & ImageNet-R & 0.831367 & 0.000777 & Exp & FeatureWise & 0 \\
# TinyImageNet & ImageNet-R & 0.831306 & 0.000835 & Exp & FeatureWise & 2 \\
# TinyImageNet & ImageNet-R & 0.831289 & 0.000829 & Exp & FeatureWise & 5 \\
# TinyImageNet & ImageNet-R & 0.421999 & 0.006611 & Exp & Global & 5 \\
# TinyImageNet & ImageNet-R & 0.421810 & 0.006610 & Exp & Global & 2 \\
# TinyImageNet & ImageNet-R & 0.420473 & 0.006612 & Exp & Global & 0 \\
# TinyImageNet & ImageNet-R & 0.419511 & 0.006852 & Beta & Global & 5 \\
# TinyImageNet & ImageNet-R & 0.419462 & 0.006853 & Beta & Global & 2 \\
# TinyImageNet & ImageNet-R & 0.419213 & 0.006850 & Beta & Global & 0 \\
# \bottomrule
# \end{tabular}

# %%
# df = pd.read_csv("../ablation_ood_results_tiny_imagenet_imagenet_r.csv")

# # df.sort_values(by=['Mean ROC AUC'])
# df = df.drop(columns=["ROC AUC Scores"])
# df = df[df["Metric"] == "multidim_scores"].sort_values(by="Mean ROC AUC", ascending=False)
# df = df.drop(columns=["Metric"])
# df
