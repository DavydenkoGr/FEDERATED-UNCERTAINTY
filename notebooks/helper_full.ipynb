# %%
from mdu.unc.constants import RiskType
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 from mdu.unc.constants import RiskType
#
# ImportError: cannot import name 'RiskType' from 'mdu.unc.constants' (/home/nkotelevskii/github/multidimensional_uncertainty/mdu/unc/constants.py)

# %%
ind_dataset = "cifar10"
ood_dataset = "cifar100"


uncertainty_type = 'risk'
proper_scoring_rule = "brierscore"
risk_type = "bayesrisk"
gt_approximation = "central"
pred_approximation = "central"
T = 1.0

path = f"resources/results/{uncertainty_type}_{proper_scoring_rule}_{risk_type}_{gt_approximation}_{pred_approximation}_T_{T}.pkl"
