# %%
import pandas as pd

pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", None)
pd.set_option("display.width", None)
pd.set_option("display.max_colwidth", None)

# %%
df = pd.read_csv("../ablation_ood_results_cifar10_cifar100.csv")

# df.sort_values(by=['Mean ROC AUC'])
df = df.drop(columns=["ROC AUC Scores"])
df = df[df["Metric"] == "multidim_scores"].sort_values(by="Mean ROC AUC", ascending=False)
df = df.drop(columns=["Metric"])
df
# Out:
#    In-distribution Out-of-distribution  Mean ROC AUC  Std ROC AUC target  \
# 49         cifar10            cifar100      0.917984     0.000778   Beta
# 54         cifar10            cifar100      0.917983     0.000779   Beta
# 59         cifar10            cifar100      0.917950     0.000783   Beta
# 14         cifar10            cifar100      0.917474     0.000840    Exp
# 9          cifar10            cifar100      0.917423     0.000835    Exp
# 4          cifar10            cifar100      0.917394     0.000832    Exp
# 34         cifar10            cifar100      0.915669     0.000847    Exp
# 39         cifar10            cifar100      0.915552     0.000814    Exp
# 44         cifar10            cifar100      0.915245     0.001195    Exp
# 64         cifar10            cifar100      0.913731     0.001273   Beta
# 69         cifar10            cifar100      0.913727     0.001273   Beta
# 74         cifar10            cifar100      0.913700     0.001274   Beta
# 19         cifar10            cifar100      0.913466     0.001299    Exp
# 24         cifar10            cifar100      0.913454     0.001300    Exp
# 29         cifar10            cifar100      0.913383     0.001302    Exp
# 89         cifar10            cifar100      0.910275     0.000686   Beta
# 84         cifar10            cifar100      0.907669     0.000635   Beta
# 79         cifar10            cifar100      0.907524     0.000649   Beta
#
#    scaling_type  grid_size
# 49  FeatureWise          5
# 54  FeatureWise          2
# 59  FeatureWise          0
# 14  FeatureWise          0
# 9   FeatureWise          2
# 4   FeatureWise          5
# 34     Identity          5
# 39     Identity          2
# 44     Identity          0
# 64       Global          5
# 69       Global          2
# 74       Global          0
# 19       Global          5
# 24       Global          2
# 29       Global          0
# 89     Identity          0
# 84     Identity          2
# 79     Identity          5

# %%
# df = pd.read_csv("../ablation_ood_results_tiny_imagenet_imagenet_r.csv")

# # df.sort_values(by=['Mean ROC AUC'])
# df = df.drop(columns=["ROC AUC Scores"])
# df = df[df["Metric"] == "multidim_scores"].sort_values(by="Mean ROC AUC", ascending=False)
# df = df.drop(columns=["Metric"])
# df
